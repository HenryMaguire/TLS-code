# %% [markdown]
# # Incoherent-Excitation in Monomers
# ## Calculations for the paper: *sanity checks, convergence & analysis*

# %%
import time

from qutip import ket, mesolve, qeye, tensor, thermal_dm, destroy, steadystate
import qutip as qt
import matplotlib.pyplot as plt
import numpy as np
from numpy import pi

import UD_liouv as RC
import driving_liouv as EM
import ME_checking as check
import exact_IB as exact
import scipy as sp
import phonon_weak_coupling as WC
from utils import J_overdamped, beta_f, J_underdamped, J_minimal_hard

reload(RC)
reload(EM)
reload(check)
reload(exact)
plt.style.use('ggplot')

# %% [markdown]
# Things to do in these notes:
# - Convergence of RC theory with respect to N for increasing alpha:
#     - a) Overdamped
#     - b) Low and high-frequency under-damped
# - Are all my overdamped parameters working correctly? Is $w_0 = \epsilon$ sufficient?
# - I need to check that the exact solution gives me what I want: At which coupling strengths, mode frequencies, temperatures is the RC method valid?
# - How about with underdamped modes?
# - Look at vibronic/electronic eigenstate populations across windows of validity.
# - Look at decay rates to various vibronic states when starting in various vibronic states
# - check steadystate convergence with respect to $\omega_{RC}$ including optical driving at high T.
# - check dynamics error with respect to $\omega_{RC}$ as well for low and high T.
#
# Thus, does the ambiguity of $\omega_{RC}$ pose a major problem for incoherent excitation? *WHAT IS THE CORRECT APPROACH?!?!*

# %%
# Things that will always be true
G = ket([0])
E = ket([1])
sigma = G*E.dag() # Definition of a sigma_- operator.
J_EM = EM.J_minimal
# Things that are true by default but are subject to overriding
## ~~ Parameters ~~

eps = 0.1*8065.5 # TLS splitting
#eps = 2.*1519.3 # ps
T_EM = 6000. # Optical bath temperature
#H_S = eps*E*E.dag()
#alpha_EM = 0.3 # System-bath strength (optical)
Gamma_EM = 0.1*5.309 #bare decay of electronic transition from inv. ps to in inv. cm
#Gamma_EM = 6.582E-7*1519.3
T_ph = 300. # Phonon bath temperature
overdamped = True
phonon_only = True
#fig1wc = 53.*0.188

''' RC stuff '''
N = 15
#w0 = 200.*0.188
Gamma = 60. # Width of distribution
alpha_ph = 3*eps # Ind.-Boson frame coupling
beta = beta_f(T_ph)#1/(0.695*T_ph)
wc = 1*53. # Ind.-Boson frame phonon cutoff freq
shift = 0.5*np.pi*alpha_ph
w0 = eps+50 #-100 # underdamped SD parameter omega_0
optical_cutoff = 20000.
if overdamped:
        Gamma = (w0**2)/wc
n_RC = EM.Occupation(w0, T_ph)
#initial_sys = G*G.dag()
#initial_sys = E*E.dag()
#initial_sys = 0.5*(G+E)*(E.dag()+G.dag())
initial_sys = 0.5*(E+G)*(E+G).dag()

rho_0 = tensor(initial_sys, thermal_dm(N, n_RC))
#print (rho_0*tensor(qeye(2), destroy(N).dag()*destroy(N))).tr()

# Expectation values and time increments needed to calculate the dynamics
expects_wc = [G*G.dag(), E*G.dag()]
expects = [tensor(G*G.dag(), qeye(N)), tensor(E*G.dag(), qeye(N)), 
           tensor(E*E.dag(), qeye(N)), tensor(qeye(2), destroy(N).dag()*destroy(N)), 
           tensor(qeye(2), destroy(N).dag()+destroy(N))]
nTimeSteps = 250
timelist = np.linspace(0, 0.07, nTimeSteps)


def eigstate_calc_and_mag_sort(H, sort=True):
    # Helper function to calculate the eigenstates and sort
    # in order of eigvalue magnitude
    evals, evecs = H.eigenstates()
    if sort:
        evals, evecs = zip(*sorted(list(zip(evals, evecs)), key=lambda x: abs(x[0])))
    else:
        pass
    return np.array(evals), np.array(evecs)

# %% [markdown]
# ## Convergence of spectral densities and dynamics

# %% [markdown]
# Firstly, with what values of $\omega_0$ does the overdamped limit of underdamped SD converge?

# %%
alpha_ph = 1*eps
nsteps = 1000
w = np.linspace(0., 3*eps, nsteps)
w0_i = 1.2*eps
w0_f = w0_i+2.5*eps
# total error is naturally a function of nsteps
total_error = np.sqrt(sum((J_underdamped(
                    w, 1*eps, w0_i**2/wc, w0_i)-J_underdamped(
                    w, 1*eps, w0_f**2/wc, w0_f))**2))
print "Average SD error per step: {}".format(total_error/nsteps)

opts = qt.Options(nsteps=5000)

Gamma_i = w0_i**2/wc
L_RC, H_RC, A_EM_, A_nrwa_, wRC_, kappa_, Gamma_1_= RC.RC_function_UD(sigma, eps, T_ph, Gamma_i, w0_i, alpha_ph, N)
DATA_sc_i =  np.array(mesolve(H_RC, rho_0, timelist, [L_RC], expects, progress_bar=True).expect[1])

Gamma_f = w0_f**2/wc
L_RC, H_RC, A_EM_, A_nrwa_, wRC_, kappa_, Gamma_1_= RC.RC_function_UD(sigma, eps, T_ph, Gamma_f, w0_f, alpha_ph, N)
DATA_sc_f =  np.array(mesolve(H_RC, rho_0, timelist, [L_RC], expects, progress_bar=True, options=opts).expect[1])

total_error_dyn = np.sqrt(abs(sum(DATA_sc_i-DATA_sc_f)**2))
print "Average (approx.) error in each timestep: {}".format(total_error_dyn/float(nTimeSteps))
# Out:
# Average SD error per step: 0.0131119193741
# w_RC= 967.86  TLS splitting = 806.55 RC-res. bath coupling= 2.90640949473  N= 15 TLS-RC coupling= 1107.3422158 Gamma_RC=  17674.5845208
# 10.0%. Run time:   0.57s. Est. time left: 00:00:00:05
# 20.0%. Run time:   1.20s. Est. time left: 00:00:00:04
# 30.0%. Run time:   1.77s. Est. time left: 00:00:00:04
# 40.0%. Run time:   2.33s. Est. time left: 00:00:00:03
# 50.0%. Run time:   2.89s. Est. time left: 00:00:00:02
# 60.0%. Run time:   3.45s. Est. time left: 00:00:00:02
# 70.0%. Run time:   4.02s. Est. time left: 00:00:00:01
# 80.0%. Run time:   4.58s. Est. time left: 00:00:00:01
# 90.0%. Run time:   5.14s. Est. time left: 00:00:00:00
# Total run time:   5.69s
# w_RC= 2984.235  TLS splitting = 806.55 RC-res. bath coupling= 8.96142927543  N= 15 TLS-RC coupling= 1944.4290286 Gamma_RC=  168031.293117
# 10.0%. Run time:   5.17s. Est. time left: 00:00:00:46
# 20.0%. Run time:  10.33s. Est. time left: 00:00:00:41
# 30.0%. Run time:  18.25s. Est. time left: 00:00:00:42
# 40.0%. Run time:  23.84s. Est. time left: 00:00:00:35
# 50.0%. Run time:  29.10s. Est. time left: 00:00:00:29
# 60.0%. Run time:  33.96s. Est. time left: 00:00:00:22
# 70.0%. Run time:  39.36s. Est. time left: 00:00:00:16
# 80.0%. Run time:  44.58s. Est. time left: 00:00:00:11
# 90.0%. Run time:  51.18s. Est. time left: 00:00:00:05
# Total run time:  56.95s
# Average (approx.) error in each timestep: 0.000191842550739

# %% [markdown]
# THings seem to converge fairly well where $\omega_0>\epsilon$. The greater $\omega_0$ is, the longer the calculations take but (generally) fewer states are needed.

# %% [markdown]
# Secondly, convergence of RC theory dynamics. For some fairly strong coupling, when do the calculations stop changing appreciably with increasing N?

# %%
def integers(ni = 2, step=1):
    i = ni
    while True:
        i+=step
        yield i


def convergence_checker(alpha_prop, w0_prop, Gamma_, overdamped=False, threshold=10E-8):
    N_gen = integers()
    last_rc_sol = np.array([1])
    current_rc_sol = np.array([3])
    alpha_ph = eps*alpha_prop
    shift = 0.5*np.pi*alpha_ph
    w0 = eps*w0_prop
    if overdamped:
        Gamma_ = (w0**2)/wc
    w = np.linspace(0., eps, 1000)
    plt.figure()
    plt.plot(w, J_underdamped(w, alpha_ph, Gamma_, w0))
    plt.axvline(eps-shift, label='Splitting',color='k')
    plt.ylabel("Coupling Strength")
    plt.xlabel(r"Frequency $cm^{-1}$")
    plt.title("Phonon Spectral Density")
    plt.legend()
    plt.show()
    while sum(abs(last_rc_sol - current_rc_sol)**2) >threshold:
        
        N = N_gen.next()
        rho_0 = tensor(initial_sys, thermal_dm(N, n_RC))
        #print (rho_0*tensor(qeye(2), destroy(N).dag()*destroy(N))).tr()

        # Expectation values and time increments needed to calculate the dynamics
        expects_wc = [G*G.dag(), E*G.dag()]
        expects = [tensor(G*G.dag(), qeye(N)), tensor(E*G.dag(), qeye(N)), 
               tensor(E*E.dag(), qeye(N)), tensor(qeye(2), destroy(N).dag()*destroy(N)), 
               tensor(qeye(2), destroy(N).dag()+destroy(N))]
        ti = time.time()
        L_RC, H_RC, A_EM, A_nrwa, wRC, kappa, Gamma_1= RC.RC_function_UD(
                                                    sigma, eps, T_ph, Gamma_, 
                                                    w0, alpha_ph, N)
        DATA_sc =  np.array(mesolve(H_RC, rho_0, timelist, [L_RC], expects).expect[1])
        tf = time.time()
        last_rc_sol = np.array(current_rc_sol)
        current_rc_sol =  DATA_sc
        print '\t ** Error: ', sum(abs(
                last_rc_sol - current_rc_sol)**2), " ** Took: {}s**".format(tf-ti)

convergence_checker(1., 1./14., 30., threshold=10E-6)
convergence_checker(1., 1./2, 30., threshold=10E-6)

convergence_checker(1., 1., 0, overdamped=True, threshold=10E-6)
convergence_checker(1., 1.5, 0, overdamped=True, threshold=10E-6)
# Out:
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 3 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# 	 ** Error:  2261.80044992  ** Took: 0.0473761558533s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 4 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# 	 ** Error:  21.4720006027  ** Took: 0.0843670368195s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 5 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# 	 ** Error:  12.6460436831  ** Took: 0.107578039169s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 6 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# 	 ** Error:  8.43139290371  ** Took: 0.130636930466s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 7 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# 	 ** Error:  5.97814285807  ** Took: 0.183845043182s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 8 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# 	 ** Error:  4.42102742406  ** Took: 0.328377008438s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 9 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# 	 ** Error:  3.1982446119  ** Took: 0.267060995102s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 10 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# 	 ** Error:  2.18054110955  ** Took: 0.287415027618s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 11 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# 	 ** Error:  1.4169108386  ** Took: 0.360805988312s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 12 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# 	 ** Error:  0.899401007961  ** Took: 0.45871591568s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 13 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# 	 ** Error:  0.552712326037  ** Took: 0.518778800964s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 14 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# 	 ** Error:  0.321097254643  ** Took: 0.582737922668s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 15 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# 	 ** Error:  0.177097507128  ** Took: 0.684996843338s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 16 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# 	 ** Error:  0.0944601768072  ** Took: 0.86209487915s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 17 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# 	 ** Error:  0.0484724660637  ** Took: 0.975254058838s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 18 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# 	 ** Error:  0.0236872871306  ** Took: 1.11957502365s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 19 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# 	 ** Error:  0.0111376936879  ** Took: 1.18005514145s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 20 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# 	 ** Error:  0.00506154937976  ** Took: 1.36518287659s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 21 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# 	 ** Error:  0.00220851043971  ** Took: 1.63261818886s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 22 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# 	 ** Error:  0.000932400226594  ** Took: 1.6371409893s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 23 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# 	 ** Error:  0.000382902867463  ** Took: 1.86429405212s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 24 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# 	 ** Error:  0.000152789132228  ** Took: 2.02501010895s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 25 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# 	 ** Error:  5.97669136456e-05  ** Took: 2.39725899696s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 26 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# 	 ** Error:  2.30009729449e-05  ** Took: 3.04482483864s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 27 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# 	 ** Error:  8.75004562109e-06  ** Took: 3.71035718918s**
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.0118396833247  N= 3 TLS-RC coupling= 714.786326724 Gamma_RC=  30.0
# 	 ** Error:  2261.6893481  ** Took: 0.0487420558929s**
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.0118396833247  N= 4 TLS-RC coupling= 714.786326724 Gamma_RC=  30.0
# 	 ** Error:  22.8904944179  ** Took: 0.0640270709991s**
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.0118396833247  N= 5 TLS-RC coupling= 714.786326724 Gamma_RC=  30.0
# 	 ** Error:  15.7219600486  ** Took: 0.096556186676s**
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.0118396833247  N= 6 TLS-RC coupling= 714.786326724 Gamma_RC=  30.0
# 	 ** Error:  10.3792490829  ** Took: 0.143913030624s**
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.0118396833247  N= 7 TLS-RC coupling= 714.786326724 Gamma_RC=  30.0
# 	 ** Error:  6.8993843002  ** Took: 0.164035081863s**
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.0118396833247  N= 8 TLS-RC coupling= 714.786326724 Gamma_RC=  30.0
# 	 ** Error:  4.45199408244  ** Took: 0.208097934723s**
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.0118396833247  N= 9 TLS-RC coupling= 714.786326724 Gamma_RC=  30.0
# 	 ** Error:  2.72341742057  ** Took: 0.259552955627s**
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.0118396833247  N= 10 TLS-RC coupling= 714.786326724 Gamma_RC=  30.0
# 	 ** Error:  1.57587331003  ** Took: 0.317222118378s**
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.0118396833247  N= 11 TLS-RC coupling= 714.786326724 Gamma_RC=  30.0
# 	 ** Error:  0.856589003839  ** Took: 0.415485858917s**
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.0118396833247  N= 12 TLS-RC coupling= 714.786326724 Gamma_RC=  30.0
# 	 ** Error:  0.436579961777  ** Took: 0.500831127167s**
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.0118396833247  N= 13 TLS-RC coupling= 714.786326724 Gamma_RC=  30.0
# 	 ** Error:  0.210475817026  ** Took: 0.583706140518s**
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.0118396833247  N= 14 TLS-RC coupling= 714.786326724 Gamma_RC=  30.0
# 	 ** Error:  0.0963974377441  ** Took: 0.681735038757s**
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.0118396833247  N= 15 TLS-RC coupling= 714.786326724 Gamma_RC=  30.0
# 	 ** Error:  0.0421897876346  ** Took: 0.787609100342s**
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.0118396833247  N= 16 TLS-RC coupling= 714.786326724 Gamma_RC=  30.0
# 	 ** Error:  0.0176544571495  ** Took: 0.917794942856s**
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.0118396833247  N= 17 TLS-RC coupling= 714.786326724 Gamma_RC=  30.0
# 	 ** Error:  0.00705026120036  ** Took: 1.06175398827s**
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.0118396833247  N= 18 TLS-RC coupling= 714.786326724 Gamma_RC=  30.0
# 	 ** Error:  0.00267629686542  ** Took: 1.18048000336s**
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.0118396833247  N= 19 TLS-RC coupling= 714.786326724 Gamma_RC=  30.0
# 	 ** Error:  0.000962082455144  ** Took: 1.46800398827s**
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.0118396833247  N= 20 TLS-RC coupling= 714.786326724 Gamma_RC=  30.0
# 	 ** Error:  0.000326559802339  ** Took: 1.74310302734s**
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.0118396833247  N= 21 TLS-RC coupling= 714.786326724 Gamma_RC=  30.0
# 	 ** Error:  0.000104484729791  ** Took: 1.84052085876s**
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.0118396833247  N= 22 TLS-RC coupling= 714.786326724 Gamma_RC=  30.0
# 	 ** Error:  3.14889961885e-05  ** Took: 2.27227807045s**
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.0118396833247  N= 23 TLS-RC coupling= 714.786326724 Gamma_RC=  30.0
# 	 ** Error:  8.93970776421e-06  ** Took: 2.78280997276s**
# w_RC= 806.55  TLS splitting = 806.55 RC-res. bath coupling= 2.42200791228  N= 3 TLS-RC coupling= 1010.86051745 Gamma_RC=  12274.0170283
# 	 ** Error:  2251.2225347  ** Took: 0.0620920658112s**
# w_RC= 806.55  TLS splitting = 806.55 RC-res. bath coupling= 2.42200791228  N= 4 TLS-RC coupling= 1010.86051745 Gamma_RC=  12274.0170283
# 	 ** Error:  3.52865857276  ** Took: 0.0982210636139s**
# w_RC= 806.55  TLS splitting = 806.55 RC-res. bath coupling= 2.42200791228  N= 5 TLS-RC coupling= 1010.86051745 Gamma_RC=  12274.0170283
# 	 ** Error:  1.69743172639  ** Took: 0.164844036102s**
# w_RC= 806.55  TLS splitting = 806.55 RC-res. bath coupling= 2.42200791228  N= 6 TLS-RC coupling= 1010.86051745 Gamma_RC=  12274.0170283
# 	 ** Error:  0.757290633131  ** Took: 0.34219789505s**
# w_RC= 806.55  TLS splitting = 806.55 RC-res. bath coupling= 2.42200791228  N= 7 TLS-RC coupling= 1010.86051745 Gamma_RC=  12274.0170283
# 	 ** Error:  0.289945315983  ** Took: 0.416749000549s**
# w_RC= 806.55  TLS splitting = 806.55 RC-res. bath coupling= 2.42200791228  N= 8 TLS-RC coupling= 1010.86051745 Gamma_RC=  12274.0170283
# 	 ** Error:  0.0973173116918  ** Took: 0.640105962753s**
# w_RC= 806.55  TLS splitting = 806.55 RC-res. bath coupling= 2.42200791228  N= 9 TLS-RC coupling= 1010.86051745 Gamma_RC=  12274.0170283
# 	 ** Error:  0.0311201636949  ** Took: 0.829831123352s**
# w_RC= 806.55  TLS splitting = 806.55 RC-res. bath coupling= 2.42200791228  N= 10 TLS-RC coupling= 1010.86051745 Gamma_RC=  12274.0170283
# 	 ** Error:  0.00978345681765  ** Took: 1.16856789589s**
# w_RC= 806.55  TLS splitting = 806.55 RC-res. bath coupling= 2.42200791228  N= 11 TLS-RC coupling= 1010.86051745 Gamma_RC=  12274.0170283
# 	 ** Error:  0.00294348996212  ** Took: 2.13630700111s**
# w_RC= 806.55  TLS splitting = 806.55 RC-res. bath coupling= 2.42200791228  N= 12 TLS-RC coupling= 1010.86051745 Gamma_RC=  12274.0170283
# 	 ** Error:  0.000847942296033  ** Took: 2.07724905014s**
# w_RC= 806.55  TLS splitting = 806.55 RC-res. bath coupling= 2.42200791228  N= 13 TLS-RC coupling= 1010.86051745 Gamma_RC=  12274.0170283
# 	 ** Error:  0.000232187275215  ** Took: 2.76526093483s**
# w_RC= 806.55  TLS splitting = 806.55 RC-res. bath coupling= 2.42200791228  N= 14 TLS-RC coupling= 1010.86051745 Gamma_RC=  12274.0170283
# 	 ** Error:  6.15036494739e-05  ** Took: 3.85064005852s**
# w_RC= 806.55  TLS splitting = 806.55 RC-res. bath coupling= 2.42200791228  N= 15 TLS-RC coupling= 1010.86051745 Gamma_RC=  12274.0170283
# 	 ** Error:  1.57038633727e-05  ** Took: 4.825922966s**
# w_RC= 806.55  TLS splitting = 806.55 RC-res. bath coupling= 2.42200791228  N= 16 TLS-RC coupling= 1010.86051745 Gamma_RC=  12274.0170283
# 	 ** Error:  3.85275478304e-06  ** Took: 6.83453297615s**
# w_RC= 1209.825  TLS splitting = 806.55 RC-res. bath coupling= 3.63301186842  N= 3 TLS-RC coupling= 1238.04623444 Gamma_RC=  27616.5383137
# 	 ** Error:  2251.91747907  ** Took: 0.109745025635s**
# w_RC= 1209.825  TLS splitting = 806.55 RC-res. bath coupling= 3.63301186842  N= 4 TLS-RC coupling= 1238.04623444 Gamma_RC=  27616.5383137
# 	 ** Error:  4.14497569796  ** Took: 0.188554048538s**
# w_RC= 1209.825  TLS splitting = 806.55 RC-res. bath coupling= 3.63301186842  N= 5 TLS-RC coupling= 1238.04623444 Gamma_RC=  27616.5383137
# 	 ** Error:  2.1607994971  ** Took: 0.303818225861s**
# w_RC= 1209.825  TLS splitting = 806.55 RC-res. bath coupling= 3.63301186842  N= 6 TLS-RC coupling= 1238.04623444 Gamma_RC=  27616.5383137
# 	 ** Error:  1.04259315267  ** Took: 0.555399179459s**
# w_RC= 1209.825  TLS splitting = 806.55 RC-res. bath coupling= 3.63301186842  N= 7 TLS-RC coupling= 1238.04623444 Gamma_RC=  27616.5383137
# 	 ** Error:  0.382326082438  ** Took: 0.791372060776s**
# w_RC= 1209.825  TLS splitting = 806.55 RC-res. bath coupling= 3.63301186842  N= 8 TLS-RC coupling= 1238.04623444 Gamma_RC=  27616.5383137
# 	 ** Error:  0.11406957482  ** Took: 1.22541499138s**
# w_RC= 1209.825  TLS splitting = 806.55 RC-res. bath coupling= 3.63301186842  N= 9 TLS-RC coupling= 1238.04623444 Gamma_RC=  27616.5383137
# 	 ** Error:  0.026450785571  ** Took: 1.7136220932s**
# w_RC= 1209.825  TLS splitting = 806.55 RC-res. bath coupling= 3.63301186842  N= 10 TLS-RC coupling= 1238.04623444 Gamma_RC=  27616.5383137
# 	 ** Error:  0.00610031973799  ** Took: 2.44120597839s**
# w_RC= 1209.825  TLS splitting = 806.55 RC-res. bath coupling= 3.63301186842  N= 11 TLS-RC coupling= 1238.04623444 Gamma_RC=  27616.5383137
# 	 ** Error:  0.0015830329081  ** Took: 3.0515639782s**
# w_RC= 1209.825  TLS splitting = 806.55 RC-res. bath coupling= 3.63301186842  N= 12 TLS-RC coupling= 1238.04623444 Gamma_RC=  27616.5383137
# 	 ** Error:  0.000400470533944  ** Took: 4.24730205536s**
# w_RC= 1209.825  TLS splitting = 806.55 RC-res. bath coupling= 3.63301186842  N= 13 TLS-RC coupling= 1238.04623444 Gamma_RC=  27616.5383137
# 	 ** Error:  9.2296023463e-05  ** Took: 5.52840399742s**
# w_RC= 1209.825  TLS splitting = 806.55 RC-res. bath coupling= 3.63301186842  N= 14 TLS-RC coupling= 1238.04623444 Gamma_RC=  27616.5383137
# 	 ** Error:  1.95896331963e-05  ** Took: 7.53684616089s**
# w_RC= 1209.825  TLS splitting = 806.55 RC-res. bath coupling= 3.63301186842  N= 15 TLS-RC coupling= 1238.04623444 Gamma_RC=  27616.5383137
# 	 ** Error:  4.0925741692e-06  ** Took: 9.9304189682s**

# %% [markdown]
# Underdamped:
# - $\alpha=\epsilon$, $\omega_0=\epsilon/14, \Gamma=30cm^{-1}$ : converges at N=27 in 2.73s
# - $\alpha=\epsilon$, $\omega_0=\epsilon/2, \Gamma=30cm^{-1}$ : converges at N=23 in 2.40s
#
# Overdamped:
# - $\alpha=\epsilon$, $\omega_0=1.5\epsilon, \Gamma=12274cm^{-1}$ : converges at N=16 in 6.6s
# - $\alpha=\epsilon$, $\omega_0=2\epsilon, \Gamma=27617cm^{-1}$ : converges at N=15 in 9.17s
#
# where $\Gamma$ is the width of the Lorentzian spectral density.

# %% [markdown]
# ## Comparison to exact solution
#
# How well does the RC theory agree with exact?
# - w_0 dependence
# - alpha dependence

# %%
def exact_comparison_alpha(w0_prop, Gamma_, N=3, overdamped=False):
    timelist_exact = np.linspace(0, 0.04, 70)
    timelist = np.linspace(0, 0.04, 250)
    w0 = eps*w0_prop
    if overdamped:
        Gamma_ = (w0**2)/wc
    w = np.linspace(0., eps*1.5, 1000)
    plt.figure()
    plt.plot(w, J_underdamped(w, alpha_ph, Gamma_, w0))
    plt.ylabel("Coupling Strength")
    plt.xlabel(r"Frequency $cm^{-1}$")
    plt.title("Phonon Spectral Density")
    plt.legend()
    plt.show()
    
    exact_sol = []
    rc_sol = []
    prop_of_eps = np.linspace(0.03,1,3)
    for prop in prop_of_eps:
        # how well
        alpha = prop*eps
        shift = 0#0.5*np.pi*alpha#*0.25
        ti = time.time()
        rho_01 = np.array(exact.exact_dynamics(eps-shift, alpha, wc, 
                                               w0, Gamma_, beta, initial_sys, 
                                               timelist_exact, overdamped=overdamped))
        print "Exact dynamics calculated"
        print "Exact solution took {} seconds.".format(time.time()-ti)
        expects = [tensor(G*G.dag(), qeye(N)), tensor(E*G.dag(), qeye(N)), 
               tensor(E*E.dag(), qeye(N)), tensor(qeye(2), destroy(N).dag()*destroy(N)), 
               tensor(qeye(2), destroy(N).dag()+destroy(N))]
        rho_0 = tensor(initial_sys, thermal_dm(N, n_RC))
        #DATA_wc = mesolve(H_S, initial_sys, timelist, [L_wc], expects_wc, progress_bar=True)
        L_RC, H_RC, A_EM, A_nrwa, wRC, kappa, Gamma= RC.RC_function_UD(sigma, eps, 
                                                                       T_ph, Gamma_, 
                                                                       w0, alpha, N)
        #print H_RC.eigenenergies()
        #print eps-0.5*np.pi*alpha, eps+w0, eps-0.5*np.pi*alpha+w0
        DATA_sc = mesolve(H_RC, rho_0, timelist, [L_RC], expects).expect[1].real
        #exact_sol.append(rho_01.real)
        #rc_sol.append(DATA_sc.real)
        plt.figure()
        plt.title("prop_of_eps: {}".format(prop))
        plt.scatter(timelist_exact, rho_01, label="exact")
        plt.plot(timelist, DATA_sc, label="rc")
        plt.xlim(0,timelist[-1])
        # Everything is oscillating at the shifted frequency
        #plt.plot(timelist, 0.5*np.exp((-50.-1j*(eps-shift))*timelist))  
        plt.legend(loc='right')
        plt.show()
        
exact_comparison_alpha(1.1, 0, N=18, overdamped=True)
exact_comparison_alpha(1.2, 20, N=24, overdamped=False)
exact_comparison_alpha(1./2., 20, N=24, overdamped=False)
exact_comparison_alpha(1./5., 20, N=27, overdamped=False)
#

#exact_comparison_alpha(1., 0., N=16, overdamped=True)
#exact_comparison_alpha(2., 0., N=15, overdamped=True)
# Out:
# /home/henry/anaconda2/envs/qutip/lib/python2.7/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# Exact solution 57.143 percent finished
# Exact dynamics calculated
# Exact solution took 8.62483811378 seconds.
# w_RC= 887.205  TLS splitting = 806.55 RC-res. bath coupling= 2.71544348627  N= 18 TLS-RC coupling= 183.631932216 Gamma_RC=  15137.1675389
# /home/henry/anaconda2/envs/qutip/lib/python2.7/site-packages/numpy/core/numeric.py:583: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)
# Exact solution 57.143 percent finished
# Exact dynamics calculated
# Exact solution took 30.570595026 seconds.
# w_RC= 887.205  TLS splitting = 806.55 RC-res. bath coupling= 2.71544348627  N= 18 TLS-RC coupling= 760.836240871 Gamma_RC=  15137.1675389
# Exact solution 57.143 percent finished
# Exact dynamics calculated
# Exact solution took 35.8098189831 seconds.
# w_RC= 887.205  TLS splitting = 806.55 RC-res. bath coupling= 2.71544348627  N= 18 TLS-RC coupling= 1060.19945497 Gamma_RC=  15137.1675389
# Exact solution 57.143 percent finished
# Exact dynamics calculated
# Exact solution took 4.7713239193 seconds.
# w_RC= 967.86  TLS splitting = 806.55 RC-res. bath coupling= 0.00328880092352  N= 24 TLS-RC coupling= 191.797297913 Gamma_RC=  20
# Exact solution 57.143 percent finished
# Exact dynamics calculated
# Exact solution took 22.5287082195 seconds.
# w_RC= 967.86  TLS splitting = 806.55 RC-res. bath coupling= 0.00328880092352  N= 24 TLS-RC coupling= 794.667536262 Gamma_RC=  20
# Exact solution 57.143 percent finished
# Exact dynamics calculated
# Exact solution took 26.4653029442 seconds.
# w_RC= 967.86  TLS splitting = 806.55 RC-res. bath coupling= 0.00328880092352  N= 24 TLS-RC coupling= 1107.3422158 Gamma_RC=  20
# Exact solution 57.143 percent finished
# Exact dynamics calculated
# Exact solution took 4.05265402794 seconds.
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.00789312221645  N= 24 TLS-RC coupling= 123.804623444 Gamma_RC=  20
# Exact solution 57.143 percent finished
# Exact dynamics calculated
# Exact solution took 6.36506700516 seconds.
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.00789312221645  N= 24 TLS-RC coupling= 512.955688953 Gamma_RC=  20
# Exact solution 57.143 percent finished
# Exact dynamics calculated
# Exact solution took 19.5914218426 seconds.
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.00789312221645  N= 24 TLS-RC coupling= 714.786326724 Gamma_RC=  20
# Exact solution 57.143 percent finished
# Exact dynamics calculated
# Exact solution took 2.08844995499 seconds.
# w_RC= 161.31  TLS splitting = 806.55 RC-res. bath coupling= 0.0197328055411  N= 27 TLS-RC coupling= 78.3009189886 Gamma_RC=  20
# Exact solution 57.143 percent finished
# Exact dynamics calculated
# Exact solution took 5.32189488411 seconds.
# w_RC= 161.31  TLS splitting = 806.55 RC-res. bath coupling= 0.0197328055411  N= 27 TLS-RC coupling= 324.421663166 Gamma_RC=  20
# Exact solution 57.143 percent finished
# Exact dynamics calculated
# Exact solution took 5.79030609131 seconds.
# w_RC= 161.31  TLS splitting = 806.55 RC-res. bath coupling= 0.0197328055411  N= 27 TLS-RC coupling= 452.070566559 Gamma_RC=  20

# %% [markdown]
# So we can see that for broad overdamped environments the RC method works extremely well, however for more structured environments it doesn't match the exact solution.
#
# ## Convergence of optical driving code
#
# Now we will check steadystate convergence with respect to N including optical driving.

# %%
#L_1, H_1, _, _, _, _, _= RC.RC_function_UD(sigma, eps, T_ph, Gamma, w0, eps*0.5, 10) # E_e >0
#L_2, H_2, _, _, _, _, _= RC.RC_function_UD(sigma, eps, T_ph, Gamma, w0, eps*0.8, 10) # E_e <0

# %%
w0 = eps*1.1
wc = 52.
Gamma = (w0**2)/wc

def driving_convergence_N(alpha_prop, w0_prop, Gamma_, T_EM=6000., overdamped=False):
    e0_population = [[],[],[]]
    g1_population = [[],[],[]]
    labels = ['nrwa', 'non-sec', 'naive']
    alpha_ph = eps*alpha_prop
    shift = 0.5*np.pi*alpha_ph
    w0 = eps*w0_prop
    if overdamped:
        Gamma_ = (w0**2)/wc
    #w = np.linspace(0., eps, 1000)
    #plt.figure()
    #plt.plot(w, J_underdamped(w, alpha_ph, Gamma_, w0))
    #plt.axvline(eps-shift, label='Splitting',color='k')
    #plt.ylabel("Coupling Strength")
    #plt.xlabel(r"Frequency $cm^{-1}$")
    #plt.title("Phonon Spectral Density")
    #plt.legend()
    #plt.show()
    N_values = range(3,23)
    for n in N_values:
        rho_0 = tensor(initial_sys, thermal_dm(n, n_RC))
        #print (rho_0*tensor(qeye(2), destroy(N).dag()*destroy(N))).tr()

        # Expectation values and time increments needed to calculate the dynamics
        expects = [tensor(G*G.dag(), qeye(n)), tensor(E*G.dag(), qeye(n)), 
               tensor(E*E.dag(), qeye(n)), tensor(qeye(2), destroy(N).dag()*destroy(N)), 
               tensor(qeye(2), destroy(n).dag()+destroy(n))]
        ti = time.time()
        L_RC, H_RC, A_EM, A_nrwa, wRC, kappa, Gamma_1= RC.RC_function_UD(
                                                    sigma, eps, T_ph, Gamma_, 
                                                    w0, alpha_ph, n)
        evals, states = eigstate_calc_and_mag_sort(H_RC, sort=False)
        
        L= [EM.L_non_rwa(H_RC, A_nrwa, eps, Gamma_EM, T_EM, J=J_EM), 
            EM.L_nonsecular(H_RC, A_EM, eps, Gamma_EM, T_EM, J=J_EM),
            EM.L_EM_lindblad(eps, A_EM, Gamma_EM, T_EM, J=J_EM)]
        
        for j, L_EM in enumerate(L):
            state = states[1]
            e0_population[j].append(steadystate(H_RC, [L_RC+L_EM]).matrix_element(
                                                                state.dag(), state))
            state = states[2]
            g1_population[j].append(steadystate(H_RC, [L_RC+L_EM]).matrix_element(
                                                                state.dag(), state))
        tf = time.time()
        print " ** Steady states took: {}s**".format(tf-ti)
    plt.figure()
    for i in range(len(e0_population)):
        plt.ylabel('e-0 population')
        plt.xlabel('N')
        plt.plot(N_values, e0_population[i], label=labels[i])
        plt.legend()
    plt.figure()
    for i in range(len(g1_population)):
        plt.ylabel('g-1 population')
        plt.xlabel('N')
        plt.plot(N_values, g1_population[i], label=labels[i])
        plt.legend()
    plt.show()
driving_convergence_N(1., 1./14., 30.)
driving_convergence_N(1., 1./2, 30.)

driving_convergence_N(1., 1., 0, overdamped=True)
driving_convergence_N(1., 1.5, 0, overdamped=True)
# Out:
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 3 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# Calculating non-RWA Liouvilliian took 0.040657043457 seconds.
# It took  0.0362038612366  seconds to build the Non-secular RWA Liouvillian
# It took  0.00285601615906  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 0.51347899437s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 4 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# Calculating non-RWA Liouvilliian took 0.0635089874268 seconds.
# It took  0.0618109703064  seconds to build the Non-secular RWA Liouvillian
# It took  0.00260376930237  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 0.204462051392s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 5 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# Calculating non-RWA Liouvilliian took 0.0857300758362 seconds.
# It took  0.0997200012207  seconds to build the Non-secular RWA Liouvillian
# It took  0.00255489349365  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 0.2963950634s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 6 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# Calculating non-RWA Liouvilliian took 0.142889022827 seconds.
# It took  0.11981511116  seconds to build the Non-secular RWA Liouvillian
# It took  0.00293278694153  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 0.375200033188s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 7 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# Calculating non-RWA Liouvilliian took 0.160638809204 seconds.
# It took  0.259742021561  seconds to build the Non-secular RWA Liouvillian
# It took  0.00599098205566  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 0.63613986969s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 8 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# Calculating non-RWA Liouvilliian took 0.198236942291 seconds.
# It took  0.211447000504  seconds to build the Non-secular RWA Liouvillian
# It took  0.00314116477966  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 0.751887083054s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 9 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# Calculating non-RWA Liouvilliian took 0.250082015991 seconds.
# It took  0.273459196091  seconds to build the Non-secular RWA Liouvillian
# It took  0.0027711391449  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 0.78126001358s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 10 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# Calculating non-RWA Liouvilliian took 0.309602022171 seconds.
# It took  0.360940217972  seconds to build the Non-secular RWA Liouvillian
# It took  0.0027220249176  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 0.965787887573s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 11 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# Calculating non-RWA Liouvilliian took 0.445198059082 seconds.
# It took  0.405275821686  seconds to build the Non-secular RWA Liouvillian
# It took  0.00264000892639  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 1.38825178146s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 12 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# Calculating non-RWA Liouvilliian took 0.476536989212 seconds.
# It took  0.531523942947  seconds to build the Non-secular RWA Liouvillian
# It took  0.00315499305725  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 1.76783490181s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 13 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# Calculating non-RWA Liouvilliian took 0.6000020504 seconds.
# It took  0.565626144409  seconds to build the Non-secular RWA Liouvillian
# It took  0.00275087356567  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 1.95628499985s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 14 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# Calculating non-RWA Liouvilliian took 0.627153873444 seconds.
# It took  0.641950130463  seconds to build the Non-secular RWA Liouvillian
# It took  0.00271415710449  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 1.8425579071s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 15 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# Calculating non-RWA Liouvilliian took 0.813266992569 seconds.
# It took  0.741511821747  seconds to build the Non-secular RWA Liouvillian
# It took  0.00276494026184  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.21481800079s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 16 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# Calculating non-RWA Liouvilliian took 0.934812068939 seconds.
# It took  0.989804983139  seconds to build the Non-secular RWA Liouvillian
# It took  0.00278401374817  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.74190282822s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 17 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# Calculating non-RWA Liouvilliian took 1.20445990562 seconds.
# It took  0.99506688118  seconds to build the Non-secular RWA Liouvillian
# It took  0.00282502174377  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 3.20264005661s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 18 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# Calculating non-RWA Liouvilliian took 1.18454217911 seconds.
# It took  1.0884449482  seconds to build the Non-secular RWA Liouvillian
# It took  0.00293779373169  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 3.66833686829s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 19 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# Calculating non-RWA Liouvilliian took 1.35571098328 seconds.
# It took  1.20800685883  seconds to build the Non-secular RWA Liouvillian
# It took  0.00292301177979  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 3.74380111694s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 20 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# Calculating non-RWA Liouvilliian took 1.91816401482 seconds.
# It took  1.34334993362  seconds to build the Non-secular RWA Liouvillian
# It took  0.0031418800354  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 4.58881497383s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 21 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# Calculating non-RWA Liouvilliian took 2.42994880676 seconds.
# It took  1.56791114807  seconds to build the Non-secular RWA Liouvillian
# It took  0.00360798835754  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 5.88995599747s**
# w_RC= 57.6107142857  TLS splitting = 806.55 RC-res. bath coupling= 0.0828777832727  N= 22 TLS-RC coupling= 270.163837294 Gamma_RC=  30.0
# Calculating non-RWA Liouvilliian took 2.20599079132 seconds.
# It took  1.90426492691  seconds to build the Non-secular RWA Liouvillian
# It took  0.00317001342773  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 6.24179911613s**
# /home/henry/anaconda2/envs/qutip/lib/python2.7/site-packages/numpy/core/numeric.py:531: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.0118396833247  N= 3 TLS-RC coupling= 714.786326724 Gamma_RC=  30.0
# Calculating non-RWA Liouvilliian took 0.0347309112549 seconds.
# It took  0.0346632003784  seconds to build the Non-secular RWA Liouvillian
# It took  0.00263094902039  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 0.1297352314s**
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.0118396833247  N= 4 TLS-RC coupling= 714.786326724 Gamma_RC=  30.0
# Calculating non-RWA Liouvilliian took 0.0626659393311 seconds.
# It took  0.0601110458374  seconds to build the Non-secular RWA Liouvillian
# It took  0.00260090827942  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 0.186096906662s**
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.0118396833247  N= 5 TLS-RC coupling= 714.786326724 Gamma_RC=  30.0
# Calculating non-RWA Liouvilliian took 0.0917639732361 seconds.
# It took  0.0878100395203  seconds to build the Non-secular RWA Liouvillian
# It took  0.00246810913086  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 0.265852928162s**
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.0118396833247  N= 6 TLS-RC coupling= 714.786326724 Gamma_RC=  30.0
# Calculating non-RWA Liouvilliian took 0.126933097839 seconds.
# It took  0.119215011597  seconds to build the Non-secular RWA Liouvillian
# It took  0.00243496894836  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 0.362097024918s**
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.0118396833247  N= 7 TLS-RC coupling= 714.786326724 Gamma_RC=  30.0
# Calculating non-RWA Liouvilliian took 0.157176017761 seconds.
# It took  0.160388946533  seconds to build the Non-secular RWA Liouvillian
# It took  0.00249099731445  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 0.475947856903s**
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.0118396833247  N= 8 TLS-RC coupling= 714.786326724 Gamma_RC=  30.0
# Calculating non-RWA Liouvilliian took 0.198466062546 seconds.
# It took  0.214148044586  seconds to build the Non-secular RWA Liouvillian
# It took  0.00269484519958  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 0.62012887001s**
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.0118396833247  N= 9 TLS-RC coupling= 714.786326724 Gamma_RC=  30.0
# Calculating non-RWA Liouvilliian took 0.293684959412 seconds.
# It took  0.276118993759  seconds to build the Non-secular RWA Liouvillian
# It took  0.00285220146179  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 0.881556987762s**
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.0118396833247  N= 10 TLS-RC coupling= 714.786326724 Gamma_RC=  30.0
# Calculating non-RWA Liouvilliian took 0.316555023193 seconds.
# It took  0.334657907486  seconds to build the Non-secular RWA Liouvillian
# It took  0.00264883041382  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 1.04897809029s**
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.0118396833247  N= 11 TLS-RC coupling= 714.786326724 Gamma_RC=  30.0
# Calculating non-RWA Liouvilliian took 0.375774145126 seconds.
# It took  0.405346870422  seconds to build the Non-secular RWA Liouvillian
# It took  0.00260400772095  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 1.20424199104s**
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.0118396833247  N= 12 TLS-RC coupling= 714.786326724 Gamma_RC=  30.0
# Calculating non-RWA Liouvilliian took 0.451912164688 seconds.
# It took  0.477761030197  seconds to build the Non-secular RWA Liouvillian
# It took  0.00270891189575  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 1.34787797928s**
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.0118396833247  N= 13 TLS-RC coupling= 714.786326724 Gamma_RC=  30.0
# Calculating non-RWA Liouvilliian took 0.539505958557 seconds.
# It took  0.578894853592  seconds to build the Non-secular RWA Liouvillian
# It took  0.00273895263672  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 1.6724319458s**
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.0118396833247  N= 14 TLS-RC coupling= 714.786326724 Gamma_RC=  30.0
# Calculating non-RWA Liouvilliian took 0.61701798439 seconds.
# It took  0.65336894989  seconds to build the Non-secular RWA Liouvillian
# It took  0.00270509719849  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 1.86146306992s**
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.0118396833247  N= 15 TLS-RC coupling= 714.786326724 Gamma_RC=  30.0
# Calculating non-RWA Liouvilliian took 0.734274864197 seconds.
# It took  0.735049962997  seconds to build the Non-secular RWA Liouvillian
# It took  0.00276684761047  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.15577411652s**
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.0118396833247  N= 16 TLS-RC coupling= 714.786326724 Gamma_RC=  30.0
# Calculating non-RWA Liouvilliian took 0.864175081253 seconds.
# It took  0.846265077591  seconds to build the Non-secular RWA Liouvillian
# It took  0.00279998779297  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.50554895401s**
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.0118396833247  N= 17 TLS-RC coupling= 714.786326724 Gamma_RC=  30.0
# Calculating non-RWA Liouvilliian took 0.980808019638 seconds.
# It took  0.978981971741  seconds to build the Non-secular RWA Liouvillian
# It took  0.00289797782898  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.85847711563s**
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.0118396833247  N= 18 TLS-RC coupling= 714.786326724 Gamma_RC=  30.0
# Calculating non-RWA Liouvilliian took 1.12079405785 seconds.
# It took  1.08904099464  seconds to build the Non-secular RWA Liouvillian
# It took  0.00295805931091  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 3.23971605301s**
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.0118396833247  N= 19 TLS-RC coupling= 714.786326724 Gamma_RC=  30.0
# Calculating non-RWA Liouvilliian took 1.28706097603 seconds.
# It took  1.20648598671  seconds to build the Non-secular RWA Liouvillian
# It took  0.00339579582214  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 3.69418001175s**
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.0118396833247  N= 20 TLS-RC coupling= 714.786326724 Gamma_RC=  30.0
# Calculating non-RWA Liouvilliian took 1.49927306175 seconds.
# It took  1.39919900894  seconds to build the Non-secular RWA Liouvillian
# It took  0.0030210018158  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 4.23697400093s**
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.0118396833247  N= 21 TLS-RC coupling= 714.786326724 Gamma_RC=  30.0
# Calculating non-RWA Liouvilliian took 2.37054681778 seconds.
# It took  1.8381819725  seconds to build the Non-secular RWA Liouvillian
# It took  0.00317406654358  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 5.93803310394s**
# w_RC= 403.275  TLS splitting = 806.55 RC-res. bath coupling= 0.0118396833247  N= 22 TLS-RC coupling= 714.786326724 Gamma_RC=  30.0
# Calculating non-RWA Liouvilliian took 1.84239792824 seconds.
# It took  1.60725307465  seconds to build the Non-secular RWA Liouvillian
# It took  0.00315594673157  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 5.36414694786s**
# w_RC= 806.55  TLS splitting = 806.55 RC-res. bath coupling= 2.46858498751  N= 3 TLS-RC coupling= 1010.86051745 Gamma_RC=  12510.0558173
# Calculating non-RWA Liouvilliian took 0.0337588787079 seconds.
# It took  0.0336120128632  seconds to build the Non-secular RWA Liouvillian
# It took  0.0028338432312  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 0.130930185318s**
# w_RC= 806.55  TLS splitting = 806.55 RC-res. bath coupling= 2.46858498751  N= 4 TLS-RC coupling= 1010.86051745 Gamma_RC=  12510.0558173
# Calculating non-RWA Liouvilliian took 0.0672750473022 seconds.
# It took  0.0597500801086  seconds to build the Non-secular RWA Liouvillian
# It took  0.0026068687439  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 0.19011092186s**
# w_RC= 806.55  TLS splitting = 806.55 RC-res. bath coupling= 2.46858498751  N= 5 TLS-RC coupling= 1010.86051745 Gamma_RC=  12510.0558173
# Calculating non-RWA Liouvilliian took 0.0898430347443 seconds.
# It took  0.0896410942078  seconds to build the Non-secular RWA Liouvillian
# It took  0.00249099731445  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 0.265928983688s**
# w_RC= 806.55  TLS splitting = 806.55 RC-res. bath coupling= 2.46858498751  N= 6 TLS-RC coupling= 1010.86051745 Gamma_RC=  12510.0558173
# Calculating non-RWA Liouvilliian took 0.127315998077 seconds.
# It took  0.120537996292  seconds to build the Non-secular RWA Liouvillian
# It took  0.00250315666199  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 0.365109920502s**
# w_RC= 806.55  TLS splitting = 806.55 RC-res. bath coupling= 2.46858498751  N= 7 TLS-RC coupling= 1010.86051745 Gamma_RC=  12510.0558173
# Calculating non-RWA Liouvilliian took 0.15761590004 seconds.
# It took  0.162187099457  seconds to build the Non-secular RWA Liouvillian
# It took  0.00246810913086  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 0.476190090179s**
# w_RC= 806.55  TLS splitting = 806.55 RC-res. bath coupling= 2.46858498751  N= 8 TLS-RC coupling= 1010.86051745 Gamma_RC=  12510.0558173
# Calculating non-RWA Liouvilliian took 0.198548078537 seconds.
# It took  0.213188886642  seconds to build the Non-secular RWA Liouvillian
# It took  0.00273084640503  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 0.613451004028s**
# w_RC= 806.55  TLS splitting = 806.55 RC-res. bath coupling= 2.46858498751  N= 9 TLS-RC coupling= 1010.86051745 Gamma_RC=  12510.0558173
# Calculating non-RWA Liouvilliian took 0.250633001328 seconds.
# It took  0.275466918945  seconds to build the Non-secular RWA Liouvillian
# It took  0.00259900093079  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 0.769347190857s**
# w_RC= 806.55  TLS splitting = 806.55 RC-res. bath coupling= 2.46858498751  N= 10 TLS-RC coupling= 1010.86051745 Gamma_RC=  12510.0558173
# Calculating non-RWA Liouvilliian took 0.309268951416 seconds.
# It took  0.336184978485  seconds to build the Non-secular RWA Liouvillian
# It took  0.00259685516357  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 0.93799495697s**
# w_RC= 806.55  TLS splitting = 806.55 RC-res. bath coupling= 2.46858498751  N= 11 TLS-RC coupling= 1010.86051745 Gamma_RC=  12510.0558173
# Calculating non-RWA Liouvilliian took 0.392770051956 seconds.
# It took  0.406713008881  seconds to build the Non-secular RWA Liouvillian
# It took  0.00257897377014  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 1.1576359272s**
# w_RC= 806.55  TLS splitting = 806.55 RC-res. bath coupling= 2.46858498751  N= 12 TLS-RC coupling= 1010.86051745 Gamma_RC=  12510.0558173
# Calculating non-RWA Liouvilliian took 0.44629406929 seconds.
# It took  0.484894037247  seconds to build the Non-secular RWA Liouvillian
# It took  0.00264883041382  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 1.34332203865s**
# w_RC= 806.55  TLS splitting = 806.55 RC-res. bath coupling= 2.46858498751  N= 13 TLS-RC coupling= 1010.86051745 Gamma_RC=  12510.0558173
# Calculating non-RWA Liouvilliian took 0.559285879135 seconds.
# It took  0.698721885681  seconds to build the Non-secular RWA Liouvillian
# It took  0.00384187698364  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 1.96846294403s**
# w_RC= 806.55  TLS splitting = 806.55 RC-res. bath coupling= 2.46858498751  N= 14 TLS-RC coupling= 1010.86051745 Gamma_RC=  12510.0558173
# Calculating non-RWA Liouvilliian took 0.618647098541 seconds.
# It took  0.648134946823  seconds to build the Non-secular RWA Liouvillian
# It took  0.00271487236023  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.0411901474s**
# w_RC= 806.55  TLS splitting = 806.55 RC-res. bath coupling= 2.46858498751  N= 15 TLS-RC coupling= 1010.86051745 Gamma_RC=  12510.0558173
# Calculating non-RWA Liouvilliian took 0.719352006912 seconds.
# It took  0.73156619072  seconds to build the Non-secular RWA Liouvillian
# It took  0.00275707244873  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.12091994286s**
# w_RC= 806.55  TLS splitting = 806.55 RC-res. bath coupling= 2.46858498751  N= 16 TLS-RC coupling= 1010.86051745 Gamma_RC=  12510.0558173
# Calculating non-RWA Liouvilliian took 0.838593959808 seconds.
# It took  1.04710102081  seconds to build the Non-secular RWA Liouvillian
# It took  0.00281620025635  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.6499710083s**
# w_RC= 806.55  TLS splitting = 806.55 RC-res. bath coupling= 2.46858498751  N= 17 TLS-RC coupling= 1010.86051745 Gamma_RC=  12510.0558173
# Calculating non-RWA Liouvilliian took 0.97889995575 seconds.
# It took  0.956383943558  seconds to build the Non-secular RWA Liouvillian
# It took  0.00294494628906  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 3.04989886284s**
# w_RC= 806.55  TLS splitting = 806.55 RC-res. bath coupling= 2.46858498751  N= 18 TLS-RC coupling= 1010.86051745 Gamma_RC=  12510.0558173
# Calculating non-RWA Liouvilliian took 1.76197099686 seconds.
# It took  1.23380899429  seconds to build the Non-secular RWA Liouvillian
# It took  0.00280690193176  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 4.33588886261s**
# w_RC= 806.55  TLS splitting = 806.55 RC-res. bath coupling= 2.46858498751  N= 19 TLS-RC coupling= 1010.86051745 Gamma_RC=  12510.0558173
# Calculating non-RWA Liouvilliian took 1.28255820274 seconds.
# It took  1.21707701683  seconds to build the Non-secular RWA Liouvillian
# It took  0.00298500061035  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 3.66723513603s**
# w_RC= 806.55  TLS splitting = 806.55 RC-res. bath coupling= 2.46858498751  N= 20 TLS-RC coupling= 1010.86051745 Gamma_RC=  12510.0558173
# Calculating non-RWA Liouvilliian took 1.4531621933 seconds.
# It took  1.33278298378  seconds to build the Non-secular RWA Liouvillian
# It took  0.00303196907043  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 4.10209393501s**
# w_RC= 806.55  TLS splitting = 806.55 RC-res. bath coupling= 2.46858498751  N= 21 TLS-RC coupling= 1010.86051745 Gamma_RC=  12510.0558173
# Calculating non-RWA Liouvilliian took 1.60994315147 seconds.
# It took  1.48092007637  seconds to build the Non-secular RWA Liouvillian
# It took  0.00313401222229  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 4.60757899284s**
# w_RC= 806.55  TLS splitting = 806.55 RC-res. bath coupling= 2.46858498751  N= 22 TLS-RC coupling= 1010.86051745 Gamma_RC=  12510.0558173
# Calculating non-RWA Liouvilliian took 2.00190401077 seconds.
# It took  2.20703005791  seconds to build the Non-secular RWA Liouvillian
# It took  0.00682616233826  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 5.91637086868s**
# w_RC= 1209.825  TLS splitting = 806.55 RC-res. bath coupling= 3.70287748127  N= 3 TLS-RC coupling= 1238.04623444 Gamma_RC=  28147.6255889
# Calculating non-RWA Liouvilliian took 0.0328030586243 seconds.
# It took  0.0350630283356  seconds to build the Non-secular RWA Liouvillian
# It took  0.00287818908691  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 0.146421194077s**
# w_RC= 1209.825  TLS splitting = 806.55 RC-res. bath coupling= 3.70287748127  N= 4 TLS-RC coupling= 1238.04623444 Gamma_RC=  28147.6255889
# Calculating non-RWA Liouvilliian took 0.152453899384 seconds.
# It took  0.117812156677  seconds to build the Non-secular RWA Liouvillian
# It took  0.00275778770447  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 0.394540071487s**
# w_RC= 1209.825  TLS splitting = 806.55 RC-res. bath coupling= 3.70287748127  N= 5 TLS-RC coupling= 1238.04623444 Gamma_RC=  28147.6255889
# Calculating non-RWA Liouvilliian took 0.130765914917 seconds.
# It took  0.268122911453  seconds to build the Non-secular RWA Liouvillian
# It took  0.00572419166565  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 0.529922008514s**
# w_RC= 1209.825  TLS splitting = 806.55 RC-res. bath coupling= 3.70287748127  N= 6 TLS-RC coupling= 1238.04623444 Gamma_RC=  28147.6255889
# Calculating non-RWA Liouvilliian took 0.161873102188 seconds.
# It took  0.272202014923  seconds to build the Non-secular RWA Liouvillian
# It took  0.00338411331177  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 0.679917097092s**
# w_RC= 1209.825  TLS splitting = 806.55 RC-res. bath coupling= 3.70287748127  N= 7 TLS-RC coupling= 1238.04623444 Gamma_RC=  28147.6255889
# Calculating non-RWA Liouvilliian took 0.19173002243 seconds.
# It took  0.300528049469  seconds to build the Non-secular RWA Liouvillian
# It took  0.00368905067444  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 0.673709154129s**
# w_RC= 1209.825  TLS splitting = 806.55 RC-res. bath coupling= 3.70287748127  N= 8 TLS-RC coupling= 1238.04623444 Gamma_RC=  28147.6255889
# Calculating non-RWA Liouvilliian took 0.270493030548 seconds.
# It took  0.218837022781  seconds to build the Non-secular RWA Liouvillian
# It took  0.00256395339966  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 0.829370975494s**
# w_RC= 1209.825  TLS splitting = 806.55 RC-res. bath coupling= 3.70287748127  N= 9 TLS-RC coupling= 1238.04623444 Gamma_RC=  28147.6255889
# Calculating non-RWA Liouvilliian took 0.251869916916 seconds.
# It took  0.313700914383  seconds to build the Non-secular RWA Liouvillian
# It took  0.00326204299927  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 0.823834180832s**
# w_RC= 1209.825  TLS splitting = 806.55 RC-res. bath coupling= 3.70287748127  N= 10 TLS-RC coupling= 1238.04623444 Gamma_RC=  28147.6255889
# Calculating non-RWA Liouvilliian took 0.331427812576 seconds.
# It took  0.370048999786  seconds to build the Non-secular RWA Liouvillian
# It took  0.00262999534607  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 1.02016305923s**
# w_RC= 1209.825  TLS splitting = 806.55 RC-res. bath coupling= 3.70287748127  N= 11 TLS-RC coupling= 1238.04623444 Gamma_RC=  28147.6255889
# Calculating non-RWA Liouvilliian took 0.465440988541 seconds.
# It took  0.439963102341  seconds to build the Non-secular RWA Liouvillian
# It took  0.00259208679199  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 1.34342598915s**
# w_RC= 1209.825  TLS splitting = 806.55 RC-res. bath coupling= 3.70287748127  N= 12 TLS-RC coupling= 1238.04623444 Gamma_RC=  28147.6255889
# Calculating non-RWA Liouvilliian took 0.650150060654 seconds.
# It took  0.478101015091  seconds to build the Non-secular RWA Liouvillian
# It took  0.00266408920288  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 1.58304905891s**
# w_RC= 1209.825  TLS splitting = 806.55 RC-res. bath coupling= 3.70287748127  N= 13 TLS-RC coupling= 1238.04623444 Gamma_RC=  28147.6255889
# Calculating non-RWA Liouvilliian took 0.52792096138 seconds.
# It took  0.574163913727  seconds to build the Non-secular RWA Liouvillian
# It took  0.00277590751648  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 1.68995308876s**
# w_RC= 1209.825  TLS splitting = 806.55 RC-res. bath coupling= 3.70287748127  N= 14 TLS-RC coupling= 1238.04623444 Gamma_RC=  28147.6255889
# Calculating non-RWA Liouvilliian took 0.61353302002 seconds.
# It took  0.655213117599  seconds to build the Non-secular RWA Liouvillian
# It took  0.00269484519958  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 1.83971714973s**
# w_RC= 1209.825  TLS splitting = 806.55 RC-res. bath coupling= 3.70287748127  N= 15 TLS-RC coupling= 1238.04623444 Gamma_RC=  28147.6255889
# Calculating non-RWA Liouvilliian took 0.710923194885 seconds.
# It took  0.920203208923  seconds to build the Non-secular RWA Liouvillian
# It took  0.00536799430847  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.48102998734s**
# w_RC= 1209.825  TLS splitting = 806.55 RC-res. bath coupling= 3.70287748127  N= 16 TLS-RC coupling= 1238.04623444 Gamma_RC=  28147.6255889
# Calculating non-RWA Liouvilliian took 0.838047027588 seconds.
# It took  1.21308684349  seconds to build the Non-secular RWA Liouvillian
# It took  0.00310111045837  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 3.10472393036s**
# w_RC= 1209.825  TLS splitting = 806.55 RC-res. bath coupling= 3.70287748127  N= 17 TLS-RC coupling= 1238.04623444 Gamma_RC=  28147.6255889
# Calculating non-RWA Liouvilliian took 0.978070020676 seconds.
# It took  0.973962068558  seconds to build the Non-secular RWA Liouvillian
# It took  0.00280785560608  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.99490404129s**
# w_RC= 1209.825  TLS splitting = 806.55 RC-res. bath coupling= 3.70287748127  N= 18 TLS-RC coupling= 1238.04623444 Gamma_RC=  28147.6255889
# Calculating non-RWA Liouvilliian took 1.11593079567 seconds.
# It took  1.08263492584  seconds to build the Non-secular RWA Liouvillian
# It took  0.00316309928894  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 3.25024390221s**
# w_RC= 1209.825  TLS splitting = 806.55 RC-res. bath coupling= 3.70287748127  N= 19 TLS-RC coupling= 1238.04623444 Gamma_RC=  28147.6255889
# Calculating non-RWA Liouvilliian took 2.01389217377 seconds.
# It took  1.44810199738  seconds to build the Non-secular RWA Liouvillian
# It took  0.00305509567261  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 4.69496202469s**
# w_RC= 1209.825  TLS splitting = 806.55 RC-res. bath coupling= 3.70287748127  N= 20 TLS-RC coupling= 1238.04623444 Gamma_RC=  28147.6255889
# Calculating non-RWA Liouvilliian took 1.4402089119 seconds.
# It took  1.50378704071  seconds to build the Non-secular RWA Liouvillian
# It took  0.0033700466156  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 4.25120806694s**
# w_RC= 1209.825  TLS splitting = 806.55 RC-res. bath coupling= 3.70287748127  N= 21 TLS-RC coupling= 1238.04623444 Gamma_RC=  28147.6255889
# Calculating non-RWA Liouvilliian took 2.02398276329 seconds.
# It took  1.6479640007  seconds to build the Non-secular RWA Liouvillian
# It took  0.00313282012939  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 5.39693188667s**
# w_RC= 1209.825  TLS splitting = 806.55 RC-res. bath coupling= 3.70287748127  N= 22 TLS-RC coupling= 1238.04623444 Gamma_RC=  28147.6255889
# Calculating non-RWA Liouvilliian took 2.20981693268 seconds.
# It took  1.83438682556  seconds to build the Non-secular RWA Liouvillian
# It took  0.00324296951294  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 6.13804292679s**

# %% [markdown]
# Check convergence of decay rates with w0. With $\omega_0>\epsilon$ we hope to see the decay rates converge.

# %%
from qutip import vector_to_operator, operator_to_vector, basis


def decay_rate_wRC_dependence(eps, T_ph, alpha_ph, Gamma, T_EM=0., overdamped=True, nvib=3):
    omega_0_props = np.linspace(0.001, 6., 50)
    omega_0 = omega_0_props*eps
    #displacements = alpha_ph/w0
    N = 25
    
    decay_wrt_wRC = [[],[],[],[]]
    labels = ['g-0',  'g-1', 'g-2','g-3', 'g-4', 'g-5']
    count = 1
    for w0 in omega_0:
        if overdamped:
            Gamma = w0**2/wc
        else:
            Gamma = 60.
        print count 
        count+=1
        if w0 > eps*0.7:
            N = 14
        L_RC, H, A_EM, A_nrwa, wRC, kappa, Gamma_1 = RC.RC_function_UD(
                                            sigma, eps, T_ph, Gamma, w0, alpha_ph, N)
        
    # given some Liouvillian, find the instantaneous decay rates
    # from e-0 to the ground manifold eigenstates, for several
    # oscillator displacements
    # - need to find the first eigenstate in the excited manifold
        evals, states = eigstate_calc_and_mag_sort(H, sort=False)
        ground_list = []
        excited_list = []
        for i in range(len(evals)):
            is_ground = sum(states[i])[0][0].real == 1.
            if is_ground:
                ground_list.append(i)
            else:
                excited_list.append(i)
        excited_ket = states[excited_list[0]]
        
        #initial_ket = tensor(basis(2,1), basis(N,0))
        excited_rho = excited_ket*excited_ket.dag()
        
        L= [EM.L_non_rwa(H, A_nrwa, eps, Gamma_EM, T_EM, J=J_EM), 
            EM.L_nonsecular(H, A_EM, eps, Gamma_EM, T_EM, J=J_EM),
            EM.L_vib_lindblad(H, A_EM, eps, Gamma_EM, T_EM, J=J_EM),
            EM.L_EM_lindblad(eps, A_EM, Gamma_EM, T_EM, J=J_EM)]
        for i_, L_EM in enumerate(L):
            decay_rates = [] # not really decay rates but population at short times
            for j in range(nvib):
                ground_ket = tensor(basis(2,0), basis(N,j))
                #print states[ground_list][j].dag()*target_ket
                #target_rho = operator_to_vector(target_ket*target_ket.dag())
                L_rho0_prod = vector_to_operator(L_EM*operator_to_vector(excited_ket*excited_ket.dag()))
                rate = L_rho0_prod.matrix_element(ground_ket.dag(), ground_ket)
                decay_rates.append(rate)
                
            if len(decay_rates)!=nvib:
                print ground_list
            decay_wrt_wRC[i_].append(decay_rates)
    for level in range(nvib): 
        plt.figure()
        plt.title(labels[level])
        plt.plot(omega_0_props, np.array(decay_wrt_wRC[0]).T[level], label='non-RWA')
        plt.plot(omega_0_props, np.array(decay_wrt_wRC[1]).T[level], label='non-sec', linestyle='dashed')
        plt.plot(omega_0_props, np.array(decay_wrt_wRC[2]).T[level], label='sec', linestyle='dotted')
        plt.plot(omega_0_props, np.array(decay_wrt_wRC[3]).T[level], label='naive')
        plt.legend()
        plt.xlabel(r'Oscillator Frequency (units of $\epsilon$)')
        plt.ylabel('Rate to {}'.format(labels[level]))
    plt.show()
    return displacements, decay_wrt_wRC
    #for i, alpha in enumerate(alpha_ph):
    #    plt.plot(decay_wrt_alpha[i])

displacements, decay_wrt_wRC = decay_rate_wRC_dependence(eps, 300., eps*0.15, 60., overdamped=True, nvib=4)
#decay_rate_plotter(H_RC, L_ns)
#decay_rate_plotter(H_RC, L_n)
# Out:
# 1
# w_RC= 0.80655  TLS splitting = 806.55 RC-res. bath coupling= 0.00242200791228  N= 25 TLS-RC coupling= 12.3804623444 Gamma_RC=  0.0122740170283
# Calculating non-RWA Liouvilliian took 1.45716309547 seconds.
# It took  2.10884618759  seconds to build the Non-secular RWA Liouvillian
# It took  8.82116985321  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00303602218628  seconds to build the electronic-Lindblad Liouvillian
# 2
# w_RC= 99.5513142857  TLS splitting = 806.55 RC-res. bath coupling= 0.298944976601  N= 25 TLS-RC coupling= 137.544970595 Gamma_RC=  186.989890113
# Calculating non-RWA Liouvilliian took 1.45087599754 seconds.
# It took  1.9577331543  seconds to build the Non-secular RWA Liouvillian
# It took  6.46495509148  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00312995910645  seconds to build the electronic-Lindblad Liouvillian
# 3
# w_RC= 198.296078571  TLS splitting = 806.55 RC-res. bath coupling= 0.59546794529  N= 25 TLS-RC coupling= 194.123574107 Gamma_RC=  741.911976921
# Calculating non-RWA Liouvilliian took 1.55063915253 seconds.
# It took  3.52631282806  seconds to build the Non-secular RWA Liouvillian
# It took  6.6742401123  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00306105613708  seconds to build the electronic-Lindblad Liouvillian
# 4
# w_RC= 297.040842857  TLS splitting = 806.55 RC-res. bath coupling= 0.891990913979  N= 25 TLS-RC coupling= 237.590625052 Gamma_RC=  1664.77853444
# Calculating non-RWA Liouvilliian took 1.44522094727 seconds.
# It took  1.95064997673  seconds to build the Non-secular RWA Liouvillian
# It took  5.98975682259  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00312113761902  seconds to build the electronic-Lindblad Liouvillian
# 5
# w_RC= 395.785607143  TLS splitting = 806.55 RC-res. bath coupling= 1.18851388267  N= 25 TLS-RC coupling= 274.252890961 Gamma_RC=  2955.58956267
# Calculating non-RWA Liouvilliian took 1.44813895226 seconds.
# It took  1.93244504929  seconds to build the Non-secular RWA Liouvillian
# It took  5.81332111359  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00302314758301  seconds to build the electronic-Lindblad Liouvillian
# 6
# w_RC= 494.530371429  TLS splitting = 806.55 RC-res. bath coupling= 1.48503685136  N= 25 TLS-RC coupling= 306.561561988 Gamma_RC=  4614.34506161
# Calculating non-RWA Liouvilliian took 1.44596409798 seconds.
# It took  1.9533200264  seconds to build the Non-secular RWA Liouvillian
# It took  5.68500614166  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00304818153381  seconds to build the electronic-Lindblad Liouvillian
# 7
# w_RC= 593.275135714  TLS splitting = 806.55 RC-res. bath coupling= 1.78155982005  N= 14 TLS-RC coupling= 335.775720351 Gamma_RC=  6641.04503126
# Calculating non-RWA Liouvilliian took 0.447363138199 seconds.
# It took  0.622988939285  seconds to build the Non-secular RWA Liouvillian
# It took  0.848112106323  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00271701812744  seconds to build the electronic-Lindblad Liouvillian
# 8
# w_RC= 692.0199  TLS splitting = 806.55 RC-res. bath coupling= 2.07808278874  N= 14 TLS-RC coupling= 362.644009278 Gamma_RC=  9035.68947162
# Calculating non-RWA Liouvilliian took 0.441103935242 seconds.
# It took  0.617035865784  seconds to build the Non-secular RWA Liouvillian
# It took  0.843382835388  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00262594223022  seconds to build the electronic-Lindblad Liouvillian
# 9
# w_RC= 790.764664286  TLS splitting = 806.55 RC-res. bath coupling= 2.37460575742  N= 14 TLS-RC coupling= 387.654511844 Gamma_RC=  11798.2783827
# Calculating non-RWA Liouvilliian took 0.440254926682 seconds.
# It took  0.611202001572  seconds to build the Non-secular RWA Liouvillian
# It took  0.841092824936  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00259613990784  seconds to build the electronic-Lindblad Liouvillian
# 10
# w_RC= 889.509428571  TLS splitting = 806.55 RC-res. bath coupling= 2.67112872611  N= 14 TLS-RC coupling= 411.146401713 Gamma_RC=  14928.8117645
# Calculating non-RWA Liouvilliian took 0.440588951111 seconds.
# It took  0.616883993149  seconds to build the Non-secular RWA Liouvillian
# It took  0.840356111526  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00261807441711  seconds to build the electronic-Lindblad Liouvillian
# 11
# w_RC= 988.254192857  TLS splitting = 806.55 RC-res. bath coupling= 2.9676516948  N= 14 TLS-RC coupling= 433.366711608 Gamma_RC=  18427.289617
# Calculating non-RWA Liouvilliian took 0.441005945206 seconds.
# It took  0.618152141571  seconds to build the Non-secular RWA Liouvillian
# It took  0.842931985855  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00281405448914  seconds to build the electronic-Lindblad Liouvillian
# 12
# w_RC= 1086.99895714  TLS splitting = 806.55 RC-res. bath coupling= 3.26417466349  N= 14 TLS-RC coupling= 454.501979993 Gamma_RC=  22293.7119402
# Calculating non-RWA Liouvilliian took 0.440805912018 seconds.
# It took  0.616589069366  seconds to build the Non-secular RWA Liouvillian
# It took  0.842691898346  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00266408920288  seconds to build the electronic-Lindblad Liouvillian
# 13
# w_RC= 1185.74372143  TLS splitting = 806.55 RC-res. bath coupling= 3.56069763218  N= 14 TLS-RC coupling= 474.697159151 Gamma_RC=  26528.0787341
# Calculating non-RWA Liouvilliian took 0.442641019821 seconds.
# It took  0.617378950119  seconds to build the Non-secular RWA Liouvillian
# It took  0.96172618866  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00342798233032  seconds to build the electronic-Lindblad Liouvillian
# 14
# w_RC= 1284.48848571  TLS splitting = 806.55 RC-res. bath coupling= 3.85722060087  N= 14 TLS-RC coupling= 494.067541936 Gamma_RC=  31130.3899987
# Calculating non-RWA Liouvilliian took 0.444444894791 seconds.
# It took  0.617646932602  seconds to build the Non-secular RWA Liouvillian
# It took  0.925783872604  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00262594223022  seconds to build the electronic-Lindblad Liouvillian
# 15
# w_RC= 1383.23325  TLS splitting = 806.55 RC-res. bath coupling= 4.15374356956  N= 14 TLS-RC coupling= 512.706620868 Gamma_RC=  36100.6457341
# Calculating non-RWA Liouvilliian took 0.44237613678 seconds.
# It took  0.616768121719  seconds to build the Non-secular RWA Liouvillian
# It took  0.83357000351  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00266313552856  seconds to build the electronic-Lindblad Liouvillian
# 16
# w_RC= 1481.97801429  TLS splitting = 806.55 RC-res. bath coupling= 4.45026653825  N= 14 TLS-RC coupling= 530.691456659 Gamma_RC=  41438.8459401
# Calculating non-RWA Liouvilliian took 0.449694156647 seconds.
# It took  0.615097999573  seconds to build the Non-secular RWA Liouvillian
# It took  0.869127035141  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00258708000183  seconds to build the electronic-Lindblad Liouvillian
# 17
# w_RC= 1580.72277857  TLS splitting = 806.55 RC-res. bath coupling= 4.74678950694  N= 14 TLS-RC coupling= 548.086457832 Gamma_RC=  47144.9906169
# Calculating non-RWA Liouvilliian took 0.531448841095 seconds.
# It took  0.634321928024  seconds to build the Non-secular RWA Liouvillian
# It took  0.924477100372  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00265383720398  seconds to build the electronic-Lindblad Liouvillian
# 18
# w_RC= 1679.46754286  TLS splitting = 806.55 RC-res. bath coupling= 5.04331247562  N= 14 TLS-RC coupling= 564.946111011 Gamma_RC=  53219.0797644
# Calculating non-RWA Liouvilliian took 0.446463108063 seconds.
# It took  0.616812944412  seconds to build the Non-secular RWA Liouvillian
# It took  0.837890148163  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00257921218872  seconds to build the electronic-Lindblad Liouvillian
# 19
# w_RC= 1778.21230714  TLS splitting = 806.55 RC-res. bath coupling= 5.33983544431  N= 14 TLS-RC coupling= 581.316997373 Gamma_RC=  59661.1133825
# Calculating non-RWA Liouvilliian took 0.445261955261 seconds.
# It took  0.611173868179  seconds to build the Non-secular RWA Liouvillian
# It took  0.832061052322  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00257301330566  seconds to build the electronic-Lindblad Liouvillian
# 20
# w_RC= 1876.95707143  TLS splitting = 806.55 RC-res. bath coupling= 5.636358413  N= 14 TLS-RC coupling= 597.239310933 Gamma_RC=  66471.0914714
# Calculating non-RWA Liouvilliian took 0.440113067627 seconds.
# It took  0.640366077423  seconds to build the Non-secular RWA Liouvillian
# It took  1.04312992096  seconds to build the vibronic Lindblad Liouvillian
# It took  0.0026388168335  seconds to build the electronic-Lindblad Liouvillian
# 21
# w_RC= 1975.70183571  TLS splitting = 806.55 RC-res. bath coupling= 5.93288138169  N= 14 TLS-RC coupling= 612.748021304 Gamma_RC=  73649.014031
# Calculating non-RWA Liouvilliian took 0.53672504425 seconds.
# It took  0.687577009201  seconds to build the Non-secular RWA Liouvillian
# It took  0.841938018799  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00273489952087  seconds to build the electronic-Lindblad Liouvillian
# 22
# w_RC= 2074.4466  TLS splitting = 806.55 RC-res. bath coupling= 6.22940435038  N= 14 TLS-RC coupling= 627.873777681 Gamma_RC=  81194.8810614
# Calculating non-RWA Liouvilliian took 0.500096082687 seconds.
# It took  0.682786941528  seconds to build the Non-secular RWA Liouvillian
# It took  0.967047929764  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00274682044983  seconds to build the electronic-Lindblad Liouvillian
# 23
# w_RC= 2173.19136429  TLS splitting = 806.55 RC-res. bath coupling= 6.52592731907  N= 14 TLS-RC coupling= 642.643621137 Gamma_RC=  89108.6925624
# Calculating non-RWA Liouvilliian took 0.525693178177 seconds.
# It took  0.639909029007  seconds to build the Non-secular RWA Liouvillian
# It took  0.837966918945  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00263285636902  seconds to build the electronic-Lindblad Liouvillian
# 24
# w_RC= 2271.93612857  TLS splitting = 806.55 RC-res. bath coupling= 6.82245028776  N= 14 TLS-RC coupling= 657.081552683 Gamma_RC=  97390.4485341
# Calculating non-RWA Liouvilliian took 0.443382024765 seconds.
# It took  0.621220111847  seconds to build the Non-secular RWA Liouvillian
# It took  0.834388971329  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00295090675354  seconds to build the electronic-Lindblad Liouvillian
# 25
# w_RC= 2370.68089286  TLS splitting = 806.55 RC-res. bath coupling= 7.11897325645  N= 14 TLS-RC coupling= 671.208991272 Gamma_RC=  106040.148977
# Calculating non-RWA Liouvilliian took 0.448472976685 seconds.
# It took  0.623089790344  seconds to build the Non-secular RWA Liouvillian
# It took  0.833316802979  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00269794464111  seconds to build the electronic-Lindblad Liouvillian
# 26
# w_RC= 2469.42565714  TLS splitting = 806.55 RC-res. bath coupling= 7.41549622514  N= 14 TLS-RC coupling= 685.045146726 Gamma_RC=  115057.79389
# Calculating non-RWA Liouvilliian took 0.44849395752 seconds.
# It took  0.621350049973  seconds to build the Non-secular RWA Liouvillian
# It took  0.828925132751  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00265598297119  seconds to build the electronic-Lindblad Liouvillian
# 27
# w_RC= 2568.17042143  TLS splitting = 806.55 RC-res. bath coupling= 7.71201919383  N= 14 TLS-RC coupling= 698.607326143 Gamma_RC=  124443.383274
# Calculating non-RWA Liouvilliian took 0.445024967194 seconds.
# It took  0.62156701088  seconds to build the Non-secular RWA Liouvillian
# It took  0.83593583107  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00266790390015  seconds to build the electronic-Lindblad Liouvillian
# 28
# w_RC= 2666.91518571  TLS splitting = 806.55 RC-res. bath coupling= 8.00854216251  N= 14 TLS-RC coupling= 711.91118774 Gamma_RC=  134196.917128
# Calculating non-RWA Liouvilliian took 0.448266983032 seconds.
# It took  0.610632896423  seconds to build the Non-secular RWA Liouvillian
# It took  0.830492019653  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00270390510559  seconds to build the electronic-Lindblad Liouvillian
# 29
# w_RC= 2765.65995  TLS splitting = 806.55 RC-res. bath coupling= 8.3050651312  N= 14 TLS-RC coupling= 724.97095274 Gamma_RC=  144318.395453
# Calculating non-RWA Liouvilliian took 0.443616867065 seconds.
# It took  0.626705884933  seconds to build the Non-secular RWA Liouvillian
# It took  0.835955858231  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00275707244873  seconds to build the electronic-Lindblad Liouvillian
# 30
# w_RC= 2864.40471429  TLS splitting = 806.55 RC-res. bath coupling= 8.60158809989  N= 14 TLS-RC coupling= 737.799583495 Gamma_RC=  154807.818249
# Calculating non-RWA Liouvilliian took 0.449986934662 seconds.
# It took  0.620885848999  seconds to build the Non-secular RWA Liouvillian
# It took  0.831130027771  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00265216827393  seconds to build the electronic-Lindblad Liouvillian
# 31
# w_RC= 2963.14947857  TLS splitting = 806.55 RC-res. bath coupling= 8.89811106858  N= 14 TLS-RC coupling= 750.408934177 Gamma_RC=  165665.185516
# Calculating non-RWA Liouvilliian took 0.451738119125 seconds.
# It took  0.623495101929  seconds to build the Non-secular RWA Liouvillian
# It took  0.822026968002  seconds to build the vibronic Lindblad Liouvillian
# It took  0.0026969909668  seconds to build the electronic-Lindblad Liouvillian
# 32
# w_RC= 3061.89424286  TLS splitting = 806.55 RC-res. bath coupling= 9.19463403727  N= 14 TLS-RC coupling= 762.809879053 Gamma_RC=  176890.497254
# Calculating non-RWA Liouvilliian took 0.443992853165 seconds.
# It took  0.622140884399  seconds to build the Non-secular RWA Liouvillian
# It took  0.826164960861  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00264501571655  seconds to build the electronic-Lindblad Liouvillian
# 33
# w_RC= 3160.63900714  TLS splitting = 806.55 RC-res. bath coupling= 9.49115700596  N= 14 TLS-RC coupling= 775.012422268 Gamma_RC=  188483.753462
# Calculating non-RWA Liouvilliian took 0.450492858887 seconds.
# It took  0.614664793015  seconds to build the Non-secular RWA Liouvillian
# It took  0.822416782379  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00265908241272  seconds to build the electronic-Lindblad Liouvillian
# 34
# w_RC= 3259.38377143  TLS splitting = 806.55 RC-res. bath coupling= 9.78767997465  N= 14 TLS-RC coupling= 787.025792308 Gamma_RC=  200444.954141
# Calculating non-RWA Liouvilliian took 0.443863868713 seconds.
# It took  0.623259067535  seconds to build the Non-secular RWA Liouvillian
# It took  0.83135509491  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00269603729248  seconds to build the electronic-Lindblad Liouvillian
# 35
# w_RC= 3358.12853571  TLS splitting = 806.55 RC-res. bath coupling= 10.0842029433  N= 14 TLS-RC coupling= 798.858523674 Gamma_RC=  212774.09929
# Calculating non-RWA Liouvilliian took 0.448713064194 seconds.
# It took  0.621852874756  seconds to build the Non-secular RWA Liouvillian
# It took  0.825922012329  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00262403488159  seconds to build the electronic-Lindblad Liouvillian
# 36
# w_RC= 3456.8733  TLS splitting = 806.55 RC-res. bath coupling= 10.380725912  N= 14 TLS-RC coupling= 810.518527817 Gamma_RC=  225471.18891
# Calculating non-RWA Liouvilliian took 0.444065093994 seconds.
# It took  0.616816997528  seconds to build the Non-secular RWA Liouvillian
# It took  0.819164037704  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00265502929688  seconds to build the electronic-Lindblad Liouvillian
# 37
# w_RC= 3555.61806429  TLS splitting = 806.55 RC-res. bath coupling= 10.6772488807  N= 14 TLS-RC coupling= 822.013155018 Gamma_RC=  238536.223001
# Calculating non-RWA Liouvilliian took 0.441025972366 seconds.
# It took  0.618357896805  seconds to build the Non-secular RWA Liouvillian
# It took  0.815904855728  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00267815589905  seconds to build the electronic-Lindblad Liouvillian
# 38
# w_RC= 3654.36282857  TLS splitting = 806.55 RC-res. bath coupling= 10.9737718494  N= 14 TLS-RC coupling= 833.349248581 Gamma_RC=  251969.201563
# Calculating non-RWA Liouvilliian took 0.450520992279 seconds.
# It took  0.614778995514  seconds to build the Non-secular RWA Liouvillian
# It took  0.812237977982  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00272393226624  seconds to build the electronic-Lindblad Liouvillian
# 39
# w_RC= 3753.10759286  TLS splitting = 806.55 RC-res. bath coupling= 11.2702948181  N= 14 TLS-RC coupling= 844.533192479 Gamma_RC=  265770.124596
# Calculating non-RWA Liouvilliian took 0.443409919739 seconds.
# It took  0.623904943466  seconds to build the Non-secular RWA Liouvillian
# It took  0.817126989365  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00274205207825  seconds to build the electronic-Lindblad Liouvillian
# 40
# w_RC= 3851.85235714  TLS splitting = 806.55 RC-res. bath coupling= 11.5668177868  N= 14 TLS-RC coupling= 855.570953391 Gamma_RC=  279938.992099
# Calculating non-RWA Liouvilliian took 0.450671195984 seconds.
# It took  0.621098041534  seconds to build the Non-secular RWA Liouvillian
# It took  0.815014839172  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00262308120728  seconds to build the electronic-Lindblad Liouvillian
# 41
# w_RC= 3950.59712143  TLS splitting = 806.55 RC-res. bath coupling= 11.8633407555  N= 14 TLS-RC coupling= 866.468117922 Gamma_RC=  294475.804072
# Calculating non-RWA Liouvilliian took 0.448859930038 seconds.
# It took  0.708120107651  seconds to build the Non-secular RWA Liouvillian
# It took  1.41076087952  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00265192985535  seconds to build the electronic-Lindblad Liouvillian
# 42
# w_RC= 4049.34188571  TLS splitting = 806.55 RC-res. bath coupling= 12.1598637242  N= 14 TLS-RC coupling= 877.229925654 Gamma_RC=  309380.560517
# Calculating non-RWA Liouvilliian took 0.555525064468 seconds.
# It took  0.666668176651  seconds to build the Non-secular RWA Liouvillian
# It took  0.962811946869  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00273680686951  seconds to build the electronic-Lindblad Liouvillian
# 43
# w_RC= 4148.08665  TLS splitting = 806.55 RC-res. bath coupling= 12.4563866928  N= 14 TLS-RC coupling= 887.8612986 Gamma_RC=  324653.261432
# Calculating non-RWA Liouvilliian took 0.461831092834 seconds.
# It took  0.711781978607  seconds to build the Non-secular RWA Liouvillian
# It took  0.808705091476  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00273299217224  seconds to build the electronic-Lindblad Liouvillian
# 44
# w_RC= 4246.83141429  TLS splitting = 806.55 RC-res. bath coupling= 12.7529096615  N= 14 TLS-RC coupling= 898.36686751 Gamma_RC=  340293.906818
# Calculating non-RWA Liouvilliian took 0.443089962006 seconds.
# It took  0.61999297142  seconds to build the Non-secular RWA Liouvillian
# It took  0.814082860947  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00260496139526  seconds to build the electronic-Lindblad Liouvillian
# 45
# w_RC= 4345.57617857  TLS splitting = 806.55 RC-res. bath coupling= 13.0494326302  N= 14 TLS-RC coupling= 908.750995448 Gamma_RC=  356302.496675
# Calculating non-RWA Liouvilliian took 0.449079990387 seconds.
# It took  0.613535881042  seconds to build the Non-secular RWA Liouvillian
# It took  0.810852050781  seconds to build the vibronic Lindblad Liouvillian
# It took  0.0026650428772  seconds to build the electronic-Lindblad Liouvillian
# 46
# w_RC= 4444.32094286  TLS splitting = 806.55 RC-res. bath coupling= 13.3459555989  N= 14 TLS-RC coupling= 919.017798966 Gamma_RC=  372679.031002
# Calculating non-RWA Liouvilliian took 0.447173833847 seconds.
# It took  0.621819019318  seconds to build the Non-secular RWA Liouvillian
# It took  0.810618877411  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00274300575256  seconds to build the electronic-Lindblad Liouvillian
# 47
# w_RC= 4543.06570714  TLS splitting = 806.55 RC-res. bath coupling= 13.6424785676  N= 14 TLS-RC coupling= 929.171167172 Gamma_RC=  389423.5098
# Calculating non-RWA Liouvilliian took 0.443856954575 seconds.
# It took  0.618049860001  seconds to build the Non-secular RWA Liouvillian
# It took  0.807592153549  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00269484519958  seconds to build the electronic-Lindblad Liouvillian
# 48
# w_RC= 4641.81047143  TLS splitting = 806.55 RC-res. bath coupling= 13.9390015363  N= 14 TLS-RC coupling= 939.214778947 Gamma_RC=  406535.933069
# Calculating non-RWA Liouvilliian took 0.44487786293 seconds.
# It took  0.61225605011  seconds to build the Non-secular RWA Liouvillian
# It took  0.813108921051  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00279688835144  seconds to build the electronic-Lindblad Liouvillian
# 49
# w_RC= 4740.55523571  TLS splitting = 806.55 RC-res. bath coupling= 14.235524505  N= 14 TLS-RC coupling= 949.152118514 Gamma_RC=  424016.300809
# Calculating non-RWA Liouvilliian took 0.447330951691 seconds.
# It took  0.624881029129  seconds to build the Non-secular RWA Liouvillian
# It took  0.81718993187  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00267100334167  seconds to build the electronic-Lindblad Liouvillian
# 50
# w_RC= 4839.3  TLS splitting = 806.55 RC-res. bath coupling= 14.5320474737  N= 14 TLS-RC coupling= 958.986489565 Gamma_RC=  441864.613019
# Calculating non-RWA Liouvilliian took 0.4507791996 seconds.
# It took  0.618047952652  seconds to build the Non-secular RWA Liouvillian
# It took  0.813812017441  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00300097465515  seconds to build the electronic-Lindblad Liouvillian

# %% [markdown]
# Now convergence of steadystates with respect to $\omega_{RC}$, since although the rates for lowest lying states (particularly for naive) are not converged well into $\omega_{RC}>\epsilon$, this may not affect the steady states. If so at high T, it might not at low T.

# %%
w0 = eps*1.1
wc = 52.
Gamma = (w0**2)/wc

def driving_convergence_wRC(eps, alpha_prop, T_EM=6000., T_ph=300., 
                            overdamped=False, min_w0_prop=0.01,
                            max_w0_prop=4.):
    omega_0_props = np.linspace(min_w0_prop, max_w0_prop, 50)
    omega_0 = omega_0_props*eps
    #displacements = alpha_ph/w0
    N = 35
    
    count = 1
    
    e0_population = [[],[],[]]
    g1_population = [[],[],[]]
    g0_population = [[],[],[]]
    g_total = [[],[],[]]
    labels = ['nrwa', 'non-sec', 'naive']
    alpha_ph = eps*alpha_prop
    shift = 0.5*np.pi*alpha_ph
    
    
    
    for w0 in omega_0:
        
        if overdamped:
            Gamma = w0**2/wc
        else:
            Gamma = 60.
        print count 
        count+=1

        if w0 > eps*0.2:
            N = 25
            if w0 > eps*0.7:
                N=14
        rho_0 = tensor(initial_sys, thermal_dm(N, n_RC))
        #print (rho_0*tensor(qeye(2), destroy(N).dag()*destroy(N))).tr()

        # Expectation values and time increments needed to calculate the dynamics
        expects = [tensor(G*G.dag(), qeye(N)), tensor(E*G.dag(), qeye(N)), 
               tensor(E*E.dag(), qeye(N)), tensor(qeye(2), destroy(N).dag()*destroy(N)), 
               tensor(qeye(2), destroy(N).dag()+destroy(N))]
        ti = time.time()
        L_RC, H_RC, A_EM, A_nrwa, wRC, kappa, Gamma_1= RC.RC_function_UD(
                                                    sigma, eps, T_ph, Gamma, 
                                                    w0, alpha_ph, N)
        evals, states = H_RC.eigenstates()
        ground_list = []
        excited_list = []
        for i in range(len(evals)): #
            is_ground = sum(states[i])[0][0].real == 1.
            if is_ground:
                ground_list.append(i)
            else:
                excited_list.append(i)
        L= [EM.L_non_rwa(H_RC, A_nrwa, eps, Gamma_EM, T_EM, J=J_EM), 
            EM.L_nonsecular(H_RC, A_EM, eps, Gamma_EM, T_EM, J=J_EM),
            EM.L_EM_lindblad(eps, A_EM, Gamma_EM, T_EM, J=J_EM)]
        
        for j, L_EM in enumerate(L):
            ss = steadystate(H_RC, [L_RC+L_EM])
            state = states[excited_list[0]]
            e0_population[j].append(ss.matrix_element(state.dag(), state))
            state = states[ground_list[1]]
            g1_population[j].append(ss.matrix_element(state.dag(), state))
            state = states[ground_list[0]]
            g0_population[j].append(ss.matrix_element(state.dag(), state))
            g_total[j].append((ss.ptrace(0)).matrix_element(G.dag(), G))
        tf = time.time()
        print " ** Steady states took: {}s**".format(tf-ti)
    plt.figure()
    for i in range(len(e0_population)):
        plt.ylabel('e-0 population')
        plt.xlabel(r'Oscillator frequency (units of $\epsilon$)')
        plt.plot(omega_0_props, e0_population[i], label=labels[i])
        plt.legend()
    plt.figure()
    for i in range(len(g1_population)):
        plt.ylabel('g-1 population')
        plt.xlabel(r'Oscillator frequency (units of $\epsilon$)')
        plt.plot(omega_0_props, g1_population[i], label=labels[i])
        plt.legend()
    plt.figure()
    for i in range(len(g0_population)):
        plt.ylabel('g-0 population')
        plt.xlabel(r'Oscillator frequency (units of $\epsilon$)')
        plt.plot(omega_0_props, g0_population[i], label=labels[i])
        plt.legend()
    plt.figure()
    for i in range(len(g0_population)):
        plt.ylabel('g population')
        plt.xlabel(r'Oscillator frequency (units of $\epsilon$)')
        plt.plot(omega_0_props, g_total[i], label=labels[i])
        plt.legend()
    plt.show()
    
    
#driving_convergence_wRC(eps, 0.3, T_EM=0., overdamped=True)
driving_convergence_wRC(eps, 0.3, T_EM=6000., max_w0_prop=1.1, overdamped=True)
driving_convergence_wRC(eps, 0.3, T_EM=6000., min_w0_prop=1, overdamped=True)

#driving_convergence_wRC(eps, 0.1, T_EM=6000., overdamped=True)
# Out:
# 1
# w_RC= 8.0655  TLS splitting = 806.55 RC-res. bath coupling= 0.0246858498751  N= 35 TLS-RC coupling= 55.36711079 Gamma_RC=  1.25100558173
# Calculating non-RWA Liouvilliian took 4.78401303291 seconds.
# It took  4.22359395027  seconds to build the Non-secular RWA Liouvillian
# It took  0.00398993492126  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 14.6563961506s**
# 2
# w_RC= 26.007122449  TLS splitting = 806.55 RC-res. bath coupling= 0.079599271026  N= 35 TLS-RC coupling= 99.4219701464 Gamma_RC=  13.0071234245
# Calculating non-RWA Liouvilliian took 6.81033015251 seconds.
# It took  4.3156440258  seconds to build the Non-secular RWA Liouvillian
# It took  0.00414419174194  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 16.9046940804s**
# 3
# w_RC= 43.948744898  TLS splitting = 806.55 RC-res. bath coupling= 0.134512692177  N= 35 TLS-RC coupling= 129.243720692 Gamma_RC=  37.1440803482
# Calculating non-RWA Liouvilliian took 5.85958099365 seconds.
# It took  4.6669960022  seconds to build the Non-secular RWA Liouvillian
# It took  0.00498390197754  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 17.3704528809s**
# 4
# w_RC= 61.8903673469  TLS splitting = 806.55 RC-res. bath coupling= 0.189426113328  N= 35 TLS-RC coupling= 153.37258728 Gamma_RC=  73.6618763527
# Calculating non-RWA Liouvilliian took 5.75170707703 seconds.
# It took  4.4451520443  seconds to build the Non-secular RWA Liouvillian
# It took  0.00481796264648  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 16.6536238194s**
# 5
# w_RC= 79.8319897959  TLS splitting = 806.55 RC-res. bath coupling= 0.244339534479  N= 35 TLS-RC coupling= 174.190590215 Gamma_RC=  122.560511438
# Calculating non-RWA Liouvilliian took 5.39806103706 seconds.
# It took  4.72009181976  seconds to build the Non-secular RWA Liouvillian
# It took  0.00453495979309  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 16.7076609135s**
# 6
# w_RC= 97.7736122449  TLS splitting = 806.55 RC-res. bath coupling= 0.299252955629  N= 35 TLS-RC coupling= 192.773371891 Gamma_RC=  183.839985604
# Calculating non-RWA Liouvilliian took 5.79822993279 seconds.
# It took  4.81700611115  seconds to build the Non-secular RWA Liouvillian
# It took  0.00416398048401  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 17.2641379833s**
# 7
# w_RC= 115.715234694  TLS splitting = 806.55 RC-res. bath coupling= 0.35416637678  N= 35 TLS-RC coupling= 209.715960529 Gamma_RC=  257.500298851
# Calculating non-RWA Liouvilliian took 5.68374991417 seconds.
# It took  4.51584482193  seconds to build the Non-secular RWA Liouvillian
# It took  0.00457811355591  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 17.0304341316s**
# 8
# w_RC= 133.656857143  TLS splitting = 806.55 RC-res. bath coupling= 0.409079797931  N= 35 TLS-RC coupling= 225.388542946 Gamma_RC=  343.541451179
# Calculating non-RWA Liouvilliian took 5.68206787109 seconds.
# It took  4.35649514198  seconds to build the Non-secular RWA Liouvillian
# It took  0.00431299209595  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 16.7128000259s**
# 9
# w_RC= 151.598479592  TLS splitting = 806.55 RC-res. bath coupling= 0.463993219082  N= 35 TLS-RC coupling= 240.040010169 Gamma_RC=  441.963442588
# Calculating non-RWA Liouvilliian took 5.54194712639 seconds.
# It took  5.3163599968  seconds to build the Non-secular RWA Liouvillian
# It took  0.00512790679932  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 18.3434538841s**
# 10
# w_RC= 169.540102041  TLS splitting = 806.55 RC-res. bath coupling= 0.518906640233  N= 25 TLS-RC coupling= 253.847232942 Gamma_RC=  552.766273077
# Calculating non-RWA Liouvilliian took 2.74768304825 seconds.
# It took  2.06569290161  seconds to build the Non-secular RWA Liouvillian
# It took  0.00320196151733  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 7.03247904778s**
# 11
# w_RC= 187.48172449  TLS splitting = 806.55 RC-res. bath coupling= 0.573820061384  N= 25 TLS-RC coupling= 266.941246088 Gamma_RC=  675.949942647
# Calculating non-RWA Liouvilliian took 2.3456299305 seconds.
# It took  2.42109489441  seconds to build the Non-secular RWA Liouvillian
# It took  0.00327682495117  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 6.8497979641s**
# 12
# w_RC= 205.423346939  TLS splitting = 806.55 RC-res. bath coupling= 0.628733482534  N= 25 TLS-RC coupling= 279.422332775 Gamma_RC=  811.514451299
# Calculating non-RWA Liouvilliian took 2.31467199326 seconds.
# It took  2.05967283249  seconds to build the Non-secular RWA Liouvillian
# It took  0.00326800346375  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 6.47029709816s**
# 13
# w_RC= 223.364969388  TLS splitting = 806.55 RC-res. bath coupling= 0.683646903685  N= 25 TLS-RC coupling= 291.36926956 Gamma_RC=  959.459799031
# Calculating non-RWA Liouvilliian took 2.94425296783 seconds.
# It took  2.14257884026  seconds to build the Non-secular RWA Liouvillian
# It took  0.00319695472717  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 7.31216287613s**
# 14
# w_RC= 241.306591837  TLS splitting = 806.55 RC-res. bath coupling= 0.738560324836  N= 25 TLS-RC coupling= 302.845278046 Gamma_RC=  1119.78598584
# Calculating non-RWA Liouvilliian took 2.43227720261 seconds.
# It took  2.42883300781  seconds to build the Non-secular RWA Liouvillian
# It took  0.00324606895447  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 7.03657984734s**
# 15
# w_RC= 259.248214286  TLS splitting = 806.55 RC-res. bath coupling= 0.793473745987  N= 25 TLS-RC coupling= 313.902012777 Gamma_RC=  1292.49301174
# Calculating non-RWA Liouvilliian took 2.33906197548 seconds.
# It took  2.14319801331  seconds to build the Non-secular RWA Liouvillian
# It took  0.00421905517578  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 6.75502920151s**
# 16
# w_RC= 277.189836735  TLS splitting = 806.55 RC-res. bath coupling= 0.848387167138  N= 25 TLS-RC coupling= 324.582323634 Gamma_RC=  1477.58087671
# Calculating non-RWA Liouvilliian took 3.00313997269 seconds.
# It took  2.78203892708  seconds to build the Non-secular RWA Liouvillian
# It took  0.00345706939697  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 8.89370393753s**
# 17
# w_RC= 295.131459184  TLS splitting = 806.55 RC-res. bath coupling= 0.903300588289  N= 25 TLS-RC coupling= 334.922223817 Gamma_RC=  1675.04958077
# Calculating non-RWA Liouvilliian took 3.29251980782 seconds.
# It took  2.81018805504  seconds to build the Non-secular RWA Liouvillian
# It took  0.00628089904785  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 9.2870349884s**
# 18
# w_RC= 313.073081633  TLS splitting = 806.55 RC-res. bath coupling= 0.958214009439  N= 25 TLS-RC coupling= 344.952325977 Gamma_RC=  1884.8991239
# Calculating non-RWA Liouvilliian took 3.00013685226 seconds.
# It took  2.23290801048  seconds to build the Non-secular RWA Liouvillian
# It took  0.00411415100098  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 7.65251517296s**
# 19
# w_RC= 331.014704082  TLS splitting = 806.55 RC-res. bath coupling= 1.01312743059  N= 25 TLS-RC coupling= 354.698912301 Gamma_RC=  2107.12950612
# Calculating non-RWA Liouvilliian took 2.60622310638 seconds.
# It took  2.50050091743  seconds to build the Non-secular RWA Liouvillian
# It took  0.00333404541016  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 7.51549696922s**
# 20
# w_RC= 348.956326531  TLS splitting = 806.55 RC-res. bath coupling= 1.06804085174  N= 25 TLS-RC coupling= 364.184746493 Gamma_RC=  2341.74072742
# Calculating non-RWA Liouvilliian took 2.7246389389 seconds.
# It took  2.29907202721  seconds to build the Non-secular RWA Liouvillian
# It took  0.00804090499878  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 7.17128705978s**
# 21
# w_RC= 366.89794898  TLS splitting = 806.55 RC-res. bath coupling= 1.12295427289  N= 25 TLS-RC coupling= 373.429699902 Gamma_RC=  2588.7327878
# Calculating non-RWA Liouvilliian took 2.36443901062 seconds.
# It took  2.22068810463  seconds to build the Non-secular RWA Liouvillian
# It took  0.00437116622925  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 7.35012102127s**
# 22
# w_RC= 384.839571429  TLS splitting = 806.55 RC-res. bath coupling= 1.17786769404  N= 25 TLS-RC coupling= 382.451241283 Gamma_RC=  2848.10568726
# Calculating non-RWA Liouvilliian took 3.07604598999 seconds.
# It took  2.29296517372  seconds to build the Non-secular RWA Liouvillian
# It took  0.00363898277283  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 7.58721113205s**
# 23
# w_RC= 402.781193878  TLS splitting = 806.55 RC-res. bath coupling= 1.23278111519  N= 25 TLS-RC coupling= 391.264824831 Gamma_RC=  3119.8594258
# Calculating non-RWA Liouvilliian took 2.55682587624 seconds.
# It took  2.75912714005  seconds to build the Non-secular RWA Liouvillian
# It took  0.00640606880188  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 7.69116806984s**
# 24
# w_RC= 420.722816327  TLS splitting = 806.55 RC-res. bath coupling= 1.28769453634  N= 25 TLS-RC coupling= 399.884201164 Gamma_RC=  3403.99400342
# Calculating non-RWA Liouvilliian took 2.66626000404 seconds.
# It took  2.14933085442  seconds to build the Non-secular RWA Liouvillian
# It took  0.00327396392822  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 7.22352981567s**
# 25
# w_RC= 438.664438776  TLS splitting = 806.55 RC-res. bath coupling= 1.3426079575  N= 25 TLS-RC coupling= 408.321669191 Gamma_RC=  3700.50942012
# Calculating non-RWA Liouvilliian took 2.63018703461 seconds.
# It took  2.26937007904  seconds to build the Non-secular RWA Liouvillian
# It took  0.00328087806702  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 7.66610813141s**
# 26
# w_RC= 456.606061224  TLS splitting = 806.55 RC-res. bath coupling= 1.39752137865  N= 25 TLS-RC coupling= 416.588282026 Gamma_RC=  4009.4056759
# Calculating non-RWA Liouvilliian took 2.93694400787 seconds.
# It took  2.14081501961  seconds to build the Non-secular RWA Liouvillian
# It took  0.00325393676758  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 7.39129710197s**
# 27
# w_RC= 474.547683673  TLS splitting = 806.55 RC-res. bath coupling= 1.4524347998  N= 25 TLS-RC coupling= 424.694016807 Gamma_RC=  4330.68277077
# Calculating non-RWA Liouvilliian took 3.19708609581 seconds.
# It took  3.41106581688  seconds to build the Non-secular RWA Liouvillian
# It took  0.00325798988342  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 9.37254118919s**
# 28
# w_RC= 492.489306122  TLS splitting = 806.55 RC-res. bath coupling= 1.50734822095  N= 25 TLS-RC coupling= 432.647915865 Gamma_RC=  4664.34070471
# Calculating non-RWA Liouvilliian took 2.4989771843 seconds.
# It took  2.69710898399  seconds to build the Non-secular RWA Liouvillian
# It took  0.00427103042603  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 8.47897601128s**
# 29
# w_RC= 510.430928571  TLS splitting = 806.55 RC-res. bath coupling= 1.5622616421  N= 25 TLS-RC coupling= 440.458204933 Gamma_RC=  5010.37947774
# Calculating non-RWA Liouvilliian took 2.44475483894 seconds.
# It took  2.08877587318  seconds to build the Non-secular RWA Liouvillian
# It took  0.00324296951294  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 6.97745490074s**
# 30
# w_RC= 528.37255102  TLS splitting = 806.55 RC-res. bath coupling= 1.61717506325  N= 25 TLS-RC coupling= 448.132392808 Gamma_RC=  5368.79908984
# Calculating non-RWA Liouvilliian took 2.61991500854 seconds.
# It took  2.26922416687  seconds to build the Non-secular RWA Liouvillian
# It took  0.00328493118286  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 7.80564713478s**
# 31
# w_RC= 546.314173469  TLS splitting = 806.55 RC-res. bath coupling= 1.6720884844  N= 25 TLS-RC coupling= 455.677355894 Gamma_RC=  5739.59954103
# Calculating non-RWA Liouvilliian took 3.02986097336 seconds.
# It took  2.07563900948  seconds to build the Non-secular RWA Liouvillian
# It took  0.00321483612061  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 7.35282611847s**
# 32
# w_RC= 564.255795918  TLS splitting = 806.55 RC-res. bath coupling= 1.72700190555  N= 25 TLS-RC coupling= 463.099410348 Gamma_RC=  6122.7808313
# Calculating non-RWA Liouvilliian took 2.59162306786 seconds.
# It took  2.55932188034  seconds to build the Non-secular RWA Liouvillian
# It took  0.0040819644928  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 7.44642210007s**
# 33
# w_RC= 582.197418367  TLS splitting = 806.55 RC-res. bath coupling= 1.7819153267  N= 14 TLS-RC coupling= 470.404373976 Gamma_RC=  6518.34296065
# Calculating non-RWA Liouvilliian took 0.657368898392 seconds.
# It took  0.737617969513  seconds to build the Non-secular RWA Liouvillian
# It took  0.00444316864014  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.05535697937s**
# 34
# w_RC= 600.139040816  TLS splitting = 806.55 RC-res. bath coupling= 1.83682874785  N= 14 TLS-RC coupling= 477.597619598 Gamma_RC=  6926.28592908
# Calculating non-RWA Liouvilliian took 0.639997005463 seconds.
# It took  0.757010936737  seconds to build the Non-secular RWA Liouvillian
# It took  0.00387191772461  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.20467996597s**
# 35
# w_RC= 618.080663265  TLS splitting = 806.55 RC-res. bath coupling= 1.891742169  N= 14 TLS-RC coupling= 484.684121296 Gamma_RC=  7346.60973659
# Calculating non-RWA Liouvilliian took 0.743662118912 seconds.
# It took  0.671375989914  seconds to build the Non-secular RWA Liouvillian
# It took  0.00272297859192  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.03984999657s**
# 36
# w_RC= 636.022285714  TLS splitting = 806.55 RC-res. bath coupling= 1.94665559015  N= 14 TLS-RC coupling= 491.668494646 Gamma_RC=  7779.31438318
# Calculating non-RWA Liouvilliian took 0.670780181885 seconds.
# It took  0.808444976807  seconds to build the Non-secular RWA Liouvillian
# It took  0.00846195220947  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.1842250824s**
# 37
# w_RC= 653.963908163  TLS splitting = 806.55 RC-res. bath coupling= 2.00156901131  N= 14 TLS-RC coupling= 498.555031885 Gamma_RC=  8224.39986885
# Calculating non-RWA Liouvilliian took 0.631362915039 seconds.
# It took  0.699469804764  seconds to build the Non-secular RWA Liouvillian
# It took  0.00445508956909  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.10282802582s**
# 38
# w_RC= 671.905530612  TLS splitting = 806.55 RC-res. bath coupling= 2.05648243246  N= 14 TLS-RC coupling= 505.347732763 Gamma_RC=  8681.8661936
# Calculating non-RWA Liouvilliian took 0.670582056046 seconds.
# It took  0.751775026321  seconds to build the Non-secular RWA Liouvillian
# It took  0.00297594070435  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.04550409317s**
# 39
# w_RC= 689.847153061  TLS splitting = 806.55 RC-res. bath coupling= 2.11139585361  N= 14 TLS-RC coupling= 512.050331705 Gamma_RC=  9151.71335744
# Calculating non-RWA Liouvilliian took 0.655283927917 seconds.
# It took  0.685443878174  seconds to build the Non-secular RWA Liouvillian
# It took  0.00263905525208  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 1.94169187546s**
# 40
# w_RC= 707.78877551  TLS splitting = 806.55 RC-res. bath coupling= 2.16630927476  N= 14 TLS-RC coupling= 518.666321819 Gamma_RC=  9633.94136035
# Calculating non-RWA Liouvilliian took 0.734954118729 seconds.
# It took  0.750757932663  seconds to build the Non-secular RWA Liouvillian
# It took  0.00383496284485  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.09509086609s**
# 41
# w_RC= 725.730397959  TLS splitting = 806.55 RC-res. bath coupling= 2.22122269591  N= 14 TLS-RC coupling= 525.19897618 Gamma_RC=  10128.5502023
# Calculating non-RWA Liouvilliian took 0.73367190361 seconds.
# It took  1.06820702553  seconds to build the Non-secular RWA Liouvillian
# It took  0.0029718875885  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.46185302734s**
# 42
# w_RC= 743.672020408  TLS splitting = 806.55 RC-res. bath coupling= 2.27613611706  N= 14 TLS-RC coupling= 531.651366753 Gamma_RC=  10635.5398834
# Calculating non-RWA Liouvilliian took 0.680984973907 seconds.
# It took  0.695849895477  seconds to build the Non-secular RWA Liouvillian
# It took  0.00278806686401  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.11096906662s**
# 43
# w_RC= 761.613642857  TLS splitting = 806.55 RC-res. bath coupling= 2.33104953821  N= 14 TLS-RC coupling= 538.026381287 Gamma_RC=  11154.9104036
# Calculating non-RWA Liouvilliian took 0.806991815567 seconds.
# It took  0.68187713623  seconds to build the Non-secular RWA Liouvillian
# It took  0.00314998626709  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.09266614914s**
# 44
# w_RC= 779.555265306  TLS splitting = 806.55 RC-res. bath coupling= 2.38596295936  N= 14 TLS-RC coupling= 544.326738413 Gamma_RC=  11686.6617628
# Calculating non-RWA Liouvilliian took 0.691841125488 seconds.
# It took  0.733360052109  seconds to build the Non-secular RWA Liouvillian
# It took  0.00357294082642  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.10114812851s**
# 45
# w_RC= 797.496887755  TLS splitting = 806.55 RC-res. bath coupling= 2.44087638051  N= 14 TLS-RC coupling= 550.555001196 Gamma_RC=  12230.7939611
# Calculating non-RWA Liouvilliian took 0.693864107132 seconds.
# It took  0.733112096786  seconds to build the Non-secular RWA Liouvillian
# It took  0.00386500358582  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.0423541069s**
# 46
# w_RC= 815.438510204  TLS splitting = 806.55 RC-res. bath coupling= 2.49578980166  N= 14 TLS-RC coupling= 556.713589319 Gamma_RC=  12787.3069985
# Calculating non-RWA Liouvilliian took 1.03056406975 seconds.
# It took  0.657018184662  seconds to build the Non-secular RWA Liouvillian
# It took  0.00275301933289  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.26716709137s**
# 47
# w_RC= 833.380132653  TLS splitting = 806.55 RC-res. bath coupling= 2.55070322281  N= 14 TLS-RC coupling= 562.804790068 Gamma_RC=  13356.200875
# Calculating non-RWA Liouvilliian took 0.626187086105 seconds.
# It took  0.656903982162  seconds to build the Non-secular RWA Liouvillian
# It took  0.00268793106079  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 1.86743497849s**
# 48
# w_RC= 851.321755102  TLS splitting = 806.55 RC-res. bath coupling= 2.60561664396  N= 14 TLS-RC coupling= 568.830768255 Gamma_RC=  13937.4755906
# Calculating non-RWA Liouvilliian took 0.694310188293 seconds.
# It took  0.700557947159  seconds to build the Non-secular RWA Liouvillian
# It took  0.00267601013184  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 1.97114300728s**
# 49
# w_RC= 869.263377551  TLS splitting = 806.55 RC-res. bath coupling= 2.66053006512  N= 14 TLS-RC coupling= 574.793575212 Gamma_RC=  14531.1311452
# Calculating non-RWA Liouvilliian took 0.726950883865 seconds.
# It took  0.7312271595  seconds to build the Non-secular RWA Liouvillian
# It took  0.00270700454712  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.04538702965s**
# 50
# w_RC= 887.205  TLS splitting = 806.55 RC-res. bath coupling= 2.71544348627  N= 14 TLS-RC coupling= 580.695156941 Gamma_RC=  15137.1675389
# Calculating non-RWA Liouvilliian took 0.711888074875 seconds.
# It took  0.654982089996  seconds to build the Non-secular RWA Liouvillian
# It took  0.00277400016785  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.00356221199s**
# 1
# w_RC= 806.55  TLS splitting = 806.55 RC-res. bath coupling= 2.46858498751  N= 14 TLS-RC coupling= 553.6711079 Gamma_RC=  12510.0558173
# Calculating non-RWA Liouvilliian took 0.702665805817 seconds.
# It took  0.643187046051  seconds to build the Non-secular RWA Liouvillian
# It took  0.00267887115479  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.01694107056s**
# 2
# w_RC= 855.930612245  TLS splitting = 806.55 RC-res. bath coupling= 2.61972284389  N= 14 TLS-RC coupling= 570.368448364 Gamma_RC=  14088.7925573
# Calculating non-RWA Liouvilliian took 0.773008108139 seconds.
# It took  0.755186080933  seconds to build the Non-secular RWA Liouvillian
# It took  0.00304889678955  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.19029808044s**
# 3
# w_RC= 905.31122449  TLS splitting = 806.55 RC-res. bath coupling= 2.77086070027  N= 14 TLS-RC coupling= 586.590690393 Gamma_RC=  15761.3156382
# Calculating non-RWA Liouvilliian took 0.668249845505 seconds.
# It took  0.659515142441  seconds to build the Non-secular RWA Liouvillian
# It took  0.00274109840393  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 1.93356704712s**
# 4
# w_RC= 954.691836735  TLS splitting = 806.55 RC-res. bath coupling= 2.92199855665  N= 14 TLS-RC coupling= 602.376219005 Gamma_RC=  17527.6250602
# Calculating non-RWA Liouvilliian took 0.708068847656 seconds.
# It took  0.726056098938  seconds to build the Non-secular RWA Liouvillian
# It took  0.00276517868042  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.03559207916s**
# 5
# w_RC= 1004.07244898  TLS splitting = 806.55 RC-res. bath coupling= 3.07313641303  N= 14 TLS-RC coupling= 617.758513005 Gamma_RC=  19387.7208231
# Calculating non-RWA Liouvilliian took 0.913171052933 seconds.
# It took  0.854897975922  seconds to build the Non-secular RWA Liouvillian
# It took  0.00262498855591  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.42923808098s**
# 6
# w_RC= 1053.45306122  TLS splitting = 806.55 RC-res. bath coupling= 3.22427426941  N= 14 TLS-RC coupling= 632.766980457 Gamma_RC=  21341.602927
# Calculating non-RWA Liouvilliian took 0.733308076859 seconds.
# It took  0.72433590889  seconds to build the Non-secular RWA Liouvillian
# It took  0.00327777862549  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.06150388718s**
# 7
# w_RC= 1102.83367347  TLS splitting = 806.55 RC-res. bath coupling= 3.37541212579  N= 14 TLS-RC coupling= 647.427619679 Gamma_RC=  23389.2713719
# Calculating non-RWA Liouvilliian took 0.77335190773 seconds.
# It took  0.692786931992  seconds to build the Non-secular RWA Liouvillian
# It took  0.00267601013184  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.11416196823s**
# 8
# w_RC= 1152.21428571  TLS splitting = 806.55 RC-res. bath coupling= 3.52654998216  N= 14 TLS-RC coupling= 661.763548324 Gamma_RC=  25530.7261578
# Calculating non-RWA Liouvilliian took 0.739765882492 seconds.
# It took  0.677454948425  seconds to build the Non-secular RWA Liouvillian
# It took  0.00260591506958  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.0515499115s**
# 9
# w_RC= 1201.59489796  TLS splitting = 806.55 RC-res. bath coupling= 3.67768783854  N= 14 TLS-RC coupling= 675.795431367 Gamma_RC=  27765.9672846
# Calculating non-RWA Liouvilliian took 0.741400957108 seconds.
# It took  0.717889070511  seconds to build the Non-secular RWA Liouvillian
# It took  0.00316715240479  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.15068912506s**
# 10
# w_RC= 1250.9755102  TLS splitting = 806.55 RC-res. bath coupling= 3.82882569492  N= 14 TLS-RC coupling= 689.541830655 Gamma_RC=  30094.9947525
# Calculating non-RWA Liouvilliian took 0.687951087952 seconds.
# It took  0.709244966507  seconds to build the Non-secular RWA Liouvillian
# It took  0.00288915634155  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.51626801491s**
# 11
# w_RC= 1300.35612245  TLS splitting = 806.55 RC-res. bath coupling= 3.9799635513  N= 14 TLS-RC coupling= 703.019492895 Gamma_RC=  32517.8085614
# Calculating non-RWA Liouvilliian took 0.692388057709 seconds.
# It took  0.69868016243  seconds to build the Non-secular RWA Liouvillian
# It took  0.0029559135437  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.04510593414s**
# 12
# w_RC= 1349.73673469  TLS splitting = 806.55 RC-res. bath coupling= 4.13110140768  N= 14 TLS-RC coupling= 716.243588842 Gamma_RC=  35034.4087112
# Calculating non-RWA Liouvilliian took 0.695268154144 seconds.
# It took  0.697536945343  seconds to build the Non-secular RWA Liouvillian
# It took  0.00263500213623  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.02209496498s**
# 13
# w_RC= 1399.11734694  TLS splitting = 806.55 RC-res. bath coupling= 4.28223926406  N= 14 TLS-RC coupling= 729.227913429 Gamma_RC=  37644.795202
# Calculating non-RWA Liouvilliian took 0.659607887268 seconds.
# It took  0.661403894424  seconds to build the Non-secular RWA Liouvillian
# It took  0.00265908241272  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 1.9857749939s**
# 14
# w_RC= 1448.49795918  TLS splitting = 806.55 RC-res. bath coupling= 4.43337712043  N= 14 TLS-RC coupling= 741.985054358 Gamma_RC=  40348.9680338
# Calculating non-RWA Liouvilliian took 0.753098011017 seconds.
# It took  1.03687500954  seconds to build the Non-secular RWA Liouvillian
# It took  0.0036609172821  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.53381705284s**
# 15
# w_RC= 1497.87857143  TLS splitting = 806.55 RC-res. bath coupling= 4.58451497681  N= 14 TLS-RC coupling= 754.526535025 Gamma_RC=  43146.9272066
# Calculating non-RWA Liouvilliian took 0.801478147507 seconds.
# It took  0.813214063644  seconds to build the Non-secular RWA Liouvillian
# It took  0.00267100334167  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.71145391464s**
# 16
# w_RC= 1547.25918367  TLS splitting = 806.55 RC-res. bath coupling= 4.73565283319  N= 14 TLS-RC coupling= 766.8629364 Gamma_RC=  46038.6727204
# Calculating non-RWA Liouvilliian took 0.728986024857 seconds.
# It took  0.680720806122  seconds to build the Non-secular RWA Liouvillian
# It took  0.00271201133728  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.07522392273s**
# 17
# w_RC= 1596.63979592  TLS splitting = 806.55 RC-res. bath coupling= 4.88679068957  N= 14 TLS-RC coupling= 779.004001524 Gamma_RC=  49024.2045752
# Calculating non-RWA Liouvilliian took 0.646497964859 seconds.
# It took  0.64427113533  seconds to build the Non-secular RWA Liouvillian
# It took  0.002681016922  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 1.89045500755s**
# 18
# w_RC= 1646.02040816  TLS splitting = 806.55 RC-res. bath coupling= 5.03792854595  N= 14 TLS-RC coupling= 790.958725571 Gamma_RC=  52103.522771
# Calculating non-RWA Liouvilliian took 0.606393814087 seconds.
# It took  0.642982006073  seconds to build the Non-secular RWA Liouvillian
# It took  0.00265884399414  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 1.81441807747s**
# 19
# w_RC= 1695.40102041  TLS splitting = 806.55 RC-res. bath coupling= 5.18906640233  N= 14 TLS-RC coupling= 802.735433828 Gamma_RC=  55276.6273077
# Calculating non-RWA Liouvilliian took 0.983201026917 seconds.
# It took  0.639102935791  seconds to build the Non-secular RWA Liouvillian
# It took  0.00273108482361  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.17947912216s**
# 20
# w_RC= 1744.78163265  TLS splitting = 806.55 RC-res. bath coupling= 5.34020425871  N= 14 TLS-RC coupling= 814.341849527 Gamma_RC=  58543.5181855
# Calculating non-RWA Liouvilliian took 0.608160018921 seconds.
# It took  0.666203022003  seconds to build the Non-secular RWA Liouvillian
# It took  0.00271606445312  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 1.83514404297s**
# 21
# w_RC= 1794.1622449  TLS splitting = 806.55 RC-res. bath coupling= 5.49134211508  N= 14 TLS-RC coupling= 825.785153086 Gamma_RC=  61904.1954042
# Calculating non-RWA Liouvilliian took 0.635777950287 seconds.
# It took  0.701684951782  seconds to build the Non-secular RWA Liouvillian
# It took  0.00281810760498  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.12975883484s**
# 22
# w_RC= 1843.54285714  TLS splitting = 806.55 RC-res. bath coupling= 5.64247997146  N= 14 TLS-RC coupling= 837.072034071 Gamma_RC=  65358.6589639
# Calculating non-RWA Liouvilliian took 0.748281955719 seconds.
# It took  0.771492004395  seconds to build the Non-secular RWA Liouvillian
# It took  0.00273299217224  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.10880494118s**
# 23
# w_RC= 1892.92346939  TLS splitting = 806.55 RC-res. bath coupling= 5.79361782784  N= 14 TLS-RC coupling= 848.208736922 Gamma_RC=  68906.9088646
# Calculating non-RWA Liouvilliian took 0.608062028885 seconds.
# It took  0.654474020004  seconds to build the Non-secular RWA Liouvillian
# It took  0.0026650428772  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 1.83390593529s**
# 24
# w_RC= 1942.30408163  TLS splitting = 806.55 RC-res. bath coupling= 5.94475568422  N= 14 TLS-RC coupling= 859.201101348 Gamma_RC=  72548.9451063
# Calculating non-RWA Liouvilliian took 1.02560400963 seconds.
# It took  0.650628089905  seconds to build the Non-secular RWA Liouvillian
# It took  0.00266909599304  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.29511809349s**
# 25
# w_RC= 1991.68469388  TLS splitting = 806.55 RC-res. bath coupling= 6.0958935406  N= 14 TLS-RC coupling= 870.054598128 Gamma_RC=  76284.767689
# Calculating non-RWA Liouvilliian took 0.607234954834 seconds.
# It took  0.660243034363  seconds to build the Non-secular RWA Liouvillian
# It took  0.00272297859192  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 1.85534405708s**
# 26
# w_RC= 2041.06530612  TLS splitting = 806.55 RC-res. bath coupling= 6.24703139698  N= 14 TLS-RC coupling= 880.774360941 Gamma_RC=  80114.3766126
# Calculating non-RWA Liouvilliian took 0.612757205963 seconds.
# It took  0.655858039856  seconds to build the Non-secular RWA Liouvillian
# It took  0.00271105766296  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 1.84130001068s**
# 27
# w_RC= 2090.44591837  TLS splitting = 806.55 RC-res. bath coupling= 6.39816925335  N= 14 TLS-RC coupling= 891.365214745 Gamma_RC=  84037.7718773
# Calculating non-RWA Liouvilliian took 0.609095096588 seconds.
# It took  0.656111955643  seconds to build the Non-secular RWA Liouvillian
# It took  0.002690076828  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 1.84705400467s**
# 28
# w_RC= 2139.82653061  TLS splitting = 806.55 RC-res. bath coupling= 6.54930710973  N= 14 TLS-RC coupling= 901.831701164 Gamma_RC=  88054.9534829
# Calculating non-RWA Liouvilliian took 0.614455938339 seconds.
# It took  0.666780948639  seconds to build the Non-secular RWA Liouvillian
# It took  0.0027379989624  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 1.8634519577s**
# 29
# w_RC= 2189.20714286  TLS splitting = 806.55 RC-res. bath coupling= 6.70044496611  N= 14 TLS-RC coupling= 912.178101245 Gamma_RC=  92165.9214296
# Calculating non-RWA Liouvilliian took 1.31771492958 seconds.
# It took  0.946407079697  seconds to build the Non-secular RWA Liouvillian
# It took  0.0030300617218  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.85383105278s**
# 30
# w_RC= 2238.5877551  TLS splitting = 806.55 RC-res. bath coupling= 6.85158282249  N= 14 TLS-RC coupling= 922.408455923 Gamma_RC=  96370.6757172
# Calculating non-RWA Liouvilliian took 0.647475004196 seconds.
# It took  0.645456075668  seconds to build the Non-secular RWA Liouvillian
# It took  0.00283813476562  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 1.86706590652s**
# 31
# w_RC= 2287.96836735  TLS splitting = 806.55 RC-res. bath coupling= 7.00272067887  N= 14 TLS-RC coupling= 932.52658446 Gamma_RC=  100669.216346
# Calculating non-RWA Liouvilliian took 0.615180015564 seconds.
# It took  0.64821100235  seconds to build the Non-secular RWA Liouvillian
# It took  0.00283598899841  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 1.83231520653s**
# 32
# w_RC= 2337.34897959  TLS splitting = 806.55 RC-res. bath coupling= 7.15385853525  N= 14 TLS-RC coupling= 942.536101107 Gamma_RC=  105061.543315
# Calculating non-RWA Liouvilliian took 0.601553916931 seconds.
# It took  0.654496908188  seconds to build the Non-secular RWA Liouvillian
# It took  0.00276899337769  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 1.85085511208s**
# 33
# w_RC= 2386.72959184  TLS splitting = 806.55 RC-res. bath coupling= 7.30499639163  N= 14 TLS-RC coupling= 952.440430188 Gamma_RC=  109547.656626
# Calculating non-RWA Liouvilliian took 0.606513023376 seconds.
# It took  0.681071043015  seconds to build the Non-secular RWA Liouvillian
# It took  0.0032639503479  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 1.87223601341s**
# 34
# w_RC= 2436.11020408  TLS splitting = 806.55 RC-res. bath coupling= 7.456134248  N= 14 TLS-RC coupling= 962.242819783 Gamma_RC=  114127.556278
# Calculating non-RWA Liouvilliian took 1.12704396248 seconds.
# It took  0.832291126251  seconds to build the Non-secular RWA Liouvillian
# It took  0.00274395942688  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.53327679634s**
# 35
# w_RC= 2485.49081633  TLS splitting = 806.55 RC-res. bath coupling= 7.60727210438  N= 14 TLS-RC coupling= 971.946354173 Gamma_RC=  118801.24227
# Calculating non-RWA Liouvilliian took 0.621382951736 seconds.
# It took  0.645736932755  seconds to build the Non-secular RWA Liouvillian
# It took  0.003093957901  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 1.83706402779s**
# 36
# w_RC= 2534.87142857  TLS splitting = 806.55 RC-res. bath coupling= 7.75840996076  N= 14 TLS-RC coupling= 981.553965179 Gamma_RC=  123568.714604
# Calculating non-RWA Liouvilliian took 0.612874031067 seconds.
# It took  0.634001016617  seconds to build the Non-secular RWA Liouvillian
# It took  0.0026478767395  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 1.83529615402s**
# 37
# w_RC= 2584.25204082  TLS splitting = 806.55 RC-res. bath coupling= 7.90954781714  N= 14 TLS-RC coupling= 991.068442503 Gamma_RC=  128429.973278
# Calculating non-RWA Liouvilliian took 0.694880008698 seconds.
# It took  0.899322986603  seconds to build the Non-secular RWA Liouvillian
# It took  0.00373506546021  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.1778690815s**
# 38
# w_RC= 2633.63265306  TLS splitting = 806.55 RC-res. bath coupling= 8.06068567352  N= 14 TLS-RC coupling= 1000.4924432 Gamma_RC=  133385.018294
# Calculating non-RWA Liouvilliian took 0.788926124573 seconds.
# It took  1.0255022049  seconds to build the Non-secular RWA Liouvillian
# It took  0.0117988586426  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.75478482246s**
# 39
# w_RC= 2683.01326531  TLS splitting = 806.55 RC-res. bath coupling= 8.2118235299  N= 14 TLS-RC coupling= 1009.82850032 Gamma_RC=  138433.84965
# Calculating non-RWA Liouvilliian took 1.2174642086 seconds.
# It took  0.76676607132  seconds to build the Non-secular RWA Liouvillian
# It took  0.00313711166382  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.78900718689s**
# 40
# w_RC= 2732.39387755  TLS splitting = 806.55 RC-res. bath coupling= 8.36296138627  N= 14 TLS-RC coupling= 1019.0790309 Gamma_RC=  143576.467348
# Calculating non-RWA Liouvilliian took 1.24135017395 seconds.
# It took  1.07875704765  seconds to build the Non-secular RWA Liouvillian
# It took  0.00320911407471  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.97214007378s**
# 41
# w_RC= 2781.7744898  TLS splitting = 806.55 RC-res. bath coupling= 8.51409924265  N= 14 TLS-RC coupling= 1028.24634324 Gamma_RC=  148812.871386
# Calculating non-RWA Liouvilliian took 0.680227041245 seconds.
# It took  0.730750083923  seconds to build the Non-secular RWA Liouvillian
# It took  0.00267314910889  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.06175804138s**
# 42
# w_RC= 2831.15510204  TLS splitting = 806.55 RC-res. bath coupling= 8.66523709903  N= 14 TLS-RC coupling= 1037.33264364 Gamma_RC=  154143.061766
# Calculating non-RWA Liouvilliian took 0.661612033844 seconds.
# It took  1.00153684616  seconds to build the Non-secular RWA Liouvillian
# It took  0.00268793106079  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.44151592255s**
# 43
# w_RC= 2880.53571429  TLS splitting = 806.55 RC-res. bath coupling= 8.81637495541  N= 14 TLS-RC coupling= 1046.34004259 Gamma_RC=  159567.038486
# Calculating non-RWA Liouvilliian took 0.638348817825 seconds.
# It took  0.66309094429  seconds to build the Non-secular RWA Liouvillian
# It took  0.00516200065613  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 1.9756860733s**
# 44
# w_RC= 2929.91632653  TLS splitting = 806.55 RC-res. bath coupling= 8.96751281179  N= 14 TLS-RC coupling= 1055.27056052 Gamma_RC=  165084.801548
# Calculating non-RWA Liouvilliian took 0.72479391098 seconds.
# It took  0.724130868912  seconds to build the Non-secular RWA Liouvillian
# It took  0.00274801254272  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.08585906029s**
# 45
# w_RC= 2979.29693878  TLS splitting = 806.55 RC-res. bath coupling= 9.11865066817  N= 14 TLS-RC coupling= 1064.12613306 Gamma_RC=  170696.35095
# Calculating non-RWA Liouvilliian took 0.731411933899 seconds.
# It took  0.654067993164  seconds to build the Non-secular RWA Liouvillian
# It took  0.00294589996338  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.05708384514s**
# 46
# w_RC= 3028.67755102  TLS splitting = 806.55 RC-res. bath coupling= 9.26978852455  N= 14 TLS-RC coupling= 1072.90861597 Gamma_RC=  176401.686693
# Calculating non-RWA Liouvilliian took 0.650534152985 seconds.
# It took  0.657799005508  seconds to build the Non-secular RWA Liouvillian
# It took  0.00269293785095  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 1.95765900612s**
# 47
# w_RC= 3078.05816327  TLS splitting = 806.55 RC-res. bath coupling= 9.42092638092  N= 14 TLS-RC coupling= 1081.61978966 Gamma_RC=  182200.808778
# Calculating non-RWA Liouvilliian took 0.776390075684 seconds.
# It took  0.865505933762  seconds to build the Non-secular RWA Liouvillian
# It took  0.00283098220825  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.23501300812s**
# 48
# w_RC= 3127.43877551  TLS splitting = 806.55 RC-res. bath coupling= 9.5720642373  N= 14 TLS-RC coupling= 1090.26136342 Gamma_RC=  188093.717203
# Calculating non-RWA Liouvilliian took 0.673649072647 seconds.
# It took  0.694402933121  seconds to build the Non-secular RWA Liouvillian
# It took  0.00278210639954  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 1.94114303589s**
# 49
# w_RC= 3176.81938776  TLS splitting = 806.55 RC-res. bath coupling= 9.72320209368  N= 14 TLS-RC coupling= 1098.8349793 Gamma_RC=  194080.41197
# Calculating non-RWA Liouvilliian took 0.710938930511 seconds.
# It took  0.718061923981  seconds to build the Non-secular RWA Liouvillian
# It took  0.00286507606506  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 2.06495904922s**
# 50
# w_RC= 3226.2  TLS splitting = 806.55 RC-res. bath coupling= 9.87433995006  N= 14 TLS-RC coupling= 1107.3422158 Gamma_RC=  200160.893077
# Calculating non-RWA Liouvilliian took 0.665830850601 seconds.
# It took  0.672293901443  seconds to build the Non-secular RWA Liouvillian
# It took  0.00303792953491  seconds to build the electronic-Lindblad Liouvillian
#  ** Steady states took: 1.97465205193s**

# %% [markdown]
# So we can see that the non-secular theory predicts steadystates which are very sensitive to $\omega_{RC}$, even when it is the same scale as $\epsilon$. This is counterintuitive since this is regime in which the specifics of the RC itself should not be so important (no longer single-mode like). This could be to do with the unphysical and non-thermodynamically stable processes that it allows. Although the phenomenological Lindblad theory has these processes as well, this is only incidental as the actual dissipator cannot see the vibronic levels at all. The NS can see these levels but just deals with them inconsistently.

# %% [markdown]
# ## Instantaneous Decay rates: coupling strength dependence
#
# Now we will look at decay rates at short times and $T_{EM}=0$ from the $|e,0\rangle \to |g,k\rangle$ states.

# %%
from qutip import vector_to_operator, operator_to_vector, basis


def decay_rate_plotter(eps, T_ph, w0, overdamped=True, nvib=3):
    alpha_ph = np.linspace(0.001,1.5,10)*eps
    displacements = alpha_ph/w0
    N = 17
    if overdamped:
        Gamma_ = w0**2/wc
    else:
        Gamma_ = 60.
    decay_wrt_alpha = [[],[],[],[]]
    labels = ['g-0',  'g-1', 'g-2','g-3', 'g-4', 'g-5']
    
    for alpha_ in alpha_ph:
        L_RC, H, A_EM, A_nrwa, wRC, kappa, Gamma_1 = RC.RC_function_UD(sigma, eps, T_ph, Gamma_, w0, alpha_, N)
    # given some Liouvillian, find the instantaneous decay rates
    # from e-0 to the ground manifold eigenstates, for several
    # oscillator displacements
    # - need to find the first eigenstate in the excited manifold
        evals, states = eigstate_calc_and_mag_sort(H, sort=False)
        ground_list = []
        excited_list = []
        for i in range(len(evals)): #
            is_ground = sum(states[i])[0][0].real == 1.
            if is_ground:
                ground_list.append(i)
            else:
                excited_list.append(i)
        excited_ket = states[excited_list[0]]
        
        #initial_ket = tensor(basis(2,1), basis(N,0))
        excited_rho = excited_ket*excited_ket.dag()
        
        L= [EM.L_non_rwa(H, A_nrwa, eps, Gamma_EM, 0, J=J_EM), 
            EM.L_nonsecular(H, A_EM, eps, Gamma_EM, 0, J=J_EM),
            EM.L_vib_lindblad(H, A_EM, eps, Gamma_EM, 0, J=J_EM),
            EM.L_EM_lindblad(eps, A_EM, Gamma_EM, 0, J=J_EM)]
        for i_, L_EM in enumerate(L):
            decay_rates = [] # not really decay rates but population at short times
            for j in range(nvib):
                ground_ket = tensor(basis(2,0), basis(N,j))
                #print states[ground_list][j].dag()*target_ket
                #target_rho = operator_to_vector(target_ket*target_ket.dag())
                L_rho0_prod = vector_to_operator(L_EM*operator_to_vector(excited_ket*excited_ket.dag()))
                rate = L_rho0_prod.matrix_element(ground_ket.dag(), ground_ket)
                decay_rates.append(rate)
                
            if len(decay_rates)!=nvib:
                print ground_list
            decay_wrt_alpha[i_].append(decay_rates)
    for level in range(nvib):
        plt.figure()
        plt.title(labels[level])
        plt.plot(displacements,np.array(decay_wrt_alpha[0]).T[level], label='non-RWA')
        plt.plot(displacements,np.array(decay_wrt_alpha[1]).T[level], label='non-sec', linestyle='dashed')
        plt.plot(displacements,np.array(decay_wrt_alpha[2]).T[level], label='sec', linestyle='dotted')
        plt.plot(displacements,np.array(decay_wrt_alpha[3]).T[level], label='naive')
        plt.legend()
        plt.xlabel('Oscillator Displacement')
        plt.ylabel('Rate to {}'.format(labels[level]))
    plt.show()
    return displacements, decay_wrt_alpha
    #for i, alpha in enumerate(alpha_ph):
    #    plt.plot(decay_wrt_alpha[i])

displacements, decay_wrt_alpha = decay_rate_plotter(eps, T_ph, eps*0.9, nvib=4)
#decay_rate_plotter(H_RC, L_ns)
#decay_rate_plotter(H_RC, L_n)
# Out:
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 17 TLS-RC coupling= 30.3258155236 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.789258956909 seconds.
# It took  0.937226057053  seconds to build the Non-secular RWA Liouvillian
# It took  0.89510178566  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00269198417664  seconds to build the electronic-Lindblad Liouvillian
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 17 TLS-RC coupling= 392.54721888 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.671725034714 seconds.
# It took  0.91846704483  seconds to build the Non-secular RWA Liouvillian
# It took  1.47354602814  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00267291069031  seconds to build the electronic-Lindblad Liouvillian
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 17 TLS-RC coupling= 554.316681161 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.670881032944 seconds.
# It took  0.953257083893  seconds to build the Non-secular RWA Liouvillian
# It took  1.50100898743  seconds to build the vibronic Lindblad Liouvillian
# It took  0.0027379989624  seconds to build the electronic-Lindblad Liouvillian
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 17 TLS-RC coupling= 678.557769815 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.67138004303 seconds.
# It took  0.935696125031  seconds to build the Non-secular RWA Liouvillian
# It took  1.49307894707  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00271391868591  seconds to build the electronic-Lindblad Liouvillian
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 17 TLS-RC coupling= 783.335375774 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.669708013535 seconds.
# It took  1.16933608055  seconds to build the Non-secular RWA Liouvillian
# It took  1.88311290741  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00286102294922  seconds to build the electronic-Lindblad Liouvillian
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 17 TLS-RC coupling= 875.664304915 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 1.30074596405 seconds.
# It took  1.21149516106  seconds to build the Non-secular RWA Liouvillian
# It took  1.92697691917  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00263595581055  seconds to build the electronic-Lindblad Liouvillian
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 17 TLS-RC coupling= 959.14630733 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.662296056747 seconds.
# It took  0.90670800209  seconds to build the Non-secular RWA Liouvillian
# It took  1.53901290894  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00264096260071  seconds to build the electronic-Lindblad Liouvillian
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 17 TLS-RC coupling= 1035.92244055 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.676297903061 seconds.
# It took  0.928254127502  seconds to build the Non-secular RWA Liouvillian
# It took  1.91959309578  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00621199607849  seconds to build the electronic-Lindblad Liouvillian
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 17 TLS-RC coupling= 1107.3883541 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.776132822037 seconds.
# It took  0.98303103447  seconds to build the Non-secular RWA Liouvillian
# It took  2.08612108231  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00319790840149  seconds to build the electronic-Lindblad Liouvillian
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 17 TLS-RC coupling= 1174.51378483 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 1.11695289612 seconds.
# It took  1.00844693184  seconds to build the Non-secular RWA Liouvillian
# It took  1.63698792458  seconds to build the vibronic Lindblad Liouvillian
# It took  0.00268483161926  seconds to build the electronic-Lindblad Liouvillian

# %% [markdown]
# IT seems that:
# - I can't see any decay rates from $|e,0\rangle \to |g,k\rangle$ with $\langle g,k|L_{EM}\rho(0) |e,0\rangle$ in non-RWA. If the system starts in a higher-lying vibrational state though, it decays to lower lying ground vibrational states in a similar manner to the non-secular theory. It's as if only certain transitions are allowed electronically and some vibrationally, so when these states are populated via the latter process they decay in a similar fashion to the non-secular theory. This absolutely makes sense from an energetic point of view as the RC frequency is greater than the system splitting, so if ground vibrational quantum number > excited vib. then this is a higher lying state and so cannot be populated at zero EM temperature.
# - Using my method of defining the rates $|e,0\rangle \to |g,k\rangle$ with $\langle g,k|L_{EM}\rho(0) |g,k\rangle$ I only see non-zero decay rates for non-RWA case for $n=0$. As alpha increases the decay to $|g,0\rangle$ decreases to zero (should be exponential overlap no?) by none of the other decay pathways open up as well. This would make it thermodynamically unstable, localising an population in the excited state (quantum zeno?).
# - With $T_{EM}=0$ and $\rho(0)=|g, n\rangle$ there are rates going to the excited state for non-RWA. This doesn't make any sense as these states cannot be thermally populated.
#
# Need to:
# - find which method is definitely correct. Speak to Ahsan.
# - Calculate using Ahsan's derivation of the non-RWA master equation.
#
# ## Steady-state population of vibronic states: displacement dependence

# %%
def steadystatePop_coupling_dependence(prop_couplings, T_ph, eps, Gamma, w0, T_EM, 
                                    Gamma_EM, overdamped=True):
    
    w0 = eps*0.9
    if overdamped:
        Gamma = w0**2/wc
    plt.figure()
    N = 14
    G = ket([0])
    E = ket([1])
    sigma = G*E.dag() # Definition of a sigma_- operator.
    J = EM.J_minimal
    count = 1

    data_nrwa  = [[],[],[],[],[],[]]
    data_ns  = [[],[],[],[],[],[]]
    data_n  = [[],[],[],[],[],[]]
    labels = ['g-0',  'g-1', 'g-2','e-0','e-1', 'e-2'] 
    # This is true for specific Hamiltonian parameters
    colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
    for prop in prop_couplings:
        alpha_ph = prop*eps
        print count
        count+=1
        L_RC, H_RC, A_EM, A_nrwa, wRC, kappa, Gamma= RC.RC_function_UD(sigma, eps, 
                                                                       T_ph, Gamma, 
                                                                       w0, alpha_ph, N)
        evals, states = eigstate_calc_and_mag_sort(H_RC, sort=False)
        ground_list = []
        excited_list = []
        for i in range(20): #
            is_ground = sum(states[i])[0][0].real == 1.
            if is_ground:
                ground_list.append(i)
            else:
                excited_list.append(i)
        #print ground_list[0:3], excited_list[0:3]
        lowest_6 = states[ground_list[0:3] + excited_list[0:3]]
        #print len(excited_list), 'excited'
        # electromagnetic bath liouvillians
        L_nrwa = EM.L_non_rwa(H_RC, A_nrwa, eps, Gamma_EM, T_EM, J)
        L_ns = EM.L_nonsecular(H_RC, A_EM, eps, Gamma_EM, T_EM, J=J)
        #L_s = EM.L_vib_lindblad(H_RC, A_EM, eps, Gamma_EM, T_EM, J=J)
        L_n = EM.L_EM_lindblad(eps, A_EM, Gamma_EM, T_EM, J=J)
        for j, state in enumerate(lowest_6):
            method = 'iterative-lgmres'
            data_nrwa[j].append(steadystate(H_RC, [L_RC+L_nrwa]).matrix_element(
                                                                state.dag(), state))
            data_ns[j].append(steadystate(H_RC, [L_RC+L_ns]).matrix_element(
                                                                state.dag(), state))
            data_n[j].append(steadystate(H_RC, [L_RC+L_n]).matrix_element(
                                                                state.dag(), state))
    for i, lab in enumerate(labels):
        plt.figure()
        plt.title(lab)
        plt.plot(prop_couplings, data_nrwa[i], label='nrwa')
        plt.plot(prop_couplings, data_ns[i], label='ns')
        plt.plot(prop_couplings, data_n[i], label='n')
        plt.legend()
        plt.grid()
        plt.ylabel("Population")
        plt.xlabel(r"Phonon Coupling Strength: units of $\epsilon$")
    plt.show()

# %%
couplings = np.linspace(0.001,1.2,45)
steadystate_coupling_dependence(couplings, T_ph, eps, Gamma, w0, 
                                T_EM, Gamma_EM, overdamped=True)
# Out:
# 1
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 30.3258155236 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.594470977783 seconds.
# It took  0.598504066467  seconds to build the Non-secular RWA Liouvillian
# It took  0.00267100334167  seconds to build the electronic-Lindblad Liouvillian
# 2
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 161.183920453 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.596840858459 seconds.
# It took  0.629395008087  seconds to build the Non-secular RWA Liouvillian
# It took  0.00270891189575  seconds to build the electronic-Lindblad Liouvillian
# 3
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 225.922237369 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.603656053543 seconds.
# It took  0.632688999176  seconds to build the Non-secular RWA Liouvillian
# It took  0.00281381607056  seconds to build the electronic-Lindblad Liouvillian
# 4
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 275.864927933 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.596653938293 seconds.
# It took  0.633259057999  seconds to build the Non-secular RWA Liouvillian
# It took  0.00274395942688  seconds to build the electronic-Lindblad Liouvillian
# 5
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 318.059836491 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.605623960495 seconds.
# It took  0.641379833221  seconds to build the Non-secular RWA Liouvillian
# It took  0.00269389152527  seconds to build the electronic-Lindblad Liouvillian
# 6
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 355.278286297 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.601320028305 seconds.
# It took  0.636995077133  seconds to build the Non-secular RWA Liouvillian
# It took  0.00268602371216  seconds to build the electronic-Lindblad Liouvillian
# 7
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 388.951490342 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.60072684288 seconds.
# It took  0.629847049713  seconds to build the Non-secular RWA Liouvillian
# It took  0.0026490688324  seconds to build the electronic-Lindblad Liouvillian
# 8
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 419.933164878 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.611029148102 seconds.
# It took  0.640758037567  seconds to build the Non-secular RWA Liouvillian
# It took  0.00273704528809  seconds to build the electronic-Lindblad Liouvillian
# 9
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 448.781087046 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.605479001999 seconds.
# It took  0.638795852661  seconds to build the Non-secular RWA Liouvillian
# It took  0.00276517868042  seconds to build the electronic-Lindblad Liouvillian
# 10
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 475.883457598 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.608859062195 seconds.
# It took  0.654097795486  seconds to build the Non-secular RWA Liouvillian
# It took  0.00464606285095  seconds to build the electronic-Lindblad Liouvillian
# 11
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 501.523345758 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.610481023788 seconds.
# It took  0.677494049072  seconds to build the Non-secular RWA Liouvillian
# It took  0.00802612304688  seconds to build the electronic-Lindblad Liouvillian
# 12
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 525.914695997 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.607672929764 seconds.
# It took  0.63605093956  seconds to build the Non-secular RWA Liouvillian
# It took  0.00275421142578  seconds to build the electronic-Lindblad Liouvillian
# 13
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 549.223878388 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.604026794434 seconds.
# It took  0.632092952728  seconds to build the Non-secular RWA Liouvillian
# It took  0.00280690193176  seconds to build the electronic-Lindblad Liouvillian
# 14
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 571.583300768 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.604771852493 seconds.
# It took  0.648536920547  seconds to build the Non-secular RWA Liouvillian
# It took  0.00264000892639  seconds to build the electronic-Lindblad Liouvillian
# 15
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 593.100388503 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.606631994247 seconds.
# It took  0.635423898697  seconds to build the Non-secular RWA Liouvillian
# It took  0.00270390510559  seconds to build the electronic-Lindblad Liouvillian
# 16
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 613.863724264 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.614672899246 seconds.
# It took  0.63467502594  seconds to build the Non-secular RWA Liouvillian
# It took  0.00278496742249  seconds to build the electronic-Lindblad Liouvillian
# 17
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 633.947374072 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.602491855621 seconds.
# It took  0.634035110474  seconds to build the Non-secular RWA Liouvillian
# It took  0.00262212753296  seconds to build the electronic-Lindblad Liouvillian
# 18
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 653.414014403 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.601781845093 seconds.
# It took  0.635947942734  seconds to build the Non-secular RWA Liouvillian
# It took  0.00266909599304  seconds to build the electronic-Lindblad Liouvillian
# 19
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 672.317243081 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.609992027283 seconds.
# It took  0.635673999786  seconds to build the Non-secular RWA Liouvillian
# It took  0.00269198417664  seconds to build the electronic-Lindblad Liouvillian
# 20
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 690.703320152 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.604104042053 seconds.
# It took  0.635524988174  seconds to build the Non-secular RWA Liouvillian
# It took  0.00267004966736  seconds to build the electronic-Lindblad Liouvillian
# 21
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 708.61250172 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.607691049576 seconds.
# It took  0.643848896027  seconds to build the Non-secular RWA Liouvillian
# It took  0.00277209281921  seconds to build the electronic-Lindblad Liouvillian
# 22
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 726.080077346 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.610987901688 seconds.
# It took  0.641973018646  seconds to build the Non-secular RWA Liouvillian
# It took  0.00278115272522  seconds to build the electronic-Lindblad Liouvillian
# 23
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 743.137187769 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.610852956772 seconds.
# It took  0.639364004135  seconds to build the Non-secular RWA Liouvillian
# It took  0.00273895263672  seconds to build the electronic-Lindblad Liouvillian
# 24
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 759.811477256 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.609506130219 seconds.
# It took  0.63356590271  seconds to build the Non-secular RWA Liouvillian
# It took  0.002681016922  seconds to build the electronic-Lindblad Liouvillian
# 25
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 776.127619722 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.607154130936 seconds.
# It took  0.628833055496  seconds to build the Non-secular RWA Liouvillian
# It took  0.00268602371216  seconds to build the electronic-Lindblad Liouvillian
# 26
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 792.107747229 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.602909088135 seconds.
# It took  0.63171005249  seconds to build the Non-secular RWA Liouvillian
# It took  0.00275993347168  seconds to build the electronic-Lindblad Liouvillian
# 27
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 807.771802148 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 1.16557908058 seconds.
# It took  0.826325178146  seconds to build the Non-secular RWA Liouvillian
# It took  0.00277590751648  seconds to build the electronic-Lindblad Liouvillian
# 28
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 823.137828964 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.609937906265 seconds.
# It took  0.63025188446  seconds to build the Non-secular RWA Liouvillian
# It took  0.00272989273071  seconds to build the electronic-Lindblad Liouvillian
# 29
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 838.222217909 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.606775045395 seconds.
# It took  0.630216121674  seconds to build the Non-secular RWA Liouvillian
# It took  0.00258994102478  seconds to build the electronic-Lindblad Liouvillian
# 30
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 853.039909806 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.602635860443 seconds.
# It took  0.631850004196  seconds to build the Non-secular RWA Liouvillian
# It took  0.00271320343018  seconds to build the electronic-Lindblad Liouvillian
# 31
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 867.604569402 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.601212024689 seconds.
# It took  0.630971908569  seconds to build the Non-secular RWA Liouvillian
# It took  0.00275897979736  seconds to build the electronic-Lindblad Liouvillian
# 32
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 881.928732933 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.599884986877 seconds.
# It took  0.63529586792  seconds to build the Non-secular RWA Liouvillian
# It took  0.00267291069031  seconds to build the electronic-Lindblad Liouvillian
# 33
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 896.023934445 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.601354837418 seconds.
# It took  0.630131006241  seconds to build the Non-secular RWA Liouvillian
# It took  0.00273203849792  seconds to build the electronic-Lindblad Liouvillian
# 34
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 909.900814498 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.60288310051 seconds.
# It took  0.635000944138  seconds to build the Non-secular RWA Liouvillian
# It took  0.00270509719849  seconds to build the electronic-Lindblad Liouvillian
# 35
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 923.569214163 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.6040391922 seconds.
# It took  0.626857042313  seconds to build the Non-secular RWA Liouvillian
# It took  0.00267314910889  seconds to build the electronic-Lindblad Liouvillian
# 36
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 937.038256676 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.603209972382 seconds.
# It took  0.631615161896  seconds to build the Non-secular RWA Liouvillian
# It took  0.0026068687439  seconds to build the electronic-Lindblad Liouvillian
# 37
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 950.316418673 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.601991891861 seconds.
# It took  0.63751411438  seconds to build the Non-secular RWA Liouvillian
# It took  0.0026421546936  seconds to build the electronic-Lindblad Liouvillian
# 38
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 963.411592584 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.599424123764 seconds.
# It took  0.630466938019  seconds to build the Non-secular RWA Liouvillian
# It took  0.00280714035034  seconds to build the electronic-Lindblad Liouvillian
# 39
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 976.331141494 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.609026193619 seconds.
# It took  0.643526077271  seconds to build the Non-secular RWA Liouvillian
# It took  0.00274395942688  seconds to build the electronic-Lindblad Liouvillian
# 40
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 989.081947553 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.607286930084 seconds.
# It took  0.644043922424  seconds to build the Non-secular RWA Liouvillian
# It took  0.00272607803345  seconds to build the electronic-Lindblad Liouvillian
# 41
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 1001.67045484 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.609377145767 seconds.
# It took  0.638706207275  seconds to build the Non-secular RWA Liouvillian
# It took  0.00274705886841  seconds to build the electronic-Lindblad Liouvillian
# 42
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 1014.10270743 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.60724401474 seconds.
# It took  0.640308141708  seconds to build the Non-secular RWA Liouvillian
# It took  0.00273704528809  seconds to build the electronic-Lindblad Liouvillian
# 43
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 1026.38438333 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.607091903687 seconds.
# It took  0.63431596756  seconds to build the Non-secular RWA Liouvillian
# It took  0.0027289390564  seconds to build the electronic-Lindblad Liouvillian
# 44
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 1038.52082477 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.607855081558 seconds.
# It took  0.636804103851  seconds to build the Non-secular RWA Liouvillian
# It took  0.00263690948486  seconds to build the electronic-Lindblad Liouvillian
# 45
# w_RC= 725.895  TLS splitting = 806.55 RC-res. bath coupling= 2.22172648876  N= 14 TLS-RC coupling= 1050.51706536 Gamma_RC=  10133.145212
# Calculating non-RWA Liouvilliian took 0.608834028244 seconds.
# It took  0.636699914932  seconds to build the Non-secular RWA Liouvillian
# It took  0.0027539730072  seconds to build the electronic-Lindblad Liouvillian

# %% [markdown]
# Although the non-secular and non-RWA

# %% [markdown]
# ## Dynamics of Vibronic States
# Should be able to see the vibronic states being occupied, even if the rates are initially zero?

# %%
def vibronic_state_dynamics(init_sys, init_RC, prop_coupling, eps, Gamma, w0, T_ph=300., T_EM=6000., 
                                    Gamma_EM=1., overdamped=True):
    # Start system+RC in adiabatic eigenstate and then time-evolve
    alpha_ph = prop_coupling*eps

    if overdamped:
        w0 = eps*1.1
        Gamma = w0**2/wc
    
    w = np.linspace(0., eps*1.5, 1000)
    plt.figure()
    plt.plot(w, J_underdamped(w, alpha_ph, Gamma, w0))
    plt.axvline(eps, label='Splitting',color='k')
    plt.ylabel("Coupling Strength")
    plt.xlabel(r"Frequency $cm^{-1}$")
    plt.title("Phonon Spectral Density")
    plt.legend()
    plt.show()
    
    N = 10
    G = ket([0])
    E = ket([1])
    
    sigma = G*E.dag() # Definition of a sigma_- operator.
    J = EM.J_minimal
    count = 1
    
    labels = ['g-0',  'g-1', 'g-2','e-0','e-1', 'e-2'] 
    # This is true for specific Hamiltonian parameters
    colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
    dyn_DATA = []
    
    L_RC, H_RC, A_EM, A_nrwa, wRC, kappa, Gamma= RC.RC_function_UD(sigma, eps, 
                                                                   T_ph, Gamma, 
                                                                   w0, alpha_ph, N)
    evals, states = H_RC.eigenstates()
    ground_list = []
    excited_list = []
    for i in range(len(evals)): #
        is_ground = sum(states[i])[0][0].real == 1.
        if is_ground:
            ground_list.append(i)
        else:
            excited_list.append(i)
    
    if init_sys == 0:
        init_ket = states[ground_list[init_RC]]
    else:
        init_ket = states[excited_list[init_RC]]
    init_rho = init_ket*init_ket.dag()    
    expects_vib = [s*s.dag() for s in states[ground_list[0:3] + excited_list[0:3]]]
    #print len(excited_list), 'excited'
    # electromagnetic bath liouvillians
    L_nrwa = EM.L_non_rwa(H_RC, A_nrwa, eps, Gamma_EM, T_EM, J)
    L_ns = EM.L_nonsecular(H_RC, A_EM, eps, Gamma_EM, T_EM, J=J)
    #L_s = EM.L_vib_lindblad(H_RC, A_EM, eps, Gamma_EM, T_EM, J=J)
    L_n = EM.L_EM_lindblad(eps, A_EM, Gamma_EM, T_EM, J=J)
    Liouvs = [L_nrwa, L_ns, L_n]
    timelist = np.linspace(0,1.,1000)
    for L_EM in Liouvs:
        ti = time.time()
        dyn_DATA.append(mesolve(H_RC, init_rho, timelist, [L_RC+L_EM], expects_vib))
        print "Completed dynamics calculation {} in {} seconds.".format(Liouvs.index(L_EM)+1, time.time()-ti)
        
    for i, lab in enumerate(labels):
        plt.figure()
        
        init_state_final_pop_0 = dyn_DATA[0].expect[(3*init_sys+init_RC)][-1]
        init_state_final_pop_1 = dyn_DATA[1].expect[(3*init_sys+init_RC)][-1]
        init_state_final_pop_2 = dyn_DATA[2].expect[(3*init_sys+init_RC)][-1]
        
        plt.title(lab)
        plt.plot(timelist, dyn_DATA[0].expect[i], label='nrwa')
        plt.plot(timelist, dyn_DATA[1].expect[i], label='ns')
        plt.plot(timelist, dyn_DATA[2].expect[i], label='n')
        
        plt.legend()
        plt.grid()
        plt.ylabel("Population")
        plt.xlabel(r"Time")
        plt.show()
        print "{} state accounts for".format(lab)
        print "NRWA: {:0.4f}%".format(100*(dyn_DATA[0].expect[i][-1]/init_state_final_pop_0))
        print "NS: {:0.4f}%" .format(100*(dyn_DATA[1].expect[i][-1]/init_state_final_pop_1))
        print "Naive: {:0.4f}% of total dynamics".format(100*(dyn_DATA[2].expect[i][-1]/init_state_final_pop_2))

vibronic_state_dynamics(1, 0, 0.2, eps, 0., 0., T_ph=300., T_EM=0., 
                                    Gamma_EM=Gamma_EM, overdamped=True)
# Out:
# w_RC= 887.205  TLS splitting = 806.55 RC-res. bath coupling= 2.66420870351  N= 10 TLS-RC coupling= 474.135610204 Gamma_RC=  14851.5606042
# Calculating non-RWA Liouvilliian took 0.223706960678 seconds.
# It took  0.340162992477  seconds to build the Non-secular RWA Liouvillian
# It took  0.00261306762695  seconds to build the electronic-Lindblad Liouvillian
# Completed dynamics calculation 1 in 21.3969898224 seconds.
# Completed dynamics calculation 2 in 15.4511041641 seconds.
# Completed dynamics calculation 3 in 15.3444809914 seconds.
# g-0 state accounts for
# NRWA: 48.9178%
# NS: 54.3098%
# Naive: 69.9129% of total dynamics
# g-1 state accounts for
# NRWA: 0.7176%
# NS: 0.8532%
# Naive: 1.1146% of total dynamics
# g-2 state accounts for
# NRWA: 0.0108%
# NS: 0.0251%
# Naive: 0.0257% of total dynamics
# e-0 state accounts for
# NRWA: 100.0000%
# NS: 100.0000%
# Naive: 100.0000% of total dynamics
# e-1 state accounts for
# NRWA: 1.3933%
# NS: 1.3670%
# Naive: 1.4191% of total dynamics
# e-2 state accounts for
# NRWA: 0.0190%
# NS: 0.0179%
# Naive: 0.0201% of total dynamics
