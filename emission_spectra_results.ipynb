# %% [markdown]
# # Checking the rigorous RWA: population dynamics and spectra

# %%
import time

from qutip import ket, mesolve, qeye, tensor, thermal_dm, destroy, steadystate
import qutip as qt
import matplotlib.pyplot as plt
import numpy as np
from numpy import pi, sqrt

import UD_liouv as RC
import driving_liouv as EM
import exact_IB as exact
import scipy as sp

import phonon_weak_coupling as WC
from utils import J_overdamped, beta_f, J_underdamped, J_minimal_hard, J_multipolar, ground_and_excited_states, initialise_TLS

import spectra_functions as SF

reload(RC)
reload(EM)
reload(exact)
plt.style.use('ggplot')
plt.rcParams["axes.grid"] = True
plt.rcParams["axes.edgecolor"] = "0.15"
plt.rcParams["axes.linewidth"]  = 1.25
plt.rcParams['axes.facecolor'] = 'white'
plt.rcParams['font.size'] = 13
plt.rcParams['legend.fontsize'] = 'large'
plt.rcParams['figure.titlesize'] = 'medium'

# Things that will always be true
ev_to_inv_cm = 8065.5
inv_ps_to_inv_cm = 5.309
G = ket([0])
E = ket([1])
sigma = G*E.dag() # Definition of a sigma_- operator.
J_EM = J_multipolar#EM.J_minimal

# %%
reload(RC)
reload(EM)
nTimeSteps = 1000
timelist = np.linspace(0, 0.60, nTimeSteps)
from qutip import basis
def dynamics_plotter(eps=1000., T_ph=300., w0_prop=0.1, alpha_prop=0.1, 
                     Gamma_prop=0.1, T_EM=0., Gamma_EM_prop=0.005, N = 25):
    
    Gamma, w0, alpha_ph, Gamma_EM = Gamma_prop*eps, w0_prop*eps, alpha_prop*eps/pi, Gamma_EM_prop*eps
    L_RC, H_RC, A_EM, A_nrwa, _, _, _, _ = RC.RC_function_UD(sigma, eps, T_ph, Gamma, w0, alpha_ph, N)
    S_plus, S_minus, S_0 = EM.RWA_system_ops(H_RC, A_nrwa)
    k_test = tensor(basis(2,1), basis(N,0))
    hh,hhh =  S_minus*k_test, A_EM*k_test
    L_nrwa = EM.L_non_rwa(H_RC, A_nrwa, eps, Gamma_EM, T_EM, J=J_EM)
    L_vib_ns = EM.L_nonsecular(H_RC, S_minus, eps, Gamma_EM, T_EM, J=J_EM).tidyup(atol=1E-9)
    L_vib_s = EM.L_vib_lindblad(H_RC, S_minus, eps, Gamma_EM, T_EM, J=J_EM).tidyup(atol=1E-9)
    L_em_ns = EM.L_nonsecular(H_RC, A_EM, eps, Gamma_EM, T_EM, J=J_EM, silent=True).tidyup(atol=1E-9)
    L_em_s = EM.L_vib_lindblad(H_RC, A_EM, eps, Gamma_EM, T_EM, J=J_EM, silent=True).tidyup(atol=1E-9)
    
    L_em = EM.L_EM_lindblad(eps, A_EM, Gamma_EM, T_EM, J_EM, silent=True)
    expects = [tensor(G*G.dag(), qeye(N)), tensor(E*G.dag()+G*E.dag(), qeye(N)), 
                   tensor(E*E.dag(), qeye(N)), tensor(qeye(2), destroy(N).dag()*destroy(N)), 
                   tensor(qeye(2), destroy(N).dag()+destroy(N))]
    n_RC = EM.Occupation(w0, T_ph)
    rho_0 = tensor(E*E.dag(), thermal_dm(N, n_RC))
    #DATA_wc = mesolve(H_S, initial_sys, timelist, [L_wc], expects_wc, progress_bar=True)
    #print H_RC.eigenenergies()
    #print eps-0.5*np.pi*alpha, eps+w0, eps-0.5*np.pi*alpha+w0
    DATA_rig = mesolve(H_RC, rho_0, timelist, [L_RC+L_vib_ns], 
                          expects, options=qt.Options(nsteps=1000), progress_bar=True).expect[2].real
    DATA_nrwa = mesolve(H_RC, rho_0, timelist, [L_RC+L_nrwa], 
                          expects, options=qt.Options(nsteps=1000), progress_bar=True).expect[2].real
    
    DATA_rigsec = mesolve(H_RC, rho_0, timelist, [L_RC+L_vib_s], 
                          expects, options=qt.Options(nsteps=1000)).expect[2].real
    DATA_nonrig = mesolve(H_RC, rho_0, timelist, [L_RC+L_em_ns], 
                          expects, options=qt.Options(nsteps=1000)).expect[2].real
    DATA_ESA = mesolve(H_RC, rho_0, timelist, [L_RC+L_em], 
                          expects, options=qt.Options(nsteps=1000)).expect[2].real
    #DATA_nonrig_sec = mesolve(H_RC, rho_0, timelist, [L_RC+L_em_s], 
    #                      expects, options=qt.Options(nsteps=1000)).expect[2].real
    plt.figure(figsize=(10,6))
    plt.plot(timelist, DATA_nrwa, label='Full', ls='dashed', linewidth=1.6)
    plt.plot(timelist, DATA_rig, label='RWA', linewidth=1.)
    plt.plot(timelist, DATA_rigsec, label='RWA sec', ls='dashed',linewidth=1.0)
    plt.plot(timelist, DATA_nonrig, label='naive RWA')
    plt.plot(timelist, DATA_ESA, label='Additive')
    plt.xlim(timelist[0], timelist[-1])
    plt.plot(timelist, DATA_nonrig, label='naive RWA sec', ls='dashed', linewidth=1.6)
    plt.legend(loc='best')
    plt.ylabel('Ground Population')
    plt.xlabel('Time')
    plt.figure(figsize=(10,6))
    plt.plot(timelist, DATA_nrwa, label='non RWA', ls='dashed', linewidth=1.6)
    plt.plot(timelist, DATA_rig, label='RWA', linewidth=1.)
    plt.plot(timelist, DATA_rigsec, label='RWA sec', ls='dashed',linewidth=1.0)
    plt.plot(timelist, DATA_nonrig, label='naive RWA')
    plt.plot(timelist, DATA_ESA, label='naive ESA')
    plt.ylim(0.6, 1.)
    plt.xlim(0.,0.075)
    #plt.plot(timelist, DATA_nonrig, label='naive RWA sec', ls='dashed', linewidth=1.6)
    plt.legend(loc='best')
    plt.ylabel('Ground Population')
    plt.xlabel('Time')
    plt.figure(figsize=(10,6))
    plt.plot(timelist, DATA_nrwa, label='non RWA', ls='dashed', linewidth=1.6)
    plt.plot(timelist, DATA_rig, label='RWA', linewidth=1.)
    plt.plot(timelist, DATA_rigsec, label='RWA sec', ls='dashed',linewidth=1.0)
    plt.plot(timelist, DATA_nonrig, label='naive RWA')
    plt.plot(timelist, DATA_ESA, label='naive ESA')
    #plt.plot(timelist, DATA_nonrig, label='naive RWA sec', ls='dashed', linewidth=1.6)
    plt.legend(loc='best')
    plt.xlim(timelist[-1]-0.2,timelist[-1])
    plt.ylabel('Excited Population')
    plt.xlabel('Time')
    
    plt.show()
    return L_nrwa
    
#dynamics_plotter(alpha_prop=0.2, w0_prop=0.99, N=12)
#L = dynamics_plotter(alpha_prop=0.001, w0_prop=0.1, N=10)
L = dynamics_plotter(alpha_prop=0.3, w0_prop=1.7, N=10, T_EM=0.)
# Out:
# w_RC=1700.0 | TLS splitting = 1000.0 | RC-res. coupling=0.01 | TLS-RC coupling=504.98 | Gamma_RC=100.00 | alpha_ph=95.49 | N=10 |
# Calculating non-RWA Liouvilliian took 0.248788118362 seconds.
# It took  0.440153837204  seconds to build the Non-secular RWA Liouvillian
# It took  0.642031908035  seconds to build the vibronic Lindblad Liouvillian
# 10.0%. Run time:   0.46s. Est. time left: 00:00:00:04
# 20.0%. Run time:   0.77s. Est. time left: 00:00:00:03
# 30.0%. Run time:   1.10s. Est. time left: 00:00:00:02
# 40.0%. Run time:   1.43s. Est. time left: 00:00:00:02
# 50.0%. Run time:   1.75s. Est. time left: 00:00:00:01
# 60.0%. Run time:   2.07s. Est. time left: 00:00:00:01
# 70.0%. Run time:   2.41s. Est. time left: 00:00:00:01
# 80.0%. Run time:   2.73s. Est. time left: 00:00:00:00
# 90.0%. Run time:   3.08s. Est. time left: 00:00:00:00
# Total run time:   3.39s
# 10.0%. Run time:   0.19s. Est. time left: 00:00:00:01
# 20.0%. Run time:   0.38s. Est. time left: 00:00:00:01
# 30.0%. Run time:   0.57s. Est. time left: 00:00:00:01
# 40.0%. Run time:   0.78s. Est. time left: 00:00:00:01
# 50.0%. Run time:   0.97s. Est. time left: 00:00:00:00
# 60.0%. Run time:   1.19s. Est. time left: 00:00:00:00
# 70.0%. Run time:   1.47s. Est. time left: 00:00:00:00
# 80.0%. Run time:   1.67s. Est. time left: 00:00:00:00
# 90.0%. Run time:   1.87s. Est. time left: 00:00:00:00
# Total run time:   2.06s

# %% [markdown]
# # RWA on the RC-residual bath interaction
#
# We have $H_I(t) = A(t)\otimes B(T)$ where $A(t) = I_{S}\otimes (a^{\dagger} + a)$ which means that we can perform a RWA and on this Hamiltonian. As a first approximation I can just use the old code for calculating the optical liouvillians and chuck in my own spectral densities. It does pretty badly - particularly for low frequency modes. Could be worth going back to the maths and having a look if there's anything missing.

# %%
def RC_residual_RWA_dynamics_plotter(eps=1000., T_ph=300., w0_prop=0.1, alpha_prop=0.1, 
                     Gamma_prop=0.1, T_EM=0., Gamma_EM_prop=0.005, N = 25):
    
    Gamma, w0, alpha_ph, Gamma_EM = Gamma_prop*eps, w0_prop*eps, alpha_prop*eps, Gamma_EM_prop*eps
    L_RC, H_RC, A_EM, A_nrwa, Z, _, _, _ = RC.RC_function_UD(sigma, eps, T_ph, Gamma, w0, alpha_ph, N)
    c_RC = destroy(N)
    A_ph = tensor(qeye(2), c_RC+c_RC.dag())
    C_plus, C_minus, S_0 = EM.RWA_system_ops(H_RC, A_ph)
    Gamma_RC_res = Gamma / (2. * np.pi * w0)
    def J_RC(x, g, _):
        return g*x
    L_RC_ns = EM.L_nonsecular(H_RC, C_minus, eps, Gamma_RC_res, T_ph, J=J_RC)
    L_RC_s = EM.L_vib_lindblad(H_RC, C_minus, eps, Gamma_RC_res, T_ph, J=J_RC)
    #L_RC_fs = EM.L_full_secular(H_RC, C_minus, eps, Gamma_RC_res, T_ph, J=J_RC)
    expects = [tensor(G*G.dag(), qeye(N)), tensor(E*G.dag()+G*E.dag(), qeye(N)), 
                   tensor(E*E.dag(), qeye(N)), tensor(qeye(2), destroy(N).dag()*destroy(N)), 
                   tensor(qeye(2), destroy(N).dag()+destroy(N))]
    n_RC = EM.Occupation(w0, T_ph)
    rho_0 = tensor(0.5*(G*E.dag()+E*G.dag()), thermal_dm(N, n_RC))
    timelist = np.linspace(0,0.05,300)
    DATA_1 = mesolve(H_RC, rho_0, timelist, [L_RC], 
                          expects, options=qt.Options(nsteps=1000)).expect[1].real
    DATA_2 = mesolve(H_RC, rho_0, timelist, [L_RC_ns], 
                          expects, options=qt.Options(nsteps=1000)).expect[1].real
    DATA_3 = mesolve(H_RC, rho_0, timelist, [L_RC_s], 
                          expects, options=qt.Options(nsteps=1000)).expect[1].real
    #DATA_4 = mesolve(H_RC, rho_0, timelist, [L_RC_fs], 
    #                      expects, options=qt.Options(nsteps=1000), progress_bar=True).expect[1].real
    plt.figure(figsize=(10,6))
    plt.plot(timelist, DATA_1, label='Full RC', ls='dashed', linewidth=1.6)
    plt.plot(timelist, DATA_2, label='non-sec RC', linewidth=1.)
    plt.plot(timelist, DATA_3, label='sec RC', ls='dashed',linewidth=1.0)
    #plt.plot(timelist, DATA_4, label='proper sec RC')
    plt.legend(loc='best')
    plt.ylabel('Ground Population')
    plt.xlabel('Time')
    plt.show()

RC_residual_RWA_dynamics_plotter(T_ph=100., alpha_prop=0.2, w0_prop=0.99,Gamma_prop=0.1, N=15)
RC_residual_RWA_dynamics_plotter(T_ph=100., alpha_prop=0.2, w0_prop=0.99,Gamma_prop=0.2, N=15)
RC_residual_RWA_dynamics_plotter(T_ph=100., alpha_prop=0.2, w0_prop=0.1,Gamma_prop=0.2, N=20)
# Out:
# w_RC=990.0 | TLS splitting = 1000.0 | RC-res. coupling=0.02 | TLS-RC coupling=557.69 | Gamma_RC=100.00 | alpha_ph=200.00 | N=15 |
# It took  1.19549107552  seconds to build the Non-secular RWA Liouvillian
# It took  2.46312189102  seconds to build the vibronic Lindblad Liouvillian
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-5119f3d3b3be> in <module>()
#      37     plt.show()
#      38
# ---> 39 RC_residual_RWA_dynamics_plotter(T_ph=100., alpha_prop=0.2, w0_prop=0.99,Gamma_prop=0.1, N=15)
#      40 RC_residual_RWA_dynamics_plotter(T_ph=100., alpha_prop=0.2, w0_prop=0.99,Gamma_prop=0.2, N=15)
#      41 RC_residual_RWA_dynamics_plotter(T_ph=100., alpha_prop=0.2, w0_prop=0.1,Gamma_prop=0.2, N=20)
#
# <ipython-input-2-5119f3d3b3be> in RC_residual_RWA_dynamics_plotter(eps, T_ph, w0_prop, alpha_prop, Gamma_prop, T_EM, Gamma_EM_prop, N)
#      35     plt.ylabel('Ground Population')
#      36     plt.xlabel('Time')
# ---> 37     plt.show()
#      38
#      39 RC_residual_RWA_dynamics_plotter(T_ph=100., alpha_prop=0.2, w0_prop=0.99,Gamma_prop=0.1, N=15)
#
# /home/henry/anaconda2/envs/qutip/lib/python2.7/site-packages/matplotlib/pyplot.pyc in show(*args, **kw)
#     251     """
#     252     global _show
# --> 253     return _show(*args, **kw)
#     254
#     255
#
# /home/henry/anaconda2/envs/qutip/lib/python2.7/site-packages/ipykernel/pylab/backend_inline.pyc in show(close, block)
#      34     try:
#      35         for figure_manager in Gcf.get_all_fig_managers():
# ---> 36             display(figure_manager.canvas.figure)
#      37     finally:
#      38         show._to_draw = []
#
# /home/henry/anaconda2/envs/qutip/lib/python2.7/site-packages/IPython/core/display.pyc in display(*objs, **kwargs)
#     162             publish_display_data(data=obj, metadata=metadata)
#     163         else:
# --> 164             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     165             if not format_dict:
#     166                 # nothing to display (e.g. _ipython_display_ took over)
#
# /home/henry/anaconda2/envs/qutip/lib/python2.7/site-packages/IPython/core/formatters.pyc in format(self, obj, include, exclude)
#     143             md = None
#     144             try:
# --> 145                 data = formatter(obj)
#     146             except:
#     147                 # FIXME: log the exception
#
# <decorator-gen-9> in __call__(self, obj)
#
# /home/henry/anaconda2/envs/qutip/lib/python2.7/site-packages/IPython/core/formatters.pyc in catch_format_error(method, self, *args, **kwargs)
#     188     """show traceback on failed format call"""
#     189     try:
# --> 190         r = method(self, *args, **kwargs)
#     191     except NotImplementedError:
#     192         # don't warn on NotImplementedErrors
#
# /home/henry/anaconda2/envs/qutip/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     305                 pass
#     306             else:
# --> 307                 return printer(obj)
#     308             # Finally look for special method names
#     309             method = get_real_method(obj, self.print_method)
#
# /home/henry/anaconda2/envs/qutip/lib/python2.7/site-packages/IPython/core/pylabtools.pyc in <lambda>(fig)
#     238
#     239     if 'png' in formats:
# --> 240         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     241     if 'retina' in formats or 'png2x' in formats:
#     242         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /home/henry/anaconda2/envs/qutip/lib/python2.7/site-packages/IPython/core/pylabtools.pyc in print_figure(fig, fmt, bbox_inches, **kwargs)
#     122
#     123     bytes_io = BytesIO()
# --> 124     fig.canvas.print_figure(bytes_io, **kw)
#     125     data = bytes_io.getvalue()
#     126     if fmt == 'svg':
#
# /home/henry/anaconda2/envs/qutip/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2190                     orientation=orientation,
#    2191                     dryrun=True,
# -> 2192                     **kwargs)
#    2193                 renderer = self.figure._cachedRenderer
#    2194                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# /home/henry/anaconda2/envs/qutip/lib/python2.7/site-packages/matplotlib/backends/backend_agg.pyc in print_png(self, filename_or_obj, *args, **kwargs)
#     554
#     555         try:
# --> 556             _png.write_png(renderer._renderer, filename_or_obj, self.figure.dpi)
#     557         finally:
#     558             if close:
#
# KeyboardInterrupt:

# %%
reload(SF)
def power_emitted(spec):
    return sum(spec[0]), sum(spec[1])

def power_emitted_vs_T(alpha_prop, eps, Gamma, w0_prop=0.1, T_EM=0., 
                         Gamma_EM=Gamma_EM, overdamped=False, 
                         N=12, end_T_mult=7., rotating=False, 
                         tau_f_mult=2.5, T_increments=20, 
                         nsteps=3000, method='bdf', order=5):
    powers = []
    T_values = [20., 30., 50, 77., 120., 200., 300.]
    for T in T_values:
        times, pops, taus, g1, specs, freqs = SF.emission_spectra(2, 0, alpha_prop, eps, Gamma, 
                                                     w0_prop=w0_prop, T_ph=T, T_EM=0., 
                                                     Gamma_EM=Gamma_EM, overdamped=overdamped, 
                                                     N=N, end_T_mult=end_T_mult, rotating=rotating, 
                                                     tau_f_mult=tau_f_mult, T_increments=T_increments, 
                                                     nsteps=nsteps, method=method, 
                                                    order=order, normalise=False, silent=True)
        powers.append(power_emitted(specs))
    powers = zip(*powers)
    naPower = np.array(powers[0])/powers[0][0]
    aPower = np.array(powers[1])/powers[1][0]
    return T_values, naPower, aPower

eps = 8000.
w0_prop = 400/eps
alpha_prop = pi*800/eps
Gamma = 80.
Gamma_EM = (10/100.)/inv_ps_to_inv_cm

T, naP, aP = power_emitted_vs_T(alpha_prop, eps, Gamma, 
                       w0_prop=w0_prop, T_ph=300., T_EM=0., 
                       Gamma_EM=Gamma_EM, overdamped=False, 
                       N=10, end_T_mult=7., rotating=True, 
                       tau_f_mult=2.5, T_increments=9, 
                       nsteps=3000, method='bdf', order=5)
# Out:
# w_RC=400.0 | TLS splitting = 8000.0 | RC-res. coupling=0.03 | TLS-RC coupling=708.98 | Gamma_RC=80.00 | alpha_ph=800.00 | N=10 |
# final t:  371.63
# 10.0%. Run time:  44.05s. Est. time left: 00:00:06:35
# 20.0%. Run time:  88.08s. Est. time left: 00:00:05:52
# 30.0%. Run time: 126.79s. Est. time left: 00:00:04:55
# 40.0%. Run time: 165.84s. Est. time left: 00:00:04:08
# 50.0%. Run time: 203.16s. Est. time left: 00:00:03:23
# 60.0%. Run time: 241.08s. Est. time left: 00:00:02:40
# 70.0%. Run time: 281.43s. Est. time left: 00:00:02:00
# 80.0%. Run time: 320.86s. Est. time left: 00:00:01:20
# 90.0%. Run time: 358.65s. Est. time left: 00:00:00:39
# Total run time: 395.22s
# Completed initial dynamics calculations for Full in 395.633387804  seconds.
# Completed correlation function calculations for Full in 8.38924694061 seconds.
# 10.0%. Run time:  41.34s. Est. time left: 00:00:06:11
# 20.0%. Run time:  78.97s. Est. time left: 00:00:05:15
# 30.0%. Run time: 117.27s. Est. time left: 00:00:04:33
# 40.0%. Run time: 154.11s. Est. time left: 00:00:03:51
# 50.0%. Run time: 190.34s. Est. time left: 00:00:03:10
# 60.0%. Run time: 227.53s. Est. time left: 00:00:02:31
# 70.0%. Run time: 262.59s. Est. time left: 00:00:01:52
# 80.0%. Run time: 297.94s. Est. time left: 00:00:01:14
# 90.0%. Run time: 333.66s. Est. time left: 00:00:00:37
# Total run time: 368.32s
# Completed initial dynamics calculations for Naive in 369.219878912  seconds.
# Completed correlation function calculations for Naive in 8.56296896935 seconds.
# w_RC=400.0 | TLS splitting = 8000.0 | RC-res. coupling=0.03 | TLS-RC coupling=708.98 | Gamma_RC=80.00 | alpha_ph=800.00 | N=10 |
# final t:  371.63
# 10.0%. Run time:  42.46s. Est. time left: 00:00:06:21
# 20.0%. Run time:  80.14s. Est. time left: 00:00:05:20
# 30.0%. Run time: 119.74s. Est. time left: 00:00:04:39
# 40.0%. Run time: 161.40s. Est. time left: 00:00:04:01
# 50.0%. Run time: 201.44s. Est. time left: 00:00:03:21
# 60.0%. Run time: 242.53s. Est. time left: 00:00:02:41
# 70.0%. Run time: 281.43s. Est. time left: 00:00:02:00
# 80.0%. Run time: 319.48s. Est. time left: 00:00:01:19
# 90.0%. Run time: 369.65s. Est. time left: 00:00:00:41
# Total run time: 427.30s
# Completed initial dynamics calculations for Full in 427.920281887  seconds.
# Completed correlation function calculations for Full in 20.7855360508 seconds.
# 10.0%. Run time:  38.65s. Est. time left: 00:00:05:47
# 20.0%. Run time:  80.25s. Est. time left: 00:00:05:20
# 30.0%. Run time: 123.74s. Est. time left: 00:00:04:48
# 40.0%. Run time: 170.13s. Est. time left: 00:00:04:15
# 50.0%. Run time: 215.63s. Est. time left: 00:00:03:35
# 60.0%. Run time: 258.35s. Est. time left: 00:00:02:52
# 70.0%. Run time: 300.39s. Est. time left: 00:00:02:08
# 80.0%. Run time: 343.98s. Est. time left: 00:00:01:25
# 90.0%. Run time: 385.65s. Est. time left: 00:00:00:42
# Total run time: 428.95s
# Completed initial dynamics calculations for Naive in 429.903060198  seconds.
# Completed correlation function calculations for Naive in 12.4764311314 seconds.
# w_RC=400.0 | TLS splitting = 8000.0 | RC-res. coupling=0.03 | TLS-RC coupling=708.98 | Gamma_RC=80.00 | alpha_ph=800.00 | N=10 |
# final t:  371.63
# 10.0%. Run time:  46.05s. Est. time left: 00:00:06:53
# 20.0%. Run time:  89.53s. Est. time left: 00:00:05:57
# 30.0%. Run time: 134.17s. Est. time left: 00:00:05:12
# 40.0%. Run time: 182.11s. Est. time left: 00:00:04:33
# 50.0%. Run time: 229.64s. Est. time left: 00:00:03:49
# 60.0%. Run time: 278.15s. Est. time left: 00:00:03:05
# 70.0%. Run time: 322.31s. Est. time left: 00:00:02:18
# 80.0%. Run time: 373.27s. Est. time left: 00:00:01:33
# 90.0%. Run time: 419.00s. Est. time left: 00:00:00:46
# Total run time: 463.55s
# Completed initial dynamics calculations for Full in 464.045312166  seconds.
# Completed correlation function calculations for Full in 14.7242910862 seconds.
# 10.0%. Run time:  43.07s. Est. time left: 00:00:06:26
# 20.0%. Run time:  85.25s. Est. time left: 00:00:05:40
# 30.0%. Run time: 129.17s. Est. time left: 00:00:05:01
# 40.0%. Run time: 174.89s. Est. time left: 00:00:04:22
# 50.0%. Run time: 218.57s. Est. time left: 00:00:03:38
# 60.0%. Run time: 261.28s. Est. time left: 00:00:02:54
# 70.0%. Run time: 303.40s. Est. time left: 00:00:02:09
# 80.0%. Run time: 344.20s. Est. time left: 00:00:01:25
# 90.0%. Run time: 387.01s. Est. time left: 00:00:00:42
# Total run time: 428.56s
# Completed initial dynamics calculations for Naive in 429.140463114  seconds.
# Completed correlation function calculations for Naive in 12.1763558388 seconds.
# w_RC=400.0 | TLS splitting = 8000.0 | RC-res. coupling=0.03 | TLS-RC coupling=708.98 | Gamma_RC=80.00 | alpha_ph=800.00 | N=10 |
# final t:  371.63
# 10.0%. Run time:  18.67s. Est. time left: 00:00:02:47
# 20.0%. Run time:  39.08s. Est. time left: 00:00:02:36
# 30.0%. Run time:  58.65s. Est. time left: 00:00:02:16
# 40.0%. Run time:  77.15s. Est. time left: 00:00:01:55
# 50.0%. Run time:  97.09s. Est. time left: 00:00:01:37
# 60.0%. Run time: 115.45s. Est. time left: 00:00:01:16
# 70.0%. Run time: 135.19s. Est. time left: 00:00:00:57
# 80.0%. Run time: 153.75s. Est. time left: 00:00:00:38
# 90.0%. Run time: 172.68s. Est. time left: 00:00:00:19
# Total run time: 193.12s
# Completed initial dynamics calculations for Full in 193.593494892  seconds.
# Completed correlation function calculations for Full in 11.2917981148 seconds.
# 10.0%. Run time:  20.27s. Est. time left: 00:00:03:02
# 20.0%. Run time:  42.49s. Est. time left: 00:00:02:49
# 30.0%. Run time:  62.49s. Est. time left: 00:00:02:25
# 40.0%. Run time:  82.91s. Est. time left: 00:00:02:04
# 50.0%. Run time: 102.51s. Est. time left: 00:00:01:42
# 60.0%. Run time: 123.28s. Est. time left: 00:00:01:22
# 70.0%. Run time: 142.31s. Est. time left: 00:00:01:00
# 80.0%. Run time: 163.32s. Est. time left: 00:00:00:40
# 90.0%. Run time: 182.42s. Est. time left: 00:00:00:20
# Total run time: 202.58s
# Completed initial dynamics calculations for Naive in 203.089950085  seconds.
# Completed correlation function calculations for Naive in 11.5252408981 seconds.
# w_RC=400.0 | TLS splitting = 8000.0 | RC-res. coupling=0.03 | TLS-RC coupling=708.98 | Gamma_RC=80.00 | alpha_ph=800.00 | N=10 |
# final t:  371.63
# 10.0%. Run time:  17.42s. Est. time left: 00:00:02:36
# 20.0%. Run time:  36.27s. Est. time left: 00:00:02:25
# 30.0%. Run time:  53.85s. Est. time left: 00:00:02:05
# 40.0%. Run time:  71.18s. Est. time left: 00:00:01:46
# 50.0%. Run time:  90.83s. Est. time left: 00:00:01:30
# 60.0%. Run time: 112.07s. Est. time left: 00:00:01:14
# 70.0%. Run time: 131.89s. Est. time left: 00:00:00:56
# 80.0%. Run time: 151.67s. Est. time left: 00:00:00:37
# 90.0%. Run time: 171.85s. Est. time left: 00:00:00:19
# Total run time: 192.08s
# Completed initial dynamics calculations for Full in 192.779157877  seconds.
# Completed correlation function calculations for Full in 12.2674109936 seconds.
# 10.0%. Run time:  21.64s. Est. time left: 00:00:03:14
# 20.0%. Run time:  39.26s. Est. time left: 00:00:02:36
# 30.0%. Run time:  57.94s. Est. time left: 00:00:02:15
# 40.0%. Run time:  76.47s. Est. time left: 00:00:01:54
# 50.0%. Run time:  95.07s. Est. time left: 00:00:01:35
# 60.0%. Run time: 115.02s. Est. time left: 00:00:01:16
# 70.0%. Run time: 132.50s. Est. time left: 00:00:00:56
# 80.0%. Run time: 151.91s. Est. time left: 00:00:00:37
# 90.0%. Run time: 171.72s. Est. time left: 00:00:00:19
# Total run time: 195.53s
# Completed initial dynamics calculations for Naive in 196.024982929  seconds.
# Completed correlation function calculations for Naive in 10.8324489594 seconds.
# w_RC=400.0 | TLS splitting = 8000.0 | RC-res. coupling=0.03 | TLS-RC coupling=708.98 | Gamma_RC=80.00 | alpha_ph=800.00 | N=10 |
# final t:  371.63
# 10.0%. Run time:  61.11s. Est. time left: 00:00:09:08
# 20.0%. Run time: 103.14s. Est. time left: 00:00:06:52
# 30.0%. Run time: 147.42s. Est. time left: 00:00:05:43
# 40.0%. Run time: 198.27s. Est. time left: 00:00:04:57
# 50.0%. Run time: 252.06s. Est. time left: 00:00:04:12
# 60.0%. Run time: 295.13s. Est. time left: 00:00:03:16
# 70.0%. Run time: 342.31s. Est. time left: 00:00:02:26
# 80.0%. Run time: 385.24s. Est. time left: 00:00:01:36
# 90.0%. Run time: 427.61s. Est. time left: 00:00:00:47
# Total run time: 469.53s
# Completed initial dynamics calculations for Full in 469.986800909  seconds.
# Completed correlation function calculations for Full in 11.5644171238 seconds.
# 10.0%. Run time:  39.91s. Est. time left: 00:00:05:58
# 20.0%. Run time:  83.90s. Est. time left: 00:00:05:35
# 30.0%. Run time: 127.10s. Est. time left: 00:00:04:56
# 40.0%. Run time: 184.24s. Est. time left: 00:00:04:36
# 50.0%. Run time: 223.67s. Est. time left: 00:00:03:43
# 60.0%. Run time: 265.35s. Est. time left: 00:00:02:56
# 70.0%. Run time: 314.26s. Est. time left: 00:00:02:14
# 80.0%. Run time: 366.58s. Est. time left: 00:00:01:31
# 90.0%. Run time: 406.93s. Est. time left: 00:00:00:45
# Total run time: 447.47s
# Completed initial dynamics calculations for Naive in 448.023159027  seconds.
# Completed correlation function calculations for Naive in 12.5067260265 seconds.
# w_RC=400.0 | TLS splitting = 8000.0 | RC-res. coupling=0.03 | TLS-RC coupling=708.98 | Gamma_RC=80.00 | alpha_ph=800.00 | N=10 |
# final t:  371.63
# 10.0%. Run time:  49.41s. Est. time left: 00:00:07:23
# 20.0%. Run time:  88.47s. Est. time left: 00:00:05:53
# 30.0%. Run time: 134.54s. Est. time left: 00:00:05:13
# 40.0%. Run time: 185.61s. Est. time left: 00:00:04:38
# 50.0%. Run time: 245.35s. Est. time left: 00:00:04:05
# 60.0%. Run time: 298.57s. Est. time left: 00:00:03:18
# 70.0%. Run time: 361.40s. Est. time left: 00:00:02:34
# 80.0%. Run time: 400.75s. Est. time left: 00:00:01:40
# 90.0%. Run time: 435.22s. Est. time left: 00:00:00:48
# Total run time: 470.21s
# Completed initial dynamics calculations for Full in 470.603878975  seconds.
# Completed correlation function calculations for Full in 9.42375206947 seconds.
# 10.0%. Run time:  32.13s. Est. time left: 00:00:04:48
# 20.0%. Run time:  64.10s. Est. time left: 00:00:04:16
# 30.0%. Run time:  96.62s. Est. time left: 00:00:03:45
# 40.0%. Run time: 129.66s. Est. time left: 00:00:03:14
# 50.0%. Run time: 170.51s. Est. time left: 00:00:02:50
# 60.0%. Run time: 206.71s. Est. time left: 00:00:02:17
# 70.0%. Run time: 243.06s. Est. time left: 00:00:01:44
# 80.0%. Run time: 279.56s. Est. time left: 00:00:01:09
# 90.0%. Run time: 316.38s. Est. time left: 00:00:00:35
# Total run time: 352.99s
# Completed initial dynamics calculations for Naive in 353.491581917  seconds.
# Completed correlation function calculations for Naive in 10.9211900234 seconds.

# %%
plt.plot(T[2:], naP[2:], color='r')
plt.plot(T[2:], aP[2:], color='b')
plt.xlabel("Temperature (K)")
plt.ylabel("Intensity (arb units)")
plt.show()

# %%
def power_emitted(init_sys, init_RC, prop_coupling, eps, Gamma, w0_prop=2.1,
                    T_ph=300., T_EM=0.,Gamma_EM=1., overdamped=False, N=9,
                    end_T_mult=10,  rotating=False,
                    T_increments=9, nsteps=2000, method='adams', order=12,
                    normalise=True, silent=False
                    ):
    # Start system+RC in adiabatic eigenstate and then time-evolve
    alpha_ph = prop_coupling*eps/pi
    w0 = eps*w0_prop
    if overdamped:
        wc = 53.
        Gamma = (w0**2)/wc
    if not silent:
        w = np.linspace(0., eps*1.5, 1000)
        plt.figure()
        plt.plot(w, J_underdamped(w, alpha_ph, Gamma, w0))
        plt.axvline(eps, label='Splitting',color='k')
        plt.ylabel("Coupling Strength")
        plt.xlabel(r"Frequency $cm^{-1}$")
        plt.title("Phonon Spectral Density")
        plt.legend()
        plt.show()
    G, E = ket([0]), ket([1])
    sigma = G*E.dag() # Definition of a sigma_- operator.
    J = J_multipolar
    count = 1
    I_RC = qt.qeye(N)
    # This is true for specific Hamiltonian parameters

    L_RC, H_RC, A_EM, A_nrwa, Z, wRC, kappa, Gamma= RC.RC_function_UD(sigma, eps,
                                                        T_ph, Gamma,
                                                        w0, alpha_ph,
                                                        N, rotating=rotating)
    H_RC_opt = RC.Ham_RC(sigma, eps, w0, kappa, N, rotating=False)[0]
    evals, states = H_RC.eigenstates()
    ground_list, excited_list = ground_and_excited_states(states)
    # work out how to initialise system rho
    init_rho = initialise_TLS(init_sys, init_RC, states, w0, T_ph)

    # electromagnetic bath liouvillians
    final_t = end_T_mult/Gamma_EM
    print "final t: ", final_t
    timelist = np.linspace(0, final_t, int(T_increments*final_t))
    options = qt.Options(nsteps=nsteps, store_states=True, 
                                method=method, order=order)
    E_op = tensor(E*E.dag(), I_RC)
    #
    power_list = []
    
    #EM.L_non_rwa(H_RC_opt, A_nrwa, eps, Gamma_EM, T_EM, J, silent=True)]
    label = [ 'Full','Naive']
    for i, L_EM in enumerate([EM.L_non_rwa(H_RC_opt, A_nrwa, eps, Gamma_EM,
                            T_EM, J, silent=True),
                             EM.L_EM_lindblad(eps, A_EM, Gamma_EM, T_EM,
                             J=J, silent=True)]):
        ti = time.time()
        sigma_RC = tensor(sigma, I_RC)

        if i==0:
            sigma_plus_RC, sigma_RC, sigma_0_RC = EM.RWA_system_ops(H_RC_opt,
                                                tensor(sigma+sigma.dag(), I_RC))
        P = mesolve(H_RC, init_rho, timelist, [L_RC+L_EM], progress_bar=True,
                                                        options=options).states
        pop = [((E_op*p).tr()).real for p in P]
        power_list.append(sum(pop))
    return power_list

def power_emitted_vs_T(alpha_prop, eps, Gamma, w0_prop=0.1, T_EM=0., 
                         Gamma_EM=Gamma_EM, overdamped=False, 
                         N=12, end_T_mult=7., rotating=False, 
                         tau_f_mult=2.5, T_increments=20, 
                         nsteps=3000, method='bdf', order=5):
    powers = []
    T_values = [20., 30., 50, 77., 120., 200., 300.]
    for T in T_values:
        power_list = power_emitted(2, 0, alpha_prop, eps, Gamma, 
                                 w0_prop=w0_prop, T_ph=T, T_EM=0., 
                                 Gamma_EM=Gamma_EM, overdamped=overdamped, 
                                 N=N, end_T_mult=end_T_mult, rotating=rotating, 
                                T_increments=T_increments, 
                                 nsteps=nsteps, method=method, 
                                order=order, normalise=False, silent=True)
        powers.append(power_emitted(specs))
    powers = zip(*powers)
    naPower = np.array(powers[0])/powers[0][0]
    aPower = np.array(powers[1])/powers[1][0]
    return T_values, naPower, aPower

eps = 8000.
w0_prop = 400/eps
alpha_prop = pi*800/eps
Gamma = 80.
Gamma_EM = (10/100.)/inv_ps_to_inv_cm

T, naP, aP = power_emitted_vs_T(alpha_prop, eps, Gamma, 
                       w0_prop=w0_prop, T_EM=0., 
                       Gamma_EM=Gamma_EM, overdamped=False, 
                       N=10, rotating=True, T_increments=9, 
                       nsteps=3000, method='bdf', order=5)
# Out:
# w_RC=400.0 | TLS splitting = 8000.0 | RC-res. coupling=0.03 | TLS-RC coupling=708.98 | Gamma_RC=80.00 | alpha_ph=800.00 | N=10 |
# final t:  371.63
# 10.0%. Run time:  38.64s. Est. time left: 00:00:05:47
# 20.0%. Run time:  75.89s. Est. time left: 00:00:05:03
# 30.0%. Run time: 112.51s. Est. time left: 00:00:04:22
# 40.0%. Run time: 150.46s. Est. time left: 00:00:03:45
# 50.0%. Run time: 191.39s. Est. time left: 00:00:03:11
# 60.0%. Run time: 230.86s. Est. time left: 00:00:02:33
# 70.0%. Run time: 270.61s. Est. time left: 00:00:01:55
# 80.0%. Run time: 309.95s. Est. time left: 00:00:01:17
# 90.0%. Run time: 348.62s. Est. time left: 00:00:00:38
# Total run time: 386.82s
# 10.0%. Run time:  34.24s. Est. time left: 00:00:05:07
# 20.0%. Run time:  68.36s. Est. time left: 00:00:04:33
# 30.0%. Run time: 102.76s. Est. time left: 00:00:03:59
# 40.0%. Run time: 137.48s. Est. time left: 00:00:03:26
# 50.0%. Run time: 173.00s. Est. time left: 00:00:02:53
# 60.0%. Run time: 207.34s. Est. time left: 00:00:02:18
# 70.0%. Run time: 241.67s. Est. time left: 00:00:01:43
# 80.0%. Run time: 276.05s. Est. time left: 00:00:01:08
# 90.0%. Run time: 310.28s. Est. time left: 00:00:00:34
# Total run time: 344.55s
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-607d64e6b50e> in <module>()
#      98                        Gamma_EM=Gamma_EM, overdamped=False,
#      99                        N=10, rotating=True, T_increments=9,
# --> 100                        nsteps=3000, method='bdf', order=5)
#
# <ipython-input-64-607d64e6b50e> in power_emitted_vs_T(alpha_prop, eps, Gamma, w0_prop, T_EM, Gamma_EM, overdamped, N, end_T_mult, rotating, tau_f_mult, T_increments, nsteps, method, order)
#      82                                  nsteps=nsteps, method=method,
#      83                                 order=order, normalise=False, silent=True)
# ---> 84         powers.append(power_emitted(specs))
#      85     powers = zip(*powers)
#      86     naPower = np.array(powers[0])/powers[0][0]
#
# TypeError: power_emitted() takes at least 5 arguments (1 given)

# %%
reload(SF)
eps = 1000.
w0_prop = 60/eps
alpha_prop = pi*100/eps
Gamma = 30.
Gamma_EM = (10/100.)/inv_ps_to_inv_cm
print Gamma_EM 
times, pops, taus, g1, specs, freqs = SF.emission_spectra(2, 0, alpha_prop, eps, Gamma, 
                                                     w0_prop=w0_prop, T_ph=300., T_EM=0., 
                                                     Gamma_EM=Gamma_EM, overdamped=False, 
                                                     N=12, end_T_mult=7., rotating=False, 
                                                     tau_f_mult=2.5, T_increments=20, 
                                                     nsteps=3000, method='bdf', order=5, normalise=False)
# Out:
# 0.0188359389716
# w_RC=60.0 | TLS splitting = 1000.0 | RC-res. coupling=0.08 | TLS-RC coupling=97.08 | Gamma_RC=30.00 | alpha_ph=100.00 | N=12 |
# final t:  371.63
# 10.0%. Run time:  24.28s. Est. time left: 00:00:03:38
# 20.0%. Run time:  48.23s. Est. time left: 00:00:03:12
# 30.0%. Run time:  72.33s. Est. time left: 00:00:02:48
# 40.0%. Run time:  96.43s. Est. time left: 00:00:02:24
# 50.0%. Run time: 120.43s. Est. time left: 00:00:02:00
# 60.0%. Run time: 144.85s. Est. time left: 00:00:01:36
# 70.0%. Run time: 175.27s. Est. time left: 00:00:01:15
# 80.0%. Run time: 202.15s. Est. time left: 00:00:00:50
# 90.0%. Run time: 232.37s. Est. time left: 00:00:00:25
# Total run time: 260.31s
# Completed initial dynamics calculations for Full in 261.184327126  seconds.
# Completed correlation function calculations for Full in 7.1953959465 seconds.
# 10.0%. Run time:  23.07s. Est. time left: 00:00:03:27
# 20.0%. Run time:  45.11s. Est. time left: 00:00:03:00
# 30.0%. Run time:  66.96s. Est. time left: 00:00:02:36
# 40.0%. Run time:  88.96s. Est. time left: 00:00:02:13
# 50.0%. Run time: 110.91s. Est. time left: 00:00:01:50
# 60.0%. Run time: 133.00s. Est. time left: 00:00:01:28
# 70.0%. Run time: 155.13s. Est. time left: 00:00:01:06
# 80.0%. Run time: 177.09s. Est. time left: 00:00:00:44
# 90.0%. Run time: 199.07s. Est. time left: 00:00:00:22
# Total run time: 221.11s
# Completed initial dynamics calculations for Naive in 221.925067902  seconds.
# Completed correlation function calculations for Naive in 6.78550386429 seconds.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-0f5107552ae3> in <module>()
#      12                                                      tau_f_mult=2.5, T_increments=20,
#      13                                                      nsteps=3000, method='bdf', order=5, normalise=False)
# ---> 14 print power_emitted(spec)
#
# NameError: name 'power_emitted' is not defined

# %%
alpha_prop = pi*0.1/eps
times, pops, taus, g1, specs, freqs = SF.emission_spectra(2, 0, alpha_prop, eps, Gamma, 
                                                     w0_prop=w0_prop, T_ph=300., T_EM=0., 
                                                     Gamma_EM=Gamma_EM, overdamped=False, 
                                                     N=4, end_T_mult=7., rotating=False, 
                                                     tau_f_mult=2.5, T_increments=20, 
                                                     nsteps=3000, method='bdf', order=5, normalise=False)
# Out:
# w_RC=60.0 | TLS splitting = 1000.0 | RC-res. coupling=0.08 | TLS-RC coupling=3.07 | Gamma_RC=30.00 | alpha_ph=0.10 | N=4 |
# final t:  371.63
# 10.0%. Run time:   0.88s. Est. time left: 00:00:00:07
# 20.0%. Run time:   1.62s. Est. time left: 00:00:00:06
# 30.0%. Run time:   2.37s. Est. time left: 00:00:00:05
# 40.0%. Run time:   3.07s. Est. time left: 00:00:00:04
# 50.0%. Run time:   3.76s. Est. time left: 00:00:00:03
# 60.0%. Run time:   4.57s. Est. time left: 00:00:00:03
# 70.0%. Run time:   5.55s. Est. time left: 00:00:00:02
# 80.0%. Run time:   6.24s. Est. time left: 00:00:00:01
# 90.0%. Run time:   6.92s. Est. time left: 00:00:00:00
# Total run time:   7.60s
# Completed initial dynamics calculations for Full in 8.32778692245  seconds.
# Completed correlation function calculations for Full in 3.61590003967 seconds.
# 10.0%. Run time:   0.66s. Est. time left: 00:00:00:05
# 20.0%. Run time:   1.33s. Est. time left: 00:00:00:05
# 30.0%. Run time:   1.98s. Est. time left: 00:00:00:04
# 40.0%. Run time:   2.64s. Est. time left: 00:00:00:03
# 50.0%. Run time:   3.31s. Est. time left: 00:00:00:03
# 60.0%. Run time:   3.98s. Est. time left: 00:00:00:02
# 70.0%. Run time:   4.65s. Est. time left: 00:00:00:01
# 80.0%. Run time:   5.31s. Est. time left: 00:00:00:01
# 90.0%. Run time:   5.97s. Est. time left: 00:00:00:00
# Total run time:   6.70s
# Completed initial dynamics calculations for Naive in 7.45045089722  seconds.
# Completed correlation function calculations for Naive in 3.62831187248 seconds.

# %%
print power_emitted(specs[0]), power_emitted(specs[1])
# Out:
# 6974.69606378 6976.04352213

# %% [markdown]
# ## TODO: Rate differences between Full, RWA and non-rigorous RWA

# %% [markdown]
# ## Emission Spectra

# %%
def plot_spectra(timelist, pops, taulist, g1s, specs, freqs,
                freq_window=1000., tau_window=2.):
    plt.close('all')
    colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
    f1, (ax1, ax2) = plt.subplots(1, 2, figsize=(14,6))
    f2, (ax3, ax4) = plt.subplots(1, 2, figsize=(14,6))
    label = ['Full', 'Naive']
    ls = ['dashed', 'solid']
    for i, spec in enumerate(specs):
        g_1  = g1s[i]
        freq = freqs[i]
        ax1.plot(timelist, pops[i],
                label=label[i], linestyle=ls[i])
        ax3.plot(taulist[0:int(len(taulist)/tau_window)],
                 g_1.real[0:int(len(taulist)/tau_window)], 
                 label=label[i], linestyle=ls[i])
        ax4.plot(taulist[0:int(len(taulist)/tau_window)],
                 g_1.imag[0:int(len(taulist)/tau_window)], 
                 label=label[i], linestyle=ls[i])
        ax2.plot(freq, spec, label=label[i], linestyle=ls[i])
    ax1.set_xlim(0,timelist[-1])
    #ax3.set_xlim(0,taulist[int((len(taulist)-1)/5.)])
    #ax4.set_xlim(0,taulist[int((len(taulist)-1)/5.)])
    ax1.set_xlabel(r"Time")
    ax2.set_xlabel(r"Frequency $cm^{-1}$")
    #ax2.axvline(eps, linestyle='dashed',color='k', alpha=0.4)
    ax2.set_xlim(-freq_window,freq_window)

    ax1.set_ylabel(r"Excited state population")
    ax2.set_ylabel(r"Fluorescence intensity (arb. units)")
    ax3.set_ylabel(r"$Re[g_1(\tau)]$") # coherence
    ax4.set_ylabel(r"$Im[g_1(\tau)]$") # coherence
    ax3.set_xlabel(r"$\tau$")
    ax4.set_xlabel(r"$\tau$")
    ax1.legend()
    ax2.legend()
    ax3.legend()
    ax4.legend()
    plt.show()

# %%
reload(SF)


eps = 8000.
w0_prop = 400/eps
alpha_prop = 800/eps
Gamma = 80.
Gamma_EM = 0.00530871
print Gamma_EM 
times, pops, taus, g1, specs, freqs = SF.emission_spectra(2, 0, alpha_prop, eps, Gamma, 
                                                     w0_prop=w0_prop, T_ph=300., T_EM=0., 
                                                     Gamma_EM=Gamma_EM, overdamped=False, 
                                                     N=12, end_T_mult=7., rotating=True, 
                                                     tau_f_mult=2.5, T_increments=9, 
                                                     nsteps=3000, method='bdf', order=5)
# Out:
# 0.00530871
# w_RC=400.0 | TLS splitting = 8000.0 | RC-res. coupling=0.03 | TLS-RC coupling=400.00 | Gamma_RC=80.00 | alpha_ph=254.65 | N=12 |
# final t:  1318.58775484
# 10.0%. Run time:  85.94s. Est. time left: 00:00:12:53
# 20.0%. Run time: 169.09s. Est. time left: 00:00:11:16
# 30.0%. Run time: 254.50s. Est. time left: 00:00:09:53
# 40.0%. Run time: 338.30s. Est. time left: 00:00:08:27
# 50.0%. Run time: 423.38s. Est. time left: 00:00:07:03
# 60.0%. Run time: 507.45s. Est. time left: 00:00:05:38
# 70.0%. Run time: 592.58s. Est. time left: 00:00:04:13
# 80.0%. Run time: 677.84s. Est. time left: 00:00:02:49
# 90.0%. Run time: 761.74s. Est. time left: 00:00:01:24
# Total run time: 846.53s
# Completed initial dynamics calculations for Full in 848.29649806  seconds.
# Completed correlation function calculations for Full in 12.5458419323 seconds.
# 10.0%. Run time:  86.29s. Est. time left: 00:00:12:56
# 20.0%. Run time: 176.94s. Est. time left: 00:00:11:47
# 30.0%. Run time: 261.92s. Est. time left: 00:00:10:10
# 40.0%. Run time: 350.90s. Est. time left: 00:00:08:46
# 50.0%. Run time: 446.82s. Est. time left: 00:00:07:26
# 60.0%. Run time: 540.32s. Est. time left: 00:00:06:00
# 70.0%. Run time: 632.79s. Est. time left: 00:00:04:31
# 80.0%. Run time: 725.12s. Est. time left: 00:00:03:01
# 90.0%. Run time: 818.97s. Est. time left: 00:00:01:30
# Total run time: 907.99s
# Completed initial dynamics calculations for Naive in 909.40231204  seconds.
# Completed correlation function calculations for Naive in 8.36425018311 seconds.

# %%
with open('spectrum.dat', 'w') as f:
    f.write(str(specs[0]))
with open('freq.dat', 'w') as f:
    f.write(str(freqs[0]))

# %%
specs
# Out:
# [(3.1345986748446762e-10,
#   3.1452965619835905e-10,
#   3.156015437528546e-10,
#   3.1667555360630121e-10,
#   3.1775167712701836e-10,
#   3.1882990213153364e-10,
#   3.1991025591908532e-10,
#   3.2099271571277486e-10,
#   3.2207727862160889e-10,
#   3.2316396040150169e-10,
#   3.2425275211102349e-10,
#   3.2534365372952439e-10,
#   3.2643667566458083e-10,
#   3.2753180158207971e-10,
#   3.2862904713468569e-10,
#   3.29728417959836e-10,
#   3.3082989130128209e-10,
#   3.3193348171724107e-10,
#   3.3303919439085117e-10,
#   3.3414702184682929e-10,
#   3.3525697891184197e-10,
#   3.3636904216884214e-10,
#   3.3748323650102349e-10,
#   3.3859956112368785e-10,
#   3.3971800595965793e-10,
#   3.4083857767886871e-10,
#   3.419612681452386e-10,
#   3.4308611673822856e-10,
#   3.4421309012881384e-10,
#   3.4534219354143276e-10,
#   3.4647344529259388e-10,
#   3.4760683036978106e-10,
#   3.4874236669715388e-10,
#   3.4988004857532512e-10,
#   3.5101987550869602e-10,
#   3.5216186250978252e-10,
#   3.5330600286734985e-10,
#   3.5445230149608689e-10,
#   3.5560077031101672e-10,
#   3.5675140530604839e-10,
#   3.57904208195128e-10,
#   3.5905918273654706e-10,
#   3.6021634022583003e-10,
#   3.6137567822628244e-10,
#   3.6253719487940843e-10,
#   3.6370090837781694e-10,
#   3.6486681116362507e-10,
#   3.6603490767657268e-10,
#   3.6720520642444064e-10,
#   3.6837772144919712e-10,
#   3.695524362721794e-10,
#   3.7072935960766778e-10,
#   3.7190850708767697e-10,
#   3.7308987516041489e-10,
#   3.7427346888512022e-10,
#   3.7545929656307407e-10,
#   3.766473577812775e-10,
#   3.7783765274622995e-10,
#   3.7903017520099557e-10,
#   3.802249746228625e-10,
#   3.8142200750237919e-10,
#   3.8262129921833817e-10,
#   3.8382285642002439e-10,
#   3.8502666729566463e-10,
#   3.8623273839129405e-10,
#   3.8744109062531536e-10,
#   3.8865169529429344e-10,
#   3.8986459483388237e-10,
#   3.910797701635253e-10,
#   3.9229723154624897e-10,
#   3.9351697763980648e-10,
#   3.9473901812902587e-10,
#   3.9596334328777915e-10,
#   3.9718996633203644e-10,
#   3.9841889700857578e-10,
#   3.9965012501307033e-10,
#   4.0088365839900194e-10,
#   4.021194957828238e-10,
#   4.0335764573426641e-10,
#   4.0459810689043295e-10,
#   4.0584089087724712e-10,
#   4.0708596294083747e-10,
#   4.0833337598638436e-10,
#   4.0958310486224473e-10,
#   4.108351227854291e-10,
#   4.1208955497725429e-10,
#   4.1334624823571678e-10,
#   4.1460528121648866e-10,
#   4.1586664425539184e-10,
#   4.1713032890659535e-10,
#   4.1839635088471371e-10,
#   4.1966470223951487e-10,
#   4.2093539360572479e-10,
#   4.222084187883575e-10,
#   4.2348376857753381e-10,
#   4.2476146232225992e-10,
#   4.2604151590234996e-10,
#   4.2732389020679245e-10,
#   4.2860858996442654e-10,
#   4.2989564621213219e-10,
#   4.3118504022040162e-10,
#   4.3247677624312533e-10,
#   4.3377085291740636e-10,
#   4.3506727047039416e-10,
#   4.3636603142138308e-10,
#   4.3766715243488546e-10,
#   4.3897059437923967e-10,
#   4.402763926484658e-10,
#   4.4158453687628725e-10,
#   4.4289502282946355e-10,
#   4.4420786258821747e-10,
#   4.4552304679812004e-10,
#   4.4684058148895775e-10,
#   4.4816046052769441e-10,
#   4.4948269331005878e-10,
#   4.5080727859705365e-10,
#   4.5213420430845636e-10,
#   4.5346350813043169e-10,
#   4.5479514938257158e-10,
#   4.5612914947887766e-10,
#   4.5746557330150322e-10,
#   4.5880422655503758e-10,
#   4.6014531123732401e-10,
#   4.6148875057183605e-10,
#   4.6283454389777524e-10,
#   4.6418272154992302e-10,
#   4.6553325337934754e-10,
#   4.6688616030445146e-10,
#   4.6824144562922735e-10,
#   4.6959909192511459e-10,
#   4.7095912620225214e-10,
#   4.7232153142442846e-10,
#   4.7368630327580346e-10,
#   4.7505346839481671e-10,
#   4.7642302512947199e-10,
#   4.7779495809555419e-10,
#   4.7916929752459491e-10,
#   4.8054602923007616e-10,
#   4.8192515486399438e-10,
#   4.8330669350690613e-10,
#   4.8469062770960112e-10,
#   4.8607697010985071e-10,
#   4.8746572913283573e-10,
#   4.8885690230056201e-10,
#   4.9025049496136722e-10,
#   4.9164651649033032e-10,
#   4.9304495811122112e-10,
#   4.944458386154971e-10,
#   4.9584916200924919e-10,
#   4.9725490413203199e-10,
#   4.9866310180271242e-10,
#   5.0007375045765056e-10,
#   5.0148684974579739e-10,
#   5.0290240606863841e-10,
#   5.0432042029347156e-10,
#   5.0574091278115087e-10,
#   5.0716385489019109e-10,
#   5.0858929539578189e-10,
#   5.1001720406639177e-10,
#   5.1144759482008901e-10,
#   5.128804886578764e-10,
#   5.1431586459940121e-10,
#   5.1575374385216555e-10,
#   5.1719414202753402e-10,
#   5.1863700159473686e-10,
#   5.2008240215934399e-10,
#   5.2153031156937803e-10,
#   5.2298075576118053e-10,
#   5.2443370458581948e-10,
#   5.2588919416006329e-10,
#   5.2734720496970606e-10,
#   5.2880777645615869e-10,
#   5.3027085654023879e-10,
#   5.3173649816842679e-10,
#   5.3320469041689726e-10,
#   5.3467540838180661e-10,
#   5.3614870913962576e-10,
#   5.3762455870053151e-10,
#   5.3910298236071677e-10,
#   5.405839576323823e-10,
#   5.4206750778802541e-10,
#   5.435536277064578e-10,
#   5.4504232548246119e-10,
#   5.4653360132253502e-10,
#   5.4802745722972485e-10,
#   5.495238953722757e-10,
#   5.5102292120177515e-10,
#   5.5252452953508519e-10,
#   5.5402873292737722e-10,
#   5.5553552617486308e-10,
#   5.5704492110996592e-10,
#   5.5855690575571298e-10,
#   5.6007149421602226e-10,
#   5.6158867405962191e-10,
#   5.6310846060877722e-10,
#   5.6463084512855812e-10,
#   5.6615584368462808e-10,
#   5.6768344006677381e-10,
#   5.6921364635521802e-10,
#   5.7074646067081491e-10,
#   5.7228188264186548e-10,
#   5.7381991528326275e-10,
#   5.753605600405035e-10,
#   5.7690381080120151e-10,
#   5.7844968398206972e-10,
#   5.7999816215454745e-10,
#   5.8154925611856048e-10,
#   5.8310296886835186e-10,
#   5.8465929309383806e-10,
#   5.8621822526387725e-10,
#   5.8777977242010343e-10,
#   5.8934394986413204e-10,
#   5.9091072969787613e-10,
#   5.9248012955639572e-10,
#   5.9405213787571711e-10,
#   5.9562678360707478e-10,
#   5.9720403592008845e-10,
#   5.9878390257914044e-10,
#   6.0036641193661686e-10,
#   6.0195150683344692e-10,
#   6.0353923972051179e-10,
#   6.0512958870886122e-10,
#   6.0672255986958141e-10,
#   6.0831815041492864e-10,
#   6.0991637244577544e-10,
#   6.1151720467202013e-10,
#   6.1312067519824909e-10,
#   6.1472676975534468e-10,
#   6.1633548258196972e-10,
#   6.1794683874716766e-10,
#   6.1956080116362229e-10,
#   6.2117740371790711e-10,
#   6.2279664808266826e-10,
#   6.2441852287978145e-10,
#   6.2604303203273783e-10,
#   6.2767018446231726e-10,
#   6.2929997058694126e-10,
#   6.3093239600274745e-10,
#   6.3256746000763713e-10,
#   6.3420524096818329e-10,
#   6.3584559582150931e-10,
#   6.3748862484378851e-10,
#   6.3913430783936662e-10,
#   6.4078266622224498e-10,
#   6.4243367622432766e-10,
#   6.4408735386997812e-10,
#   6.4574370081119289e-10,
#   6.4740273030524176e-10,
#   6.4906443933723173e-10,
#   6.5072882177412654e-10,
#   6.5239589690298262e-10,
#   6.5406565873531353e-10,
#   6.5573811565500031e-10,
#   6.574132711105852e-10,
#   6.5909117579770342e-10,
#   6.60771739558659e-10,
#   6.6245503452373878e-10,
#   6.6414104470987896e-10,
#   6.658297980771161e-10,
#   6.6752126511666725e-10,
#   6.6921548646764023e-10,
#   6.7091244957486356e-10,
#   6.7261214630225562e-10,
#   6.7431460987559129e-10,
#   6.7601983438898391e-10,
#   6.7772784045108691e-10,
#   6.7943859772711887e-10,
#   6.8115213601496237e-10,
#   6.8286847197912975e-10,
#   6.8458758583696575e-10,
#   6.863095089144496e-10,
#   6.8803423941503526e-10,
#   6.8976177335328177e-10,
#   6.9149213639708102e-10,
#   6.9322530783453007e-10,
#   6.9496133049363179e-10,
#   6.9670017085951222e-10,
#   6.9844187353607033e-10,
#   7.0018641481715978e-10,
#   7.0193381770682862e-10,
#   7.0368408075957997e-10,
#   7.0543721413519104e-10,
#   7.071932294802353e-10,
#   7.0895211250494516e-10,
#   7.1071389602209652e-10,
#   7.1247856671246934e-10,
#   7.1424613547923902e-10,
#   7.1601661665347313e-10,
#   7.1779000905812439e-10,
#   7.1956631583198565e-10,
#   7.2134555140937424e-10,
#   7.2312771403504431e-10,
#   7.2491281110167888e-10,
#   7.2670083724029035e-10,
#   7.2849183102499126e-10,
#   7.302857668291898e-10,
#   7.3208265580386049e-10,
#   7.3388246523947755e-10,
#   7.3568529855100696e-10,
#   7.3749108455805971e-10,
#   7.3929982730802661e-10,
#   7.4111159188956061e-10,
#   7.4292629448450122e-10,
#   7.4474398971197483e-10,
#   7.4656468011192572e-10,
#   7.4838836593215344e-10,
#   7.5021504644990945e-10,
#   7.5204473607886129e-10,
#   7.5387741869139538e-10,
#   7.5571312433319382e-10,
#   7.5755183247820294e-10,
#   7.5939355859323786e-10,
#   7.6123828297824305e-10,
#   7.6308605162066466e-10,
#   7.6493683668436546e-10,
#   7.6679063818999549e-10,
#   7.6864747005562317e-10,
#   7.7050733477989301e-10,
#   7.7237024448432759e-10,
#   7.7423617125018993e-10,
#   7.7610514088992173e-10,
#   7.7797715344482288e-10,
#   7.7985218838883982e-10,
#   7.8173028097144283e-10,
#   7.8361140661918744e-10,
#   7.8549559725690145e-10,
#   7.873828096022828e-10,
#   7.8927308330324184e-10,
#   7.9116641212349258e-10,
#   7.930627869770556e-10,
#   7.9496222518924186e-10,
#   7.9686471548517668e-10,
#   7.9877026593899182e-10,
#   8.0067887876023239e-10,
#   8.0259055580739405e-10,
#   8.0450531851512848e-10,
#   8.0642324904959977e-10,
#   8.0834382845683152e-10,
#   8.1026782134264456e-10,
#   8.1219484047911471e-10,
#   8.1412491541632512e-10,
#   8.1605807518811005e-10,
#   8.1799429441567692e-10,
#   8.1993360275235869e-10,
#   8.2187599082307654e-10,
#   8.2382145381639142e-10,
#   8.2577000364732628e-10,
#   8.2772164368182369e-10,
#   8.2967636435895499e-10,
#   8.3163419328770803e-10,
#   8.3359511089192686e-10,
#   8.3555913462082209e-10,
#   8.3752624448523902e-10,
#   8.394964689614632e-10,
#   8.41469803423905e-10,
#   8.4344624803776418e-10,
#   8.4542580749058e-10,
#   8.4740848595364324e-10,
#   8.4939429024143818e-10,
#   8.513832218820617e-10,
#   8.5337528356000748e-10,
#   8.5537048776849741e-10,
#   8.5736882050686311e-10,
#   8.5937030663764826e-10,
#   8.61374942650361e-10,
#   8.6338273296409123e-10,
#   8.6539367993293354e-10,
#   8.6740779150712006e-10,
#   8.6942507507933411e-10,
#   8.7144552523928778e-10,
#   8.7346916040673956e-10,
#   8.7549598400958163e-10,
#   8.7752600618694106e-10,
#   8.7955921413584693e-10,
#   8.8159562547070918e-10,
#   8.8363525146640242e-10,
#   8.8567809678981616e-10,
#   8.877241517974221e-10,
#   8.897734461838532e-10,
#   8.9182596863293499e-10,
#   8.9388172118901281e-10,
#   8.9594073024272711e-10,
#   8.9800299562887813e-10,
#   9.0006851220562763e-10,
#   9.0213730681791472e-10,
#   9.042093602819329e-10,
#   9.0628469876117311e-10,
#   9.0836332047973917e-10,
#   9.1044523400736172e-10,
#   9.1253044601397585e-10,
#   9.1461896647350887e-10,
#   9.1671080331554284e-10,
#   9.1880594545105289e-10,
#   9.2090440518741118e-10,
#   9.2300622264747697e-10,
#   9.2511136799206779e-10,
#   9.2721985125706088e-10,
#   9.2933168834292026e-10,
#   9.3144687749439991e-10,
#   9.3356543587161112e-10,
#   9.3568736192580729e-10,
#   9.3781266061297739e-10,
#   9.3994134244394745e-10,
#   9.4207340620037018e-10,
#   9.4420886245502189e-10,
#   9.463477216154789e-10,
#   9.4848998409474029e-10,
#   9.506356545596956e-10,
#   9.5278473317554438e-10,
#   9.5493724243008575e-10,
#   9.5709317181249366e-10,
#   9.5925252892195068e-10,
#   9.6141532829602392e-10,
#   9.6358156266593013e-10,
#   9.6575124029165028e-10,
#   9.6792437697039907e-10,
#   9.7010094255324417e-10,
#   9.7228098870636908e-10,
#   9.7446448342234611e-10,
#   9.7665145978240044e-10,
#   9.7884189494768369e-10,
#   9.8103579971812152e-10,
#   9.8323319883235775e-10,
#   9.8543407707137713e-10,
#   9.8763843652082478e-10,
#   9.8984627604495318e-10,
#   9.9205761926730919e-10,
#   9.9427245396312021e-10,
#   9.9649079250170823e-10,
#   9.9871262418639752e-10,
#   1.00093796590885e-09,
#   1.003166825867097e-09,
#   1.0053991845056329e-09,
#   1.007635053058032e-09,
#   1.0098744020568112e-09,
#   1.0121173801609844e-09,
#   1.0143638110818997e-09,
#   1.0166137749000768e-09,
#   1.0188672706656172e-09,
#   1.021124286979747e-09,
#   1.0233848458759663e-09,
#   1.0256489386812947e-09,
#   1.0279165747708113e-09,
#   1.0301877568703093e-09,
#   1.0324624794456017e-09,
#   1.0347407563734569e-09,
#   1.0370225740455558e-09,
#   1.0393079605871349e-09,
#   1.0415969014399767e-09,
#   1.0438894044510641e-09,
#   1.0461854635493101e-09,
#   1.0484851049601561e-09,
#   1.0507882914104359e-09,
#   1.0530950631675586e-09,
#   1.0554054200663246e-09,
#   1.057719379308145e-09,
#   1.0600368776835125e-09,
#   1.0623579838741721e-09,
#   1.0646826880507461e-09,
#   1.0670109798263076e-09,
#   1.0693428820603553e-09,
#   1.0716783849028612e-09,
#   1.0740175008676972e-09,
#   1.0763602220872308e-09,
#   1.0787065780082957e-09,
#   1.081056541971802e-09,
#   1.0834101354124014e-09,
#   1.0857673775552005e-09,
#   1.0881282501662901e-09,
#   1.0904927660486417e-09,
#   1.092860934102385e-09,
#   1.0952327525516239e-09,
#   1.0976082298628395e-09,
#   1.0999873786118532e-09,
#   1.1023701955153225e-09,
#   1.1047566970725598e-09,
#   1.1071468769027301e-09,
#   1.1095407463220073e-09,
#   1.1119383255053961e-09,
#   1.114339598201383e-09,
#   1.116744583986124e-09,
#   1.1191532914499994e-09,
#   1.1215657013059531e-09,
#   1.1239818576416352e-09,
#   1.1264017495125705e-09,
#   1.1288253912498263e-09,
#   1.1312527771953161e-09,
#   1.1336839255209982e-09,
#   1.1361188353182748e-09,
#   1.1385575097259391e-09,
#   1.1409999782734238e-09,
#   1.1434462377186868e-09,
#   1.1458962777367508e-09,
#   1.1483501154051279e-09,
#   1.1508077713118211e-09,
#   1.1532692373826986e-09,
#   1.1557345252849841e-09,
#   1.1582036463968022e-09,
#   1.160676611951727e-09,
#   1.1631533974176144e-09,
#   1.165634050206757e-09,
#   1.1681185572477342e-09,
#   1.1706069256441303e-09,
#   1.1730991738157033e-09,
#   1.1755952856554897e-09,
#   1.1780952927992181e-09,
#   1.1805991850458116e-09,
#   1.1831069757351397e-09,
#   1.185618671495838e-09,
#   1.1881342732365039e-09,
#   1.1906537974977501e-09,
#   1.193177237506392e-09,
#   1.195704605569802e-09,
#   1.1982359044137734e-09,
#   1.2007711490095229e-09,
#   1.2033103343597616e-09,
#   1.2058534635619822e-09,
#   1.2084005380823317e-09,
#   1.2109515929844309e-09,
#   1.213506612202616e-09,
#   1.2160655829339158e-09,
#   1.2186285340263151e-09,
#   1.22119546731766e-09,
#   1.2237663771911631e-09,
#   1.2263412821491824e-09,
#   1.2289201553880787e-09,
#   1.2315030455384918e-09,
#   1.2340899348621121e-09,
#   1.2366808121666646e-09,
#   1.2392757101410258e-09,
#   1.2418746031999031e-09,
#   1.2444775215128785e-09,
#   1.2470844439963498e-09,
#   1.2496953976604556e-09,
#   1.2523103674307305e-09,
#   1.2549293609063567e-09,
#   1.257552380937028e-09,
#   1.2601794337796805e-09,
#   1.2628105270541468e-09,
#   1.2654456497540015e-09,
#   1.2680848202783535e-09,
#   1.2707280250188831e-09,
#   1.2733752790913564e-09,
#   1.2760265812980762e-09,
#   1.2786819304000451e-09,
#   1.2813413354212927e-09,
#   1.2840048031350036e-09,
#   1.2866723218533044e-09,
#   1.2893439126597977e-09,
#   1.2920195767315303e-09,
#   1.294699288152811e-09,
#   1.2973830830610579e-09,
#   1.3000709564383329e-09,
#   1.3027628956055642e-09,
#   1.3054589354818231e-09,
#   1.3081590492221699e-09,
#   1.3108632617717487e-09,
#   1.3135715654074767e-09,
#   1.3162839667786388e-09,
#   1.3190004740213168e-09,
#   1.3217210744564391e-09,
#   1.3244458114282579e-09,
#   1.3271746403948239e-09,
#   1.3299076049894886e-09,
#   1.3326446958991226e-09,
#   1.3353859085600866e-09,
#   1.3381312640353328e-09,
#   1.3408807633573589e-09,
#   1.3436344053284678e-09,
#   1.34639221615345e-09,
#   1.3491541816251376e-09,
#   1.3519203183047934e-09,
#   1.3546906274727144e-09,
#   1.3574651193919272e-09,
#   1.360243816612181e-09,
#   1.3630267012093163e-09,
#   1.3658137814639645e-09,
#   1.3686050832505167e-09,
#   1.3714006118347115e-09,
#   1.3742003649450536e-09,
#   1.3770043649041428e-09,
#   1.3798126089655352e-09,
#   1.3826251061532604e-09,
#   1.3854418868227499e-09,
#   1.3882629223325183e-09,
#   1.3910882623663533e-09,
#   1.3939178801825653e-09,
#   1.3967518152432152e-09,
#   1.3995900585655733e-09,
#   1.4024326495704003e-09,
#   1.4052795561883189e-09,
#   1.4081308151968959e-09,
#   1.4109864283926771e-09,
#   1.4138464319750309e-09,
#   1.4167107982936695e-09,
#   1.4195795647456585e-09,
#   1.4224527291834029e-09,
#   1.4253303015601801e-09,
#   1.428212308824179e-09,
#   1.431098751264499e-09,
#   1.43398961574777e-09,
#   1.4368849733098312e-09,
#   1.439784795515697e-09,
#   1.4426890941977904e-09,
#   1.445597884265378e-09,
#   1.4485111762705858e-09,
#   1.4514289917719651e-09,
#   1.4543513423541395e-09,
#   1.4572781848380571e-09,
#   1.4602096097324627e-09,
#   1.4631456001869946e-09,
#   1.4660861508120154e-09,
#   1.4690312804815816e-09,
#   1.4719810031550623e-09,
#   1.4749353227765983e-09,
#   1.477894279943998e-09,
#   1.4808578161765936e-09,
#   1.4838260041828704e-09,
#   1.4867988310772576e-09,
#   1.4897762973966544e-09,
#   1.4927584350452384e-09,
#   1.4957452381171227e-09,
#   1.4987367140875907e-09,
#   1.5017328866214889e-09,
#   1.5047337445678425e-09,
#   1.5077392994493252e-09,
#   1.5107495674555007e-09,
#   1.5137645600677428e-09,
#   1.5167842721648632e-09,
#   1.519808715682535e-09,
#   1.5228378983438405e-09,
#   1.5258718247743695e-09,
#   1.5289105091399899e-09,
#   1.5319539429535708e-09,
#   1.5350021501071081e-09,
#   1.5380551279574079e-09,
#   1.5411128576097632e-09,
#   1.5441753974415913e-09,
#   1.5472427071854838e-09,
#   1.5503148149253772e-09,
#   1.5533917162421813e-09,
#   1.5564734159473353e-09,
#   1.5595599343603931e-09,
#   1.5626512393087276e-09,
#   1.5657473861548638e-09,
#   1.5688483322566476e-09,
#   1.5719541034058711e-09,
#   1.5750646628662675e-09,
#   1.5781801086838145e-09,
#   1.5813003598900458e-09,
#   1.5844254505573839e-09,
#   1.587555374594093e-09,
#   1.5906901440390954e-09,
#   1.5938297670078231e-09,
#   1.5969742290659588e-09,
#   1.6001235412199273e-09,
#   1.6032777135262561e-09,
#   1.6064367386955114e-09,
#   1.6096006410946386e-09,
#   1.6127693815506757e-09,
#   1.6159430028503263e-09,
#   1.6191215030731447e-09,
#   1.6223048319984445e-09,
#   1.6254931087558061e-09,
#   1.6286862394498921e-09,
#   1.631884255138232e-09,
#   1.6350871587324695e-09,
#   1.6382949570057891e-09,
#   1.6415076488430933e-09,
#   1.6447252483896002e-09,
#   1.6479477544682626e-09,
#   1.6511751672236298e-09,
#   1.6544075181675309e-09,
#   1.6576447767173849e-09,
#   1.66088696573269e-09,
#   1.6641340807324065e-09,
#   1.6673861462280289e-09,
#   1.6706431551366234e-09,
#   1.6739051172462676e-09,
#   1.6771720250197286e-09,
#   1.6804439201079623e-09,
#   1.6837207667865495e-09,
#   1.6870025993963625e-09,
#   1.6902894731966764e-09,
#   1.6935812794861368e-09,
#   1.6968780962389676e-09,
#   1.7001799198414269e-09,
#   1.7034868216184535e-09,
#   1.7067987111645516e-09,
#   1.7101156493764338e-09,
#   1.7134376443901813e-09,
#   1.716764681461728e-09,
#   1.7200968036049262e-09,
#   1.7234339983472042e-09,
#   1.7267762936485987e-09,
#   1.7301236823642262e-09,
#   1.7334761976992111e-09,
#   1.7368338242280387e-09,
#   1.7401965788630207e-09,
#   1.7435644976589754e-09,
#   1.7469375711582244e-09,
#   1.7503158093140449e-09,
#   1.7536992436795657e-09,
#   1.7570878630831622e-09,
#   1.7604816895376844e-09,
#   1.7638807421649892e-09,
#   1.7672850256319661e-09,
#   1.7706945498299426e-09,
#   1.7741093405094104e-09,
#   1.7775294039066557e-09,
#   1.7809547430572215e-09,
#   1.7843853712390276e-09,
#   1.7878213290498822e-09,
#   1.7912625967690802e-09,
#   1.794709206878998e-09,
#   1.7981611641291246e-09,
#   1.8016184764077427e-09,
#   1.8050811686186956e-09,
#   1.8085492445409249e-09,
#   1.8120227229865377e-09,
#   1.8155016058346802e-09,
#   1.8189859284587224e-09,
#   1.8224756645299738e-09,
#   1.8259708800869847e-09,
#   1.8294715361013436e-09,
#   1.8329776721590113e-09,
#   1.8364892618280472e-09,
#   1.8400063999330369e-09,
#   1.8435290177509357e-09,
#   1.8470571565610005e-09,
#   1.8505908383554317e-09,
#   1.8541300432689738e-09,
#   1.8576747983737159e-09,
#   1.8612251229773642e-09,
#   1.8647810284993431e-09,
#   1.8683425023431803e-09,
#   1.8719095662739277e-09,
#   1.8754822317729587e-09,
#   1.8790605195315268e-09,
#   1.8826444261630393e-09,
#   1.8862339476407556e-09,
#   1.8898291239636349e-09,
#   1.8934299273161906e-09,
#   1.8970363930717924e-09,
#   1.9006485217879894e-09,
#   1.9042663098097393e-09,
#   1.9078897872653242e-09,
#   1.9115189513670004e-09,
#   1.9151537983564764e-09,
#   1.9187943461992117e-09,
#   1.9224406019161904e-09,
#   1.9260925633804673e-09,
#   1.9297502500855983e-09,
#   1.933413657199494e-09,
#   1.9370828017996664e-09,
#   1.9407576752131346e-09,
#   1.9444383055857851e-09,
#   1.9481246685506733e-09,
#   1.9518167973955236e-09,
#   1.9555146877425459e-09,
#   1.9592183396330402e-09,
#   1.9629277742332086e-09,
#   1.9666429668044068e-09,
#   1.9703639630862821e-09,
#   1.9740907450927245e-09,
#   1.9778233079296953e-09,
#   1.9815617142078532e-09,
#   1.9853058899797148e-09,
#   1.9890558776396343e-09,
#   1.9928116877190885e-09,
#   1.9965733202593767e-09,
#   2.0003407909751137e-09,
#   2.0041140831398374e-09,
#   2.0078932327670663e-09,
#   2.0116782227586384e-09,
#   2.0154690550763003e-09,
#   2.019265767075817e-09,
#   2.0230683385615339e-09,
#   2.0268767833069705e-09,
#   2.0306911070734635e-09,
#   2.0345112981937889e-09,
#   2.0383374813936651e-09,
#   2.042169481644088e-09,
#   2.046007410351555e-09,
#   2.049851272823105e-09,
#   2.0537010345320153e-09,
#   2.0575567543513032e-09,
#   2.0614184165870045e-09,
#   2.0652860379655805e-09,
#   2.0691596186728812e-09,
#   2.0730391778307637e-09,
#   2.0769247099876403e-09,
#   2.0808162446316436e-09,
#   2.0847137736060426e-09,
#   2.0886173153099457e-09,
#   2.0925268864904646e-09,
#   2.0964424824187606e-09,
#   2.1003641250663838e-09,
#   2.1042918314695456e-09,
#   2.1082255985307532e-09,
#   2.1121654533014449e-09,
#   2.1161113980118161e-09,
#   2.1200634323727676e-09,
#   2.1240215926662667e-09,
#   2.1279858891759911e-09,
#   2.1319563110813642e-09,
#   2.1359329000333426e-09,
#   2.1399156356297722e-09,
#   2.1439045659850443e-09,
#   2.1478996891374132e-09,
#   2.151901008535421e-09,
#   2.1559085496611105e-09,
#   2.1599223195767653e-09,
#   2.1639423349468979e-09,
#   2.167968609090728e-09,
#   2.1720011437635019e-09,
#   2.1760399651906602e-09,
#   2.1800851015593891e-09,
#   2.1841365410785651e-09,
#   2.1881943035721437e-09,
#   2.1922584044449898e-09,
#   2.1963288562729255e-09,
#   2.2004056805112518e-09,
#   2.2044888741244253e-09,
#   2.2085784754387599e-09,
#   2.2126744650639492e-09,
#   2.2167768691841342e-09,
#   2.2208857200751917e-09,
#   2.225000999978162e-09,
#   2.2291227441838151e-09,
#   2.2332509569253912e-09,
#   2.2373856503863634e-09,
#   2.2415268341896098e-09,
#   2.2456745271265874e-09,
#   2.24982873667258e-09,
#   2.2539894545056555e-09,
#   2.2581567492869097e-09,
#   2.2623305734181996e-09,
#   2.2665109618185963e-09,
#   2.2706979357988514e-09,
#   2.2748914794791514e-09,
#   2.2790916256309721e-09,
#   2.2832983745434121e-09,
#   2.2875117361903994e-09,
#   2.2917317301687403e-09,
#   2.2959583615170221e-09,
#   2.3001916364921813e-09,
#   2.3044315633748497e-09,
#   2.3086781593870877e-09,
#   2.3129314213488023e-09,
#   2.3171913696827978e-09,
#   2.3214580135783035e-09,
#   2.3257313549764145e-09,
#   2.3300114021371129e-09,
#   2.3342981749876026e-09,
#   2.3385916613237622e-09,
#   2.3428918954864631e-09,
#   2.3471988538934597e-09,
#   2.3515125724550199e-09,
#   2.3558330353532798e-09,
#   2.3601603017916554e-09,
#   2.3644943020146047e-09,
#   2.3688350965884407e-09,
#   2.3731826353750765e-09,
#   2.3775370882203781e-09,
#   2.3818982634101794e-09,
#   2.3862662676427888e-09,
#   2.3906410900356809e-09,
#   2.3950227469229691e-09,
#   2.399411230147921e-09,
#   2.4038065708506672e-09,
#   2.4082087631872702e-09,
#   2.4126178159546104e-09,
#   2.4170337496167919e-09,
#   2.4214565588254759e-09,
#   2.4258862554130867e-09,
#   2.4303228526368934e-09,
#   2.4347663521695425e-09,
#   2.4392167692093999e-09,
#   2.4436741277930111e-09,
#   2.4481384109461142e-09,
#   2.4526096359527206e-09,
#   2.4570878262298769e-09,
#   2.4615729888811676e-09,
#   2.4660651294407795e-09,
#   2.4705642558382953e-09,
#   2.4750703834372794e-09,
#   2.4795835292119947e-09,
#   2.4841037092074538e-09,
#   2.4886309194588662e-09,
#   2.4931651835278281e-09,
#   2.4977065075680266e-09,
#   2.5022549263746319e-09,
#   2.5068104277848223e-09,
#   2.5113730316225527e-09,
#   2.5159427573607291e-09,
#   2.5205196240179581e-09,
#   2.5251036402465705e-09,
#   2.5296948206873835e-09,
#   2.5342931650719472e-09,
#   2.5388987405332599e-09,
#   2.5435115222913778e-09,
#   2.5481315300257063e-09,
#   2.5527587366641567e-09,
#   2.5573932760597261e-09,
#   2.5620350683383953e-09,
#   2.5666841664879444e-09,
#   2.5713405714169718e-09,
#   2.576004311250713e-09,
#   2.5806754183889455e-09,
#   2.5853538880821794e-09,
#   2.5900397323899884e-09,
#   2.5947329916210805e-09,
#   2.5994336919389466e-09,
#   2.6041418268388517e-09,
#   2.6088574275641751e-09,
#   2.6135805148474699e-09,
#   2.6183111028133043e-09,
#   2.6230492365198761e-09,
#   2.6277948747498784e-09,
#   2.632548083748362e-09,
#   2.637308880468938e-09,
#   2.6420772700327953e-09,
#   2.6468532852733591e-09,
#   2.6516369441147895e-09,
#   2.656428248869881e-09,
#   2.6612272404255406e-09,
#   2.6660339280535982e-09,
#   2.6708483141700977e-09,
#   2.6756704458569334e-09,
#   2.680500333046732e-09,
#   2.6853379893271631e-09,
#   2.6901834348732309e-09,
#   2.6950366869895967e-09,
#   2.6998977671935118e-09,
#   2.70476668236141e-09,
#   2.7096434698697076e-09,
#   2.714528128107708e-09,
#   2.7194206915195329e-09,
#   2.7243211225429174e-09,
#   2.7292295213507856e-09,
#   2.7341458696679281e-09,
#   2.7390701593582634e-09,
#   2.7440024352941403e-09,
#   2.7489426966495606e-09,
#   2.7538909653960747e-09,
#   2.7588472549561521e-09,
#   2.7638115767905167e-09,
#   2.7687839482657795e-09,
#   2.7737643888341965e-09,
#   2.7787528794978105e-09,
#   2.7837494947410035e-09,
#   2.7887542054473409e-09,
#   2.7937670237589952e-09,
#   2.798787983128891e-09,
#   2.8038170681315131e-09,
#   2.8088543047445024e-09,
#   2.8138996980683983e-09,
#   2.8189532965273406e-09,
#   2.824015063075313e-09,
#   2.8290850149756768e-09,
#   2.8341631808286172e-09,
#   2.8392495724459074e-09,
#   2.8443441893938983e-09,
#   2.8494470396021724e-09,
#   2.8545581443608314e-09,
#   2.8596775095551117e-09,
#   2.8648051371674089e-09,
#   2.8699410455968316e-09,
#   2.875085245436806e-09,
#   2.8802377387523269e-09,
#   2.8853985399157621e-09,
#   2.8905676581782904e-09,
#   2.8957450901946202e-09,
#   2.9009308701610729e-09,
#   2.9061249927499619e-09,
#   2.9113274676667644e-09,
#   2.9165383086849992e-09,
#   2.9217575273892906e-09,
#   2.9269851142806596e-09,
#   2.9322211100395146e-09,
#   2.9374655030812321e-09,
#   2.9427183109169716e-09,
#   2.9479795428598624e-09,
#   2.9532492193120584e-09,
#   2.9585273326743771e-09,
#   2.9638138939532435e-09,
#   2.9691089297251468e-09,
#   2.9744124544037555e-09,
#   2.9797244677825691e-09,
#   2.9850449802898148e-09,
#   2.9903740118113971e-09,
#   2.9957115763686347e-09,
#   3.001057696118927e-09,
#   3.0064123414708912e-09,
#   3.0117755716279436e-09,
#   3.0171473944990161e-09,
#   3.022527758686375e-09,
#   3.0279168298439455e-09,
#   3.0333145040611631e-09,
#   ...),
#  (3.1325718505506286e-10,
#   3.1432682008997677e-10,
#   3.1539865911543574e-10,
#   3.1647267747539136e-10,
#   3.1754892937598032e-10,
#   3.186273578852716e-10,
#   3.1970798239357472e-10,
#   3.2079079918389739e-10,
#   3.2187581286117998e-10,
#   3.2296301318304389e-10,
#   3.2405241658685485e-10,
#   3.2514401183903628e-10,
#   3.2623777750493297e-10,
#   3.2733374776022352e-10,
#   3.2843192710659851e-10,
#   3.2953226883385554e-10,
#   3.3063481682315293e-10,
#   3.317395580443679e-10,
#   3.3284646899784953e-10,
#   3.339555634158192e-10,
#   3.3506683487614023e-10,
#   3.3618029568618695e-10,
#   3.3729589504706552e-10,
#   3.3841365899837154e-10,
#   3.3953357130923888e-10,
#   3.4065561389030536e-10,
#   3.4177979485700399e-10,
#   3.4290608494834592e-10,
#   3.4403447677164668e-10,
#   3.4516495523178766e-10,
#   3.4629751539342931e-10,
#   3.4743216716855079e-10,
#   3.4856882911372237e-10,
#   3.497075409181611e-10,
#   3.5084827325892822e-10,
#   3.5199103195931157e-10,
#   3.5313578484667838e-10,
#   3.5428255007234075e-10,
#   3.5543129383231924e-10,
#   3.5658201641571332e-10,
#   3.5773470650634654e-10,
#   3.5888937643224327e-10,
#   3.600460166324734e-10,
#   3.6120464883079151e-10,
#   3.6236525848962806e-10,
#   3.6352785797830722e-10,
#   3.6469245514381247e-10,
#   3.6585906136427014e-10,
#   3.6702770284447546e-10,
#   3.6819837935727891e-10,
#   3.6937113292534265e-10,
#   3.7054597036315247e-10,
#   3.7172290866562286e-10,
#   3.7290199169326218e-10,
#   3.7408321880592176e-10,
#   3.7526664625408406e-10,
#   3.7645229650490222e-10,
#   3.7764018409594577e-10,
#   3.7883037112163501e-10,
#   3.8002280721672517e-10,
#   3.8121761607445781e-10,
#   3.8241478129876721e-10,
#   3.8361434259952036e-10,
#   3.8481630216561269e-10,
#   3.8602071220013519e-10,
#   3.8722760091092885e-10,
#   3.8843694110200054e-10,
#   3.8964880073235824e-10,
#   3.908631764980089e-10,
#   3.9208008791316165e-10,
#   3.9329953382141903e-10,
#   3.9452153728878276e-10,
#   3.9574609895540153e-10,
#   3.9697322084497115e-10,
#   3.9820291264232126e-10,
#   3.9943515782748655e-10,
#   4.0066996521799846e-10,
#   4.019073335955096e-10,
#   4.031472465226543e-10,
#   4.0438970034439023e-10,
#   4.0563466569647865e-10,
#   4.0688216560362158e-10,
#   4.0813216293719647e-10,
#   4.0938464811562339e-10,
#   4.1063962200620054e-10,
#   4.1189703622607902e-10,
#   4.1315689540084916e-10,
#   4.1441922040761733e-10,
#   4.1568394190382838e-10,
#   4.1695107265115564e-10,
#   4.1822059691433209e-10,
#   4.1949250779627202e-10,
#   4.2076677048114824e-10,
#   4.2204338738500573e-10,
#   4.2332235747534655e-10,
#   4.2460367552773166e-10,
#   4.2588730395923965e-10,
#   4.2717324566086439e-10,
#   4.2846151775142013e-10,
#   4.2975209245671488e-10,
#   4.3104497400998989e-10,
#   4.3234014392953373e-10,
#   4.3363761415102141e-10,
#   4.3493736759693865e-10,
#   4.3623939875374694e-10,
#   4.3754371288718537e-10,
#   4.3885029969292536e-10,
#   4.401591500230361e-10,
#   4.4147029086701114e-10,
#   4.4278367173570597e-10,
#   4.4409931069783291e-10,
#   4.4541719691216454e-10,
#   4.4673732449346321e-10,
#   4.4805969666312214e-10,
#   4.4938428238425619e-10,
#   4.5071111546084475e-10,
#   4.5204015364307611e-10,
#   4.5337140758632795e-10,
#   4.5470484695581372e-10,
#   4.5604049690318076e-10,
#   4.5737834088781375e-10,
#   4.5871835462536339e-10,
#   4.6006054565306391e-10,
#   4.6140491161682024e-10,
#   4.6275145893876896e-10,
#   4.6410017237924189e-10,
#   4.6545105683227886e-10,
#   4.6680411708866983e-10,
#   4.6815935209526696e-10,
#   4.6951676914150505e-10,
#   4.7087638720469447e-10,
#   4.7223819969749897e-10,
#   4.7360222470928084e-10,
#   4.7496847892520506e-10,
#   4.7633698526672381e-10,
#   4.7770775597926152e-10,
#   4.7908080078894782e-10,
#   4.8045616791343206e-10,
#   4.8183387011438745e-10,
#   4.8321395129362243e-10,
#   4.8459636963497421e-10,
#   4.8598123284861782e-10,
#   4.8736854223550053e-10,
#   4.8875833802173834e-10,
#   4.9015063532309958e-10,
#   4.9154548394728019e-10,
#   4.9294288180863461e-10,
#   4.9434288963868588e-10,
#   4.9574552845909012e-10,
#   4.9715080745907815e-10,
#   4.9855878034918771e-10,
#   4.9996947203326671e-10,
#   5.0138285715316828e-10,
#   5.0279899922815958e-10,
#   5.0421789084490611e-10,
#   5.0563955990149967e-10,
#   5.0706398711088042e-10,
#   5.0849122446963986e-10,
#   5.0992124953127482e-10,
#   5.1135406842882247e-10,
#   5.1278966546831565e-10,
#   5.1422805630242163e-10,
#   5.1566922550562263e-10,
#   5.1711314257793238e-10,
#   5.1855981862902769e-10,
#   5.2000921797578315e-10,
#   5.2146134588393758e-10,
#   5.229161635315723e-10,
#   5.2437364642783836e-10,
#   5.2583378765500031e-10,
#   5.2729655691957134e-10,
#   5.2876193247714688e-10,
#   5.3022986464393086e-10,
#   5.3170038493175739e-10,
#   5.3317340801500457e-10,
#   5.3464894289705383e-10,
#   5.3612695620757489e-10,
#   5.3760744278407833e-10,
#   5.390903511668718e-10,
#   5.4057567753571325e-10,
#   5.4206340972777815e-10,
#   5.4355353365979585e-10,
#   5.450460224868225e-10,
#   5.4654086140283893e-10,
#   5.4803806552361367e-10,
#   5.495376042252607e-10,
#   5.5103947573188365e-10,
#   5.5254368138572987e-10,
#   5.5405020295288727e-10,
#   5.5555904090830486e-10,
#   5.5707021187519811e-10,
#   5.5858370336034296e-10,
#   5.6009952017517937e-10,
#   5.616176779104248e-10,
#   5.6313814270015003e-10,
#   5.6466096728434482e-10,
#   5.6618612659396152e-10,
#   5.6771363921396137e-10,
#   5.6924349950690613e-10,
#   5.7077572603710701e-10,
#   5.7231030552664178e-10,
#   5.7384727801577664e-10,
#   5.7538663423268112e-10,
#   5.7692835061575447e-10,
#   5.7847252934098311e-10,
#   5.8001897788881932e-10,
#   5.8156795413592421e-10,
#   5.831193157834453e-10,
#   5.8467309554091402e-10,
#   5.8622929768287162e-10,
#   5.8778797358641055e-10,
#   5.8934907214288782e-10,
#   5.9091262893217901e-10,
#   5.9247865876030321e-10,
#   5.9404717800267603e-10,
#   5.9561817507467186e-10,
#   5.9719168809611112e-10,
#   5.9876772730937214e-10,
#   6.0034630109833761e-10,
#   6.0192742732522023e-10,
#   6.0351113913320057e-10,
#   6.0509743274333668e-10,
#   6.066863652321093e-10,
#   6.0827792553114151e-10,
#   6.0987215388719916e-10,
#   6.1146906667569817e-10,
#   6.1306869625512086e-10,
#   6.1467106360582337e-10,
#   6.162761900179113e-10,
#   6.1788411253740718e-10,
#   6.1949486139584788e-10,
#   6.2110839979501022e-10,
#   6.2272489650699164e-10,
#   6.2434425433244526e-10,
#   6.2596652283126746e-10,
#   6.2759173830608237e-10,
#   6.2921990748877596e-10,
#   6.3085106533972529e-10,
#   6.324852230925067e-10,
#   6.3412239452064149e-10,
#   6.3576258346502174e-10,
#   6.3740580237757121e-10,
#   6.3905206141806887e-10,
#   6.4070136562510416e-10,
#   6.4235370159685501e-10,
#   6.4400907825410294e-10,
#   6.456674797789807e-10,
#   6.4732889564001054e-10,
#   6.4899334341030575e-10,
#   6.5066076535258677e-10,
#   6.5233116493604661e-10,
#   6.5400452460822173e-10,
#   6.5568082979024264e-10,
#   6.5736002914631665e-10,
#   6.5904212193304526e-10,
#   6.607270706914068e-10,
#   6.6241484349656787e-10,
#   6.6410542651305756e-10,
#   6.6579879783127145e-10,
#   6.6749489025625001e-10,
#   6.6919370242509605e-10,
#   6.708952118500066e-10,
#   6.7259938710174743e-10,
#   6.7430620399921886e-10,
#   6.7601562258475448e-10,
#   6.7772764428320131e-10,
#   6.7944223289518497e-10,
#   6.8115938695455851e-10,
#   6.8287908630696406e-10,
#   6.8460132866025643e-10,
#   6.8632606645758488e-10,
#   6.8805332949683737e-10,
#   6.8978311480441986e-10,
#   6.9151541030010778e-10,
#   6.9325021592195109e-10,
#   6.9498754544347119e-10,
#   6.9672739235993149e-10,
#   6.984697866344196e-10,
#   7.0021471315116687e-10,
#   7.0196220410345618e-10,
#   7.0371226004883641e-10,
#   7.054649101243965e-10,
#   7.0722017227494913e-10,
#   7.0897805502892639e-10,
#   7.1073857918083492e-10,
#   7.1250173450894593e-10,
#   7.1426767912997925e-10,
#   7.1603625065267402e-10,
#   7.1780757413316898e-10,
#   7.1958162807485906e-10,
#   7.2135846521773406e-10,
#   7.2313808318704902e-10,
#   7.2492052010262422e-10,
#   7.2670579072917876e-10,
#   7.2849389547971183e-10,
#   7.3028487751263337e-10,
#   7.3207873449449811e-10,
#   7.3387550256273051e-10,
#   7.3567517356059779e-10,
#   7.3747778478192187e-10,
#   7.3928335629846088e-10,
#   7.4109189145550785e-10,
#   7.4290339454825373e-10,
#   7.4471790297377049e-10,
#   7.4653542352589382e-10,
#   7.4835597169209154e-10,
#   7.5017956613992438e-10,
#   7.5200625000715244e-10,
#   7.5383595998100798e-10,
#   7.5566878138711259e-10,
#   7.5750471042587426e-10,
#   7.5934377767987912e-10,
#   7.6118599452725344e-10,
#   7.6303136761728329e-10,
#   7.6487989554577149e-10,
#   7.6673163218845574e-10,
#   7.6858658369902286e-10,
#   7.7044478262180517e-10,
#   7.7230620376385503e-10,
#   7.7417090581235001e-10,
#   7.7603888461664877e-10,
#   7.7791016218960513e-10,
#   7.7978473568152524e-10,
#   7.8166262813776094e-10,
#   7.8354384598044873e-10,
#   7.8542839724242184e-10,
#   7.8731629848494569e-10,
#   7.8920754776692435e-10,
#   7.9110213856297139e-10,
#   7.9300007599427624e-10,
#   7.9490135704594507e-10,
#   7.9680597223964776e-10,
#   7.9871392510652684e-10,
#   8.0062518886358839e-10,
#   8.0253975171970686e-10,
#   8.044576150997295e-10,
#   8.0637874222608306e-10,
#   8.0830311752870004e-10,
#   8.1023072554076284e-10,
#   8.121615280185512e-10,
#   8.1409551217974196e-10,
#   8.1603264603755189e-10,
#   8.1797290766172694e-10,
#   8.1991624367212843e-10,
#   8.2186265865304696e-10,
#   8.2381212646163706e-10,
#   8.2576458097673681e-10,
#   8.2772001600335941e-10,
#   8.2967841648768603e-10,
#   8.3163974802688871e-10,
#   8.3360398854616347e-10,
#   8.3557110118533749e-10,
#   8.3754111024940981e-10,
#   8.3951395977699747e-10,
#   8.4148965509578924e-10,
#   8.4346818193666498e-10,
#   8.4544953065609483e-10,
#   8.474336939439941e-10,
#   8.4942068326108882e-10,
#   8.514104965423834e-10,
#   8.5340313919816637e-10,
#   8.5539863431508947e-10,
#   8.5739697617311491e-10,
#   8.5939818005321047e-10,
#   8.6140227548481464e-10,
#   8.6340927944219191e-10,
#   8.6541921879093609e-10,
#   8.6743211314850632e-10,
#   8.694479803358152e-10,
#   8.7146686093002808e-10,
#   8.7348878276728672e-10,
#   8.7551377607912801e-10,
#   8.7754185934726337e-10,
#   8.7957311252832561e-10,
#   8.8160750665042536e-10,
#   8.8364509273960605e-10,
#   8.8568590084155474e-10,
#   8.8772998094981718e-10,
#   8.8977733956912962e-10,
#   8.9182799445845506e-10,
#   8.9388200374742196e-10,
#   8.9593937517976425e-10,
#   8.9800012504829777e-10,
#   9.0006427408557924e-10,
#   9.021318750109485e-10,
#   9.0420291367918519e-10,
#   9.0627741321824093e-10,
#   9.0835539163487812e-10,
#   9.1043685316233789e-10,
#   9.1252184263167646e-10,
#   9.1461035145251201e-10,
#   9.167023875337778e-10,
#   9.1879795913545676e-10,
#   9.2089709576633711e-10,
#   9.229998191501735e-10,
#   9.2510604214414806e-10,
#   9.2721587875667245e-10,
#   9.2932927242751494e-10,
#   9.3144628518914583e-10,
#   9.3356687454395418e-10,
#   9.3569106888563025e-10,
#   9.3781885570030056e-10,
#   9.3995026449675313e-10,
#   9.4208529283829337e-10,
#   9.4422393366263582e-10,
#   9.4636620598839094e-10,
#   9.4851211283045216e-10,
#   9.5066164636248609e-10,
#   9.5281481416302659e-10,
#   9.5497163473443532e-10,
#   9.5713208040577008e-10,
#   9.5929616395935402e-10,
#   9.6146389074352584e-10,
#   9.6363524491976887e-10,
#   9.6581024181035098e-10,
#   9.6798885372368001e-10,
#   9.7017109668412276e-10,
#   9.7235693767239767e-10,
#   9.745463779688027e-10,
#   9.7673940545181269e-10,
#   9.7893601572298694e-10,
#   9.8113613390558218e-10,
#   9.833398258316604e-10,
#   9.8554702756895545e-10,
#   9.8775773077488494e-10,
#   9.8997187781541884e-10,
#   9.9218949179785914e-10,
#   9.9441053769987915e-10,
#   9.9663495984919491e-10,
#   9.9886276518419204e-10,
#   1.0010939155437501e-09,
#   1.0033283883987665e-09,
#   1.0055661398887327e-09,
#   1.0078071719960444e-09,
#   1.0100514537044668e-09,
#   1.0122989538945146e-09,
#   1.014549670563142e-09,
#   1.0168035593955417e-09,
#   1.0190606286723463e-09,
#   1.021320851094313e-09,
#   1.0235842284786378e-09,
#   1.0258507456476024e-09,
#   1.0281203968605192e-09,
#   1.0303931944660618e-09,
#   1.0326691271893544e-09,
#   1.0349482199548942e-09,
#   1.037230464523349e-09,
#   1.0395158922000533e-09,
#   1.0418045039349048e-09,
#   1.0440963294844917e-09,
#   1.0463913982750023e-09,
#   1.0486897083033907e-09,
#   1.0509913480340724e-09,
#   1.0532962770757315e-09,
#   1.0556046092096304e-09,
#   1.0579163085048441e-09,
#   1.0602314462863236e-09,
#   1.0625500489447138e-09,
#   1.0648721466702516e-09,
#   1.0671978275350031e-09,
#   1.0695270857776301e-09,
#   1.0718599628632461e-09,
#   1.0741965144847847e-09,
#   1.0765367710183325e-09,
#   1.078880747992657e-09,
#   1.0812285226385968e-09,
#   1.0835800919206084e-09,
#   1.0859354897872209e-09,
#   1.0882947574144479e-09,
#   1.0906579068412146e-09,
#   1.0930249814324302e-09,
#   1.0953959779460516e-09,
#   1.0977709242801704e-09,
#   1.1001498327008612e-09,
#   1.1025327248699285e-09,
#   1.1049195915155417e-09,
#   1.10731046169219e-09,
#   1.1097053401080639e-09,
#   1.1121042143525392e-09,
#   1.1145070771981307e-09,
#   1.1169139393208665e-09,
#   1.1193248334922279e-09,
#   1.1217397109783169e-09,
#   1.1241585813813633e-09,
#   1.1265814335503903e-09,
#   1.1290082765300793e-09,
#   1.1314391075533358e-09,
#   1.1338738506283187e-09,
#   1.1363125790004249e-09,
#   1.1387552531869369e-09,
#   1.1412018664766188e-09,
#   1.1436524033820028e-09,
#   1.1461068665669337e-09,
#   1.148565239821195e-09,
#   1.1510275122416096e-09,
#   1.1534936849432751e-09,
#   1.1559637261665579e-09,
#   1.1584376588122604e-09,
#   1.1609154558908885e-09,
#   1.163397110939006e-09,
#   1.1658826180713753e-09,
#   1.1683719399941741e-09,
#   1.1708651193289136e-09,
#   1.1733620939605234e-09,
#   1.1758628957312368e-09,
#   1.178367476815754e-09,
#   1.1808758623657224e-09,
#   1.1833880109160285e-09,
#   1.185903929818057e-09,
#   1.188423585185229e-09,
#   1.1909469821800332e-09,
#   1.1934740899101345e-09,
#   1.1960048961714083e-09,
#   1.1985394313192911e-09,
#   1.2010776184739937e-09,
#   1.2036194789049715e-09,
#   1.206164983206686e-09,
#   1.2087141285500931e-09,
#   1.2112668948634348e-09,
#   1.213823290757743e-09,
#   1.2163832845353339e-09,
#   1.2189468694230218e-09,
#   1.2215140454414568e-09,
#   1.2240848130036375e-09,
#   1.2266591720063146e-09,
#   1.2292370966370419e-09,
#   1.2318186159503086e-09,
#   1.2344037215622324e-09,
#   1.2369924316654251e-09,
#   1.2395847536319214e-09,
#   1.2421807065835811e-09,
#   1.2447802947742958e-09,
#   1.2473835544447394e-09,
#   1.249990500049882e-09,
#   1.2526012587108577e-09,
#   1.2552155931596622e-09,
#   1.2578337748399786e-09,
#   1.2604557795087575e-09,
#   1.2630816246565123e-09,
#   1.2657113691562701e-09,
#   1.2683450523874984e-09,
#   1.2709827033220867e-09,
#   1.2736243642511469e-09,
#   1.2762700999329436e-09,
#   1.2789199420032105e-09,
#   1.2815739479514276e-09,
#   1.2842320740616364e-09,
#   1.2868944981712653e-09,
#   1.2895611889130294e-09,
#   1.2922322022483123e-09,
#   1.2949075649807577e-09,
#   1.2975873037488103e-09,
#   1.3002714757735001e-09,
#   1.3029600869400652e-09,
#   1.3056531857965538e-09,
#   1.3083507776706549e-09,
#   1.3110528889736634e-09,
#   1.3137595472526218e-09,
#   1.3164707458788937e-09,
#   1.3191865010833454e-09,
#   1.321906829551142e-09,
#   1.3246317199867571e-09,
#   1.3273611772222805e-09,
#   1.3300952033020582e-09,
#   1.3328337822636731e-09,
#   1.3355769105140331e-09,
#   1.3383245628395407e-09,
#   1.3410767160296445e-09,
#   1.3438334188182427e-09,
#   1.3465945802422751e-09,
#   1.3493602194236019e-09,
#   1.3521303109627763e-09,
#   1.3549048293158016e-09,
#   1.3576837281441745e-09,
#   1.3604670396411779e-09,
#   1.3632547155065625e-09,
#   1.3660467354827208e-09,
#   1.3688430679752188e-09,
#   1.37164372566313e-09,
#   1.3744486850055036e-09,
#   1.3772579120538103e-09,
#   1.3800713879752899e-09,
#   1.3828891235905193e-09,
#   1.3857110923023545e-09,
#   1.3885372806470233e-09,
#   1.3913676891201249e-09,
#   1.3942023047534862e-09,
#   1.397041115198433e-09,
#   1.3998841078378419e-09,
#   1.4027313239303266e-09,
#   1.4055827204826768e-09,
#   1.4084382874177135e-09,
#   1.4112980560820716e-09,
#   1.4141620006633046e-09,
#   1.4170301396637741e-09,
#   1.4199024634606001e-09,
#   1.4227789619559536e-09,
#   1.425659673827204e-09,
#   1.4285445718370581e-09,
#   1.4314336519587743e-09,
#   1.4343269452705378e-09,
#   1.4372244368424296e-09,
#   1.4401261312174403e-09,
#   1.4430320411365932e-09,
#   1.4459421676736863e-09,
#   1.4488565026926365e-09,
#   1.4517750833633659e-09,
#   1.4546978919269117e-09,
#   1.4576249366226069e-09,
#   1.460556239132906e-09,
#   1.4634918023901031e-09,
#   1.4664316423772645e-09,
#   1.4693757605398872e-09,
#   1.4723241858911608e-09,
#   1.475276936251998e-09,
#   1.4782340047872629e-09,
#   1.4811954396526552e-09,
#   1.4841612762215509e-09,
#   1.4871314826517162e-09,
#   1.4901061310321509e-09,
#   1.4930852484142983e-09,
#   1.4960688307301169e-09,
#   1.4990569608272336e-09,
#   1.5020496400685456e-09,
#   1.5050469037241792e-09,
#   1.5080487991651353e-09,
#   1.5110553423331809e-09,
#   1.5140666150847445e-09,
#   1.5170826216117678e-09,
#   1.5201034098634503e-09,
#   1.5231290229569021e-09,
#   1.5261594912682098e-09,
#   1.5291948617553752e-09,
#   1.5322351806949514e-09,
#   1.535280453641777e-09,
#   1.5383307479560111e-09,
#   1.5413860678502453e-09,
#   1.5444464811182876e-09,
#   1.5475119606880445e-09,
#   1.5505825759640213e-09,
#   1.5536583362386983e-09,
#   1.5567392488015105e-09,
#   1.5598253618081573e-09,
#   1.5629165983168992e-09,
#   1.5660130678344576e-09,
#   1.5691147356689048e-09,
#   1.5722215850111761e-09,
#   1.5753336370274771e-09,
#   1.5784508633654174e-09,
#   1.5815732692700857e-09,
#   1.5847008315309305e-09,
#   1.5878335399262235e-09,
#   1.5909713686435181e-09,
#   1.5941143258188978e-09,
#   1.5972623270972886e-09,
#   1.6004154161946491e-09,
#   1.6035735255443206e-09,
#   1.60673664696892e-09,
#   1.6099047384044855e-09,
#   1.6130777851275977e-09,
#   1.6162557538092261e-09,
#   1.6194386277642059e-09,
#   1.6226263738287061e-09,
#   1.6258189649719333e-09,
#   1.6290163992321414e-09,
#   1.6322186253561378e-09,
#   1.6354256450372187e-09,
#   1.6386374414456696e-09,
#   1.6418539941793326e-09,
#   1.6450752975181701e-09,
#   1.6483013397949564e-09,
#   1.6515321090946662e-09,
#   1.6547676278431527e-09,
#   1.6580078565989984e-09,
#   1.6612528229298958e-09,
#   1.6645025459164049e-09,
#   1.6677569816360673e-09,
#   1.6710161836961714e-09,
#   1.6742801555659095e-09,
#   1.6775488917936935e-09,
#   1.6808224560846398e-09,
#   1.6841007443836159e-09,
#   1.6873839018391689e-09,
#   1.6906719015650548e-09,
#   1.6939647502312093e-09,
#   1.6972624795766166e-09,
#   1.7005651080416877e-09,
#   1.7038726527658873e-09,
#   1.7071851244458927e-09,
#   1.7105025676649609e-09,
#   1.713824967018224e-09,
#   1.7171523841664532e-09,
#   1.7204848120473632e-09,
#   1.723822274552954e-09,
#   1.7271647974543721e-09,
#   1.7305123911178957e-09,
#   1.7338650811701209e-09,
#   1.7372228961079887e-09,
#   1.7405858354358998e-09,
#   1.743953943799061e-09,
#   1.7473272122973409e-09,
#   1.7507056916883334e-09,
#   1.7540893798450931e-09,
#   1.7574783056569094e-09,
#   1.7608724890509911e-09,
#   1.7642719734748468e-09,
#   1.7676767490164976e-09,
#   1.7710868582148547e-09,
#   1.7745023314666542e-09,
#   1.7779231871503582e-09,
#   1.7813494519663604e-09,
#   1.7847811496621117e-09,
#   1.7882183100561494e-09,
#   1.7916609849592154e-09,
#   1.7951091403814807e-09,
#   1.7985628716224962e-09,
#   1.8020221736023725e-09,
#   1.8054870826030838e-09,
#   1.8089576214634823e-09,
#   1.8124338107509254e-09,
#   1.8159156865821872e-09,
#   1.8194032822243483e-09,
#   1.8228965897271752e-09,
#   1.8263956654650505e-09,
#   1.829900490708463e-09,
#   1.8334111057867787e-09,
#   1.8369275089241009e-09,
#   1.8404497367121536e-09,
#   1.8439777544590091e-09,
#   1.8475116109192153e-09,
#   1.8510512890152583e-09,
#   1.8545967663212847e-09,
#   1.85814806889754e-09,
#   1.861705160090351e-09,
#   1.8652680405192164e-09,
#   1.8688367649065214e-09,
#   1.8724112333271252e-09,
#   1.875991396055932e-09,
#   1.8795773010627908e-09,
#   1.8831689041980945e-09,
#   1.886766184770586e-09,
#   1.8903691257440511e-09,
#   1.8939776619059259e-09,
#   1.8975918018259421e-09,
#   1.9012115090362769e-09,
#   1.9048367423609155e-09,
#   1.9084674885012855e-09,
#   1.9121037185061483e-09,
#   1.9157454002441708e-09,
#   1.919392513127345e-09,
#   1.9230450351221686e-09,
#   1.926702949977124e-09,
#   1.9303662320449656e-09,
#   1.9340348694313181e-09,
#   1.9377088567878428e-09,
#   1.9413881928548919e-09,
#   1.9450728580150069e-09,
#   1.9487628486750952e-09,
#   1.9524581888097567e-09,
#   1.9561588622294249e-09,
#   1.9598648976994897e-09,
#   1.9635762448753568e-09,
#   1.9672930594164006e-09,
#   1.9710152170305311e-09,
#   1.9747427861723549e-09,
#   1.9784758072744876e-09,
#   1.9822142931192528e-09,
#   1.9859582590702177e-09,
#   1.9897077681717017e-09,
#   1.993462816975161e-09,
#   1.9972234509724506e-09,
#   2.000989694200121e-09,
#   2.0047615738541647e-09,
#   2.008539185254783e-09,
#   2.0123224658119564e-09,
#   2.0161115064680954e-09,
#   2.0199063231443158e-09,
#   2.0237069481371509e-09,
#   2.0275134080437446e-09,
#   2.0313257531260923e-09,
#   2.0351439828885945e-09,
#   2.0389681417493092e-09,
#   2.0427982661967095e-09,
#   2.0466343382446833e-09,
#   2.0504764159196094e-09,
#   2.0543245238362365e-09,
#   2.058178675685485e-09,
#   2.0620389049822363e-09,
#   2.065905179781006e-09,
#   2.0697776478322362e-09,
#   2.0736561635537304e-09,
#   2.0775408227199892e-09,
#   2.0814316419129273e-09,
#   2.0853286393458069e-09,
#   2.0892318289779992e-09,
#   2.0931412199161344e-09,
#   2.0970568403474045e-09,
#   2.1009786981807423e-09,
#   2.1049068137150555e-09,
#   2.1088412010129649e-09,
#   2.1127818828307228e-09,
#   2.116728861357225e-09,
#   2.1206821748155408e-09,
#   2.1246418175888831e-09,
#   2.1286078137964006e-09,
#   2.132580194330429e-09,
#   2.1365589464086452e-09,
#   2.1405441094724664e-09,
#   2.1445356808373987e-09,
#   2.1485336906110788e-09,
#   2.1525381192792974e-09,
#   2.1565490009557837e-09,
#   2.16056635839679e-09,
#   2.1645901603589312e-09,
#   2.1686204318906056e-09,
#   2.1726571877152319e-09,
#   2.1767004024333634e-09,
#   2.1807500938865624e-09,
#   2.1848062430149197e-09,
#   2.188868854258175e-09,
#   2.1929379280499781e-09,
#   2.1970134481594622e-09,
#   2.2010953836942927e-09,
#   2.205183753673079e-09,
#   2.2092785118605685e-09,
#   2.2133796719270323e-09,
#   2.2174871943897524e-09,
#   2.2216010705963979e-09,
#   2.2257212650496918e-09,
#   2.2298477805786792e-09,
#   2.2339805880462706e-09,
#   2.2381196586664259e-09,
#   2.2422649957844386e-09,
#   2.2464165600414907e-09,
#   2.2505743380977095e-09,
#   2.2547383267317029e-09,
#   2.2589085061401612e-09,
#   2.2630848619094151e-09,
#   2.2672674230320039e-09,
#   2.2714561224162177e-09,
#   2.2756510092089538e-09,
#   2.2798520682944442e-09,
#   2.2840592948199484e-09,
#   2.2882727431155032e-09,
#   2.2924923297552828e-09,
#   2.2967181921028006e-09,
#   2.3009502819197568e-09,
#   2.3051886414353136e-09,
#   2.3094332425242296e-09,
#   2.3136841972331705e-09,
#   2.3179415073999826e-09,
#   2.3222051998283105e-09,
#   2.3264753097469795e-09,
#   2.3307518808306491e-09,
#   2.3350349663975076e-09,
#   2.3393246035348777e-09,
#   2.343620824931641e-09,
#   2.3479236869415299e-09,
#   2.3522332193624316e-09,
#   2.3565494933953983e-09,
#   2.3608725119520732e-09,
#   2.3652023655618671e-09,
#   2.3695390664289048e-09,
#   2.3738826547586523e-09,
#   2.3782331754854158e-09,
#   2.3825906650357186e-09,
#   2.3869551632020283e-09,
#   2.3913266872890084e-09,
#   2.3957052821690151e-09,
#   2.4000909487919466e-09,
#   2.4044837695717806e-09,
#   2.4088837084949919e-09,
#   2.4132907946573706e-09,
#   2.4177050724769734e-09,
#   2.4221265564294201e-09,
#   2.4265552131030807e-09,
#   2.4309911111590611e-09,
#   2.4354342219558718e-09,
#   2.4398845697159122e-09,
#   2.4443421560085785e-09,
#   2.4488069985928341e-09,
#   2.4532790784294186e-09,
#   2.4577584247173709e-09,
#   2.4622450191195295e-09,
#   2.4667388819761015e-09,
#   2.4712400040772066e-09,
#   2.4757483953141742e-09,
#   2.4802640529818595e-09,
#   2.4847869926090303e-09,
#   2.4893172007525646e-09,
#   2.4938546978352699e-09,
#   2.4983994975067674e-09,
#   2.5029515469031681e-09,
#   2.5075109082634413e-09,
#   2.5120775725842061e-09,
#   2.5166515419511084e-09,
#   2.5212328303854682e-09,
#   2.5258214354299413e-09,
#   2.5304173538837846e-09,
#   2.5350206158133342e-09,
#   2.5396311992057373e-09,
#   2.5442491363781753e-09,
#   2.5488743974088616e-09,
#   2.5535070258692044e-09,
#   2.5581469932622642e-09,
#   2.5627943075589234e-09,
#   2.5674489831109025e-09,
#   2.5721110001148925e-09,
#   2.5767803797990496e-09,
#   2.5814570889582429e-09,
#   2.5861411706476323e-09,
#   2.5908325791482138e-09,
#   2.595531330215904e-09,
#   2.6002374160450193e-09,
#   2.6049508116078119e-09,
#   2.6096715542394043e-09,
#   2.6143996012150351e-09,
#   2.6191349690546701e-09,
#   2.6238776533185687e-09,
#   2.628627606078181e-09,
#   2.6333848909560238e-09,
#   2.6381494707202249e-09,
#   2.642921348633478e-09,
#   2.6477005248196825e-09,
#   2.6524870200320447e-09,
#   2.6572808107502642e-09,
#   2.6620819460386384e-09,
#   2.6668904048342116e-09,
#   2.6717062340123852e-09,
#   2.6765293713754896e-09,
#   2.6813599607504738e-09,
#   2.6861979461553057e-09,
#   2.6910433756630838e-09,
#   2.6958962696140163e-09,
#   2.7007566672636712e-09,
#   2.7056246098293618e-09,
#   2.7105001309911684e-09,
#   2.7153832674440641e-09,
#   2.7202740637506557e-09,
#   2.7251725747572283e-09,
#   2.7300788272467766e-09,
#   2.7349928971491915e-09,
#   2.7399148070761759e-09,
#   2.7448446146824092e-09,
#   2.749782375722775e-09,
#   2.7547281103929316e-09,
#   2.7596818960682665e-09,
#   2.7646437781993353e-09,
#   2.7696137825159838e-09,
#   2.7745919615930027e-09,
#   2.7795783540871109e-09,
#   2.7845730017525208e-09,
#   2.7895759397561098e-09,
#   2.7945871966567675e-09,
#   2.7996068016328833e-09,
#   2.8046347726705696e-09,
#   2.8096711689939022e-09,
#   2.8147159679292295e-09,
#   2.8197692009057845e-09,
#   2.8248308921459676e-09,
#   2.829901044231023e-09,
#   2.8349796603203946e-09,
#   2.8400667447299226e-09,
#   2.8451623156315691e-09,
#   2.8502663582193157e-09,
#   2.8553788656993261e-09,
#   2.8604998460218338e-09,
#   2.8656292932809512e-09,
#   2.8707672040900855e-09,
#   2.8759135583568284e-09,
#   2.8810683645683121e-09,
#   2.886231612606058e-09,
#   2.8914032861772503e-09,
#   2.8965833740276618e-09,
#   2.9017719058106313e-09,
#   2.9069688464831816e-09,
#   2.9121741856583847e-09,
#   2.9173879482813885e-09,
#   2.9226101045130049e-09,
#   2.9278406770475366e-09,
#   2.9330796505627159e-09,
#   2.9383270462660484e-09,
#   2.9435828841466923e-09,
#   2.9488470421014526e-09,
#   2.954119770263257e-09,
#   2.9594008808207473e-09,
#   2.9646904489810671e-09,
#   2.9699884764788123e-09,
#   2.9752949831792416e-09,
#   2.9806099864076686e-09,
#   2.9859334866596924e-09,
#   2.9912655185652908e-09,
#   2.9966060918092932e-09,
#   3.0019552070937987e-09,
#   3.0073128883521064e-09,
#   3.0126791582785196e-09,
#   3.0180540152623417e-09,
#   3.0234374938922502e-09,
#   3.0288296042454239e-09,
#   3.0342303574108897e-09,
#   ...)]

# %%
plot_spectra(times, pops, taus, g1, specs, freqs, freq_window=4000., tau_window=30.)

# %%
reload(SF)


eps = 8000.
w0_prop = 600/eps
alpha_prop = pi*800/eps
Gamma = 80.
Gamma_EM = (10/100.)/inv_ps_to_inv_cm
print Gamma_EM 
times, pops, taus, g1, specs, freqs = SF.emission_spectra(2, 0, alpha_prop, eps, Gamma, 
                                                     w0_prop=w0_prop, T_ph=300., T_EM=0., 
                                                     Gamma_EM=Gamma_EM, overdamped=False, 
                                                     N=12, end_T_mult=7., rotating=True, 
                                                     tau_f_mult=2.5, T_increments=9, 
                                                     nsteps=3000, method='bdf', order=5)
# Out:
# 0.0188359389716
# w_RC=600.0 | TLS splitting = 8000.0 | RC-res. coupling=0.02 | TLS-RC coupling=868.32 | Gamma_RC=80.00 | alpha_ph=800.00 | N=12 |
# final t:  371.63
# 10.0%. Run time:  59.43s. Est. time left: 00:00:08:53
# 20.0%. Run time: 121.00s. Est. time left: 00:00:08:03
# 30.0%. Run time: 181.47s. Est. time left: 00:00:07:02
# 40.0%. Run time: 246.07s. Est. time left: 00:00:06:08
# 50.0%. Run time: 309.74s. Est. time left: 00:00:05:09
# 60.0%. Run time: 378.82s. Est. time left: 00:00:04:12
# 70.0%. Run time: 446.45s. Est. time left: 00:00:03:11
# 80.0%. Run time: 512.79s. Est. time left: 00:00:02:08
# 90.0%. Run time: 573.47s. Est. time left: 00:00:01:03
# Total run time: 634.24s
# Completed initial dynamics calculations for Full in 634.75899291  seconds.
# Completed correlation function calculations for Full in 22.9273068905 seconds.
# 10.0%. Run time:  45.21s. Est. time left: 00:00:06:46
# 20.0%. Run time:  90.07s. Est. time left: 00:00:06:00
# 30.0%. Run time: 135.28s. Est. time left: 00:00:05:15
# 40.0%. Run time: 180.30s. Est. time left: 00:00:04:30
# 50.0%. Run time: 225.10s. Est. time left: 00:00:03:45
# 60.0%. Run time: 270.33s. Est. time left: 00:00:03:00
# 70.0%. Run time: 315.52s. Est. time left: 00:00:02:15
# 80.0%. Run time: 360.42s. Est. time left: 00:00:01:29
# 90.0%. Run time: 405.47s. Est. time left: 00:00:00:44
# Total run time: 450.36s
# Completed initial dynamics calculations for Naive in 451.008622169  seconds.
# Completed correlation function calculations for Naive in 22.6862559319 seconds.

# %%
plot_spectra(times, pops, taus, g1, specs, freqs, freq_window=4000., tau_window=30.)

# %%
reload(SF)
alpha_prop = 0.05
w0_prop = 0.05
eps = 1000
print "eps is {} times the RC freq".format(1/w0_prop)
Gamma = eps*0.01
Gamma_EM = eps*0.001
print Gamma_EM
# beginning in a product state of |E> and non-displaced thermal state (that's what the first parameters mean)
freq, spec = emission_spectra(2, 0, alpha_prop, eps, Gamma, w0_prop=w0_prop, T_ph=77., T_EM=77., 
                                    Gamma_EM=Gamma_EM, overdamped=False, N=15)
# Out:
# eps is 20.0 times the RC freq
# 1.0
# w_RC=50.0 | TLS splitting = 1000 | RC-res. coupling=0.03 | TLS-RC coupling=35.36 | Gamma_RC=10.00 | alpha_ph=15.92 | N=15 |
# Completed initial dynamics calculations for Naive in 2.86493301392 seconds.
# Completed correlation function calculations for Naive in 1.42068505287 seconds.
# Completed initial dynamics calculations for Full in 4.20401096344 seconds.
# Completed correlation function calculations for Full in 1.81511306763 seconds.

# %% [markdown]
# ### Emission: Lower $T_{ph}$

# %%
alpha_prop = 0.1
w0_prop = 0.05
eps = 1000
print "eps is {} times the RC freq".format(1/w0_prop)
Gamma = eps*0.01
Gamma_EM = eps*0.001
eps = 1000
freq, spec = SF.emission_spectra(2, 0, alpha_prop, eps, Gamma, w0_prop=w0_prop, T_ph=45., T_EM=0., 
                                    Gamma_EM=Gamma_EM, overdamped=False, N=20)
# Out:
# eps is 20.0 times the RC freq
# w_RC=50.0 | TLS splitting = 1000 | RC-res. coupling=0.03 | TLS-RC coupling=50.00 | Gamma_RC=10.00 | alpha_ph=31.83 | N=20 |
# Completed initial dynamics calculations for Naive in 11.3144381046 seconds.
# Completed correlation function calculations for Naive in 2.63095712662 seconds.
# Completed initial dynamics calculations for Full in 13.3193480968 seconds.
# Completed correlation function calculations for Full in 2.92482709885 seconds.

# %% [markdown]
# ### Emission: smaller $\omega_0$ but larger $\alpha_1$

# %%
alpha_prop = 0.2
w0_prop = 0.02
print "eps is {} times the RC freq".format(1/w0_prop)
eps = 1000
freq, spec = SF.emission_spectra(2, 0, alpha_prop, eps, Gamma, w0_prop=w0_prop, T_ph=77., T_EM=0., 
                                    Gamma_EM=Gamma_EM, overdamped=False, N=27)
# Out:
# eps is 50.0 times the RC freq
# w_RC=20.0 | TLS splitting = 1000 | RC-res. coupling=0.08 | TLS-RC coupling=44.72 | Gamma_RC=10.00 | alpha_ph=63.66 | N=27 |
# Completed initial dynamics calculations for Naive in 59.9946351051 seconds.
# Completed correlation function calculations for Naive in 6.48902606964 seconds.
# Completed initial dynamics calculations for Full in 56.9160017967 seconds.
# Completed correlation function calculations for Full in 5.45249986649 seconds.

# %% [markdown]
# From the above, there are minor changes in this intermediate-strong coupling regime, for low frequency modes. However, the number of states taken is rather small (there are 50 states until the first excited state)

# %%
alpha_prop = 0.2
w0_prop = 0.02
print "eps is {} times the RC freq".format(1/w0_prop)
eps = 1000
freq, spec = SF.emission_spectra(2, 0, alpha_prop, eps, Gamma, w0_prop=w0_prop, T_ph=25., T_EM=0., 
                                    Gamma_EM=Gamma_EM, overdamped=False, N=27)
# Out:
# eps is 50.0 times the RC freq
# w_RC=20.0 | TLS splitting = 1000 | RC-res. coupling=0.08 | TLS-RC coupling=44.72 | Gamma_RC=10.00 | alpha_ph=63.66 | N=27 |
# Completed initial dynamics calculations for Naive in 31.0070509911 seconds.
# Completed correlation function calculations for Naive in 7.31235599518 seconds.
# Completed initial dynamics calculations for Full in 35.100673914 seconds.
# Completed correlation function calculations for Full in 6.53607106209 seconds.

# %% [markdown]
# check convergence of the previous plot

# %%
alpha_prop = 0.2
w0_prop = 0.02
print "eps is {} times the RC freq".format(1/w0_prop)
eps = 1000
freq, spec = SF.emission_spectra(2, 0, alpha_prop, eps, Gamma, w0_prop=w0_prop, T_ph=25., T_EM=0., 
                                    Gamma_EM=Gamma_EM, overdamped=False, N=35)
# Out:
# eps is 50.0 times the RC freq
# w_RC=20.0 | TLS splitting = 1000 | RC-res. coupling=0.08 | TLS-RC coupling=44.72 | Gamma_RC=10.00 | alpha_ph=63.66 | N=35 |
# Completed initial dynamics calculations for Naive in 59.6243739128 seconds.
# Completed correlation function calculations for Naive in 21.5777461529 seconds.
# Completed initial dynamics calculations for Full in 65.5812039375 seconds.
# Completed correlation function calculations for Full in 17.7616739273 seconds.

# %%
alpha_prop = 0.5
w0_prop = 0.02
eps = 1000
freq, spec = SF.emission_spectra(2, 0, alpha_prop, eps, Gamma, w0_prop=w0_prop, T_ph=77., T_EM=0., 
                                    Gamma_EM=Gamma_EM, overdamped=False, N=27)
# Out:
# w_RC=20.0 | TLS splitting = 1000 | RC-res. coupling=0.08 | TLS-RC coupling=70.71 | Gamma_RC=10.00 | alpha_ph=159.15 | N=27 |
# Completed initial dynamics calculations for Naive in 108.050420046 seconds.
# Completed correlation function calculations for Naive in 11.4769351482 seconds.
# Completed initial dynamics calculations for Full in 119.560393095 seconds.
# Completed correlation function calculations for Full in 12.3575100899 seconds.

# %%
alpha_prop = 0.5
w0_prop = 0.02
eps = 1000
freq, spec = SF.emission_spectra(2, 0, alpha_prop, eps, Gamma, w0_prop=w0_prop, T_ph=77., T_EM=0., 
                                    Gamma_EM=Gamma_EM, overdamped=False, N=38)
# Out:
# w_RC=20.0 | TLS splitting = 1000 | RC-res. coupling=0.08 | TLS-RC coupling=70.71 | Gamma_RC=10.00 | alpha_ph=159.15 | N=38 |
# Completed initial dynamics calculations for Naive in 247.858265877 seconds.
# Completed correlation function calculations for Naive in 26.0641291142 seconds.
# Completed initial dynamics calculations for Full in 250.421614885 seconds.
# Completed correlation function calculations for Full in 30.3401827812 seconds.

# %%
alpha_prop = 0.5
w0_prop = 0.1
eps = 1000
freq, spec = SF.emission_spectra(2, 0, alpha_prop, eps, Gamma, w0_prop=w0_prop, T_ph=77., T_EM=0., 
                                    Gamma_EM=Gamma_EM, overdamped=False, N=19)
# Out:
# w_RC=100.0 | TLS splitting = 1000 | RC-res. coupling=0.01 | TLS-RC coupling=158.11 | Gamma_RC=5.00 | alpha_ph=159.15 | N=19 |
# Completed initial dynamics calculations for Naive in 41.381909132 seconds.
# Completed correlation function calculations for Naive in 3.43289995193 seconds.
# Completed initial dynamics calculations for Full in 54.9468028545 seconds.
# Completed correlation function calculations for Full in 4.51809692383 seconds.

# %%
alpha_prop = 0.21
w0_prop = 0.06
print 1/w0_prop
eps = 1000
freq, spec = SF.emission_spectra(2, 0, alpha_prop, eps, Gamma, w0_prop=w0_prop, T_ph=25., T_EM=0., 
                                    Gamma_EM=Gamma_EM, overdamped=False, N=20)
# Out:
# 16.6666666667
# w_RC=60.0 | TLS splitting = 1000 | RC-res. coupling=0.01 | TLS-RC coupling=79.37 | Gamma_RC=5.00 | alpha_ph=66.85 | N=20 |
# Completed initial dynamics calculations for Naive in 35.2304289341 seconds.
# Completed correlation function calculations for Naive in 2.66073393822 seconds.
# Completed initial dynamics calculations for Full in 35.003015995 seconds.
# Completed correlation function calculations for Full in 3.49464702606 seconds.

# %% [markdown]
# The last calculations are slightly more interesting...

# %% [markdown]
# ### Emission: smaller spontaneous emission and phonon broadening

# %%
alpha_prop = 0.5
w0_prop = 0.02
eps = 1000
Gamma = eps*0.01
Gamma_EM = eps*0.0005
freq, spec = SF.emission_spectra(2, 0, alpha_prop, eps, Gamma, w0_prop=w0_prop, T_ph=77., T_EM=0., 
                                    Gamma_EM=Gamma_EM, overdamped=False, N=27)
# Out:
# w_RC=20.0 | TLS splitting = 1000 | RC-res. coupling=0.08 | TLS-RC coupling=70.71 | Gamma_RC=10.00 | alpha_ph=159.15 | N=27 |
# Completed initial dynamics calculations for Naive in 103.544978142 seconds.
# Completed correlation function calculations for Naive in 9.60875701904 seconds.
# Completed initial dynamics calculations for Full in 115.829185963 seconds.
# Completed correlation function calculations for Full in 14.7421360016 seconds.

# %%
reload(SF)
alpha_prop = 1.
w0_prop = 0.02
eps = 1000
Gamma = eps*0.005
Gamma_EM = eps*0.0005
freq, spec = SF.emission_spectra(2, 0, alpha_prop, eps, Gamma, w0_prop=w0_prop, T_ph=77., T_EM=0., 
                                    Gamma_EM=Gamma_EM, overdamped=False, N=27)
# Out:
# w_RC=20.0 | TLS splitting = 1000 | RC-res. coupling=0.04 | TLS-RC coupling=100.00 | Gamma_RC=5.00 | alpha_ph=318.31 | N=27 |
# Completed initial dynamics calculations for Naive in 84.2470109463 seconds.
# Completed correlation function calculations for Naive in 8.75793814659 seconds.
# Completed initial dynamics calculations for Full in 93.8188679218 seconds.
# Completed correlation function calculations for Full in 10.8651258945 seconds.

# %%
alpha_prop = 0.1
w0_prop = 0.02
eps = ev_to_inv_cm*1.5
Gamma = eps*0.005
Gamma_EM = eps*0.0005
freq, spec = SF.emission_spectra(2, 0, alpha_prop, eps, Gamma, w0_prop=w0_prop, T_ph=77., T_EM=0., 
                                    Gamma_EM=Gamma_EM, overdamped=False, N=27)
# Out:
# w_RC=20.0 | TLS splitting = 1000 | RC-res. coupling=0.48 | TLS-RC coupling=31.62 | Gamma_RC=60.49 | alpha_ph=31.83 | N=27 |
# Completed initial dynamics calculations for Naive in 51.9058740139 seconds.
# Completed correlation function calculations for Naive in 31.7289760113 seconds.
# Completed initial dynamics calculations for Full in 50.1810450554 seconds.
# Completed correlation function calculations for Full in 38.7844150066 seconds.

# %%
reload(SF)
alpha_prop = 0.3
w0_prop = 0.02
eps = ev_to_inv_cm*1.
Gamma = eps*0.005
Gamma_EM = eps*0.0005
freq, spec = SF.emission_spectra(2, 0, alpha_prop, eps, Gamma, w0_prop=w0_prop, T_ph=300., T_EM=0., 
                                    Gamma_EM=Gamma_EM, overdamped=False, N=27, tau_f_mult=0.125)
# Out:
# w_RC=161.31 | TLS splitting = 8065.5 | RC-res. coupling=0.04 | TLS-RC coupling=441.77 | Gamma_RC=40.33 | alpha_ph=770.20 | N=27 |
# Completed initial dynamics calculations for Naive in 57.0613410473 seconds.
# Completed correlation function calculations for Naive in 5.72468781471 seconds.
# Completed initial dynamics calculations for Full in 65.8397397995 seconds.
# Completed correlation function calculations for Full in 6.07505011559 seconds.

# %%
plt.plot(freq, spec)
plt.show()

# %%
reload(SF)
alpha_prop = 0.0005
w0_prop = 0.02
eps = ev_to_inv_cm*1.
Gamma = eps*0.005
Gamma_EM = eps*0.0005
freq, spec = SF.emission_spectra(2, 0, alpha_prop, eps, Gamma, w0_prop=w0_prop, T_ph=77., T_EM=0., 
                                    Gamma_EM=Gamma_EM, overdamped=False, N=10, tau_f_mult=1., per_tau=0.7)
# Out:
# w_RC=161.31 | TLS splitting = 8065.5 | RC-res. coupling=0.04 | TLS-RC coupling=18.04 | Gamma_RC=40.33 | alpha_ph=1.28 | N=10 |
# Completed initial dynamics calculations for Naive in 0.956996917725 seconds.
# Completed correlation function calculations for Naive in 3.2286939621 seconds.
# Completed initial dynamics calculations for Full in 1.13579297066 seconds.
# Completed correlation function calculations for Full in 3.52195096016 seconds.

# %%
plt.plot(freq, spec)
plt.show()

# %% [markdown]
# ## Emission: much higher $\omega_0$
#
# note that $g_1(\tau)$ is calculated for twice as long as is shown on the axes. I expect that the spectra will agree much more in this parameter regime.

# %%
reload(SF)
alpha_prop = 0.5
w0_prop = 0.33
eps = 1000
Gamma = eps*0.005
Gamma_EM = eps*0.0005


freq, spec = SF.emission_spectra(2, 0, alpha_prop, eps, Gamma, w0_prop=w0_prop, T_ph=77., T_EM=0., 
                                    Gamma_EM=Gamma_EM, overdamped=False, N=14, end_T_mult=11, tau_f_mult=4.)
# Out:
# w_RC=330.0 | TLS splitting = 1000 | RC-res. coupling=0.00 | TLS-RC coupling=287.23 | Gamma_RC=5.00 | alpha_ph=159.15 | N=14 |
# Completed initial dynamics calculations for Naive in 39.5174250603 seconds.
# Completed correlation function calculations for Naive in 10.9831750393 seconds.
# Completed initial dynamics calculations for Full in 59.4871919155 seconds.
# Completed correlation function calculations for Full in 18.0676279068 seconds.

# %%
reload(SF)
alpha_prop = 0.5
w0_prop = 0.3
Gamma = eps*0.1
Gamma_EM = eps*0.001
eps = 1000

freq, spec = SF.emission_spectra(2, 0, alpha_prop, eps, Gamma, w0_prop=w0_prop, T_ph=77., T_EM=0., 
                                    Gamma_EM=Gamma_EM, overdamped=False, N=12, end_T_mult=11)
# Out:
# w_RC=300.0 | TLS splitting = 1000 | RC-res. coupling=0.05 | TLS-RC coupling=273.86 | Gamma_RC=100.00 | alpha_ph=159.15 | N=12 |
# Completed initial dynamics calculations for Naive in 11.1509330273 seconds.
# Completed correlation function calculations for Naive in 1.65879893303 seconds.
# Completed initial dynamics calculations for Full in 15.4421069622 seconds.
# Completed correlation function calculations for Full in 1.92984294891 seconds.

# %%
def emission_spectra_Tdep(init_sys, init_RC, prop_coupling, eps, Gamma, w0_prop=2.1,
                          T_vals = [10, 30, 77, 150], T_EM=0.,Gamma_EM=1., overdamped=False, N=9,
                    end_T_mult=10, tau_f_mult=1., per_tau=1. , log_y=True):
    wc = 53.
    # Start system+RC in adiabatic eigenstate and then time-evolve
    plt.close('all')
    alpha_ph = prop_coupling*eps/pi
    w0 = eps*w0_prop
    if overdamped:
        Gamma = (w0**2)/wc
    else:
        #N=20
        pass
    w = np.linspace(0., eps*1.5, 1000)
    plt.figure()
    plt.plot(w, J_underdamped(w, alpha_ph, Gamma, w0))
    plt.axvline(eps, label='Splitting',color='k')
    plt.ylabel("Coupling Strength")
    plt.xlabel(r"Frequency $cm^{-1}$")
    plt.title("Phonon Spectral Density")
    plt.legend()
    plt.show()
    G = ket([0])
    E = ket([1])
    sigma = G*E.dag() # Definition of a sigma_- operator.
    J = J_multipolar
    count = 1
    I_RC = qt.qeye(N)
    f1, ax1 = plt.subplots(1, 1, figsize=(14,6))
    # This is true for specific Hamiltonian parameters
    colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
    dyn_DATA = []
    for j, T_ph in enumerate(T_vals):
        L_RC, H_RC, A_EM, A_nrwa, Z, wRC, kappa, Gamma= RC.RC_function_UD(sigma, eps,
                                                                       T_ph, Gamma,
                                                                       w0, alpha_ph, N, rotating=False)
        evals, states = H_RC.eigenstates()
        ground_list, excited_list = ground_and_excited_states(states)
        # work out how to initialise system rho
        init_rho = initialise_TLS(init_sys, init_RC, states, w0, T_ph)
        label = ['Naive', 'Full']
        #print len(excited_list), 'excited'
        # electromagnetic bath liouvillians
        final_t = end_T_mult/Gamma_EM
        timelist = np.linspace(0,final_t,int(380*final_t))
        options = qt.Options(nsteps=6000, store_states=True)
        

        E_op = tensor(E*E.dag(), I_RC)
        if overdamped:
                steps_per_tau, tau_f = 1500*per_tau,  1.1
        else:
            if abs((w0-eps)/eps)<0.1:
                steps_per_tau, tau_f = 2000*per_tau, 2.5
            else:
                steps_per_tau, tau_f = 2000*per_tau, 1.1
        tau_f*=tau_f_mult
        for i, L_EM in enumerate([EM.L_EM_lindblad(eps, A_EM, Gamma_EM, T_EM, J=J, silent=True),
                            EM.L_non_rwa(H_RC, A_nrwa, eps, Gamma_EM, T_EM, J, silent=True)]):
            #L_EM = EM.L_nonsecular(H_RC, A_EM, eps, Gamma_EM, T_EM, J=J)
            #L_s = EM.L_vib_lindblad(H_RC, A_EM, eps, Gamma_EM, T_EM, J=J, silent=True)
            ti = time.time()
            sigma_RC = tensor(sigma, I_RC)

            if label[i]=='Full':
                sigma_plus_RC, sigma_RC, sigma_0_RC = EM.RWA_system_ops(H_RC, tensor(sigma+sigma.dag(), I_RC))
                ls = 'solid'
            else:
                ls = 'dashed'
            P = mesolve(H_RC, init_rho, timelist, [L_RC+L_EM], progress_bar=None,options=options).states
            
            #norm = np.array([(sigma_RC.dag()*sigma_RC*rho_t).tr() for rho_t in P])[0:tau_f*steps_per_tau]
            R= sum(P)
            print "Completed initial dynamics calculations for {} in {} seconds.".format(label[i], time.time()-ti)
            ti = time.time()
            Lambda_0 = sigma_RC*R
            del P
            taulist = np.linspace(0, tau_f, int(tau_f*steps_per_tau))
            Lambda_t = mesolve(H_RC, Lambda_0, taulist, [L_RC+L_EM],options=options)
            #sigma_t = mesolve(H_RC, init_rho, taulist, [L_RC+L_EM],
            #                  [sigma_RC.dag()*sigma_RC], options=options).expect[0]
            g_1 = np.array([(sigma_RC.dag()*l).tr() for l in Lambda_t.states])
            g_1/=abs(g_1[0])
            #else:
            #    g_1/=np.sqrt(norm*norm[0])

            #if label[i] == 'Full':
            #    g_1=g_1.conjugate()
            freq, spec = qt.spectrum_correlation_fft(taulist, g_1)
            spec-= min(spec)
            spec = spec/sum(spec)
            if i==1:
                # only label one of the two calculations
                ax1.plot(freq, spec.real, label=int(T_ph), linestyle=ls, color=colors[j])
            else:
                ax1.plot(freq, spec.real, linestyle=ls, color=colors[j])
            print "Completed correlation function calculations for {} in {} seconds. Final value was {:.3f}.".format(
                                                                            label[i], time.time()-ti, g_1[-1])

    ax1.set_xlabel(r"Frequency $cm^{-1}$")
    #ax2.axvline(eps, linestyle='dashed',color='k', alpha=0.4)
    ax1.set_xlim(eps*0.5,eps*1.5)
    ax1.set_ylabel(r"Fluorescence intensity (arb. units)")
    if log_y:
        ax1.set_yscale('log')
    ax1.legend()
    plt.show()
    return freq, spec

alpha_prop = 0.3
w0_prop = 0.075
eps = 1000
freq, spec = emission_spectra_Tdep(2, 0, alpha_prop, eps, Gamma, w0_prop=w0_prop, T_EM=0., 
                                    Gamma_EM=Gamma_EM, overdamped=False, N=14, per_tau=0.96, log_y=True)
# Out:
# w_RC=75.0 | TLS splitting = 1000 | RC-res. coupling=0.01 | TLS-RC coupling=106.07 | Gamma_RC=5.00 | alpha_ph=95.49 | N=14 |
# Completed initial dynamics calculations for Naive in 12.3327441216 seconds.
# Completed correlation function calculations for Naive in 1.67038106918 seconds. Final value was 0.011+0.003j.
# Completed initial dynamics calculations for Full in 13.1319849491 seconds.
# Completed correlation function calculations for Full in 1.99560904503 seconds. Final value was 0.014+0.003j.
# w_RC=75.0 | TLS splitting = 1000 | RC-res. coupling=0.01 | TLS-RC coupling=106.07 | Gamma_RC=5.00 | alpha_ph=95.49 | N=14 |
# Completed initial dynamics calculations for Naive in 12.3329980373 seconds.
# Completed correlation function calculations for Naive in 1.94236302376 seconds. Final value was 0.000+0.000j.
# Completed initial dynamics calculations for Full in 12.4141538143 seconds.
# Completed correlation function calculations for Full in 3.31222391129 seconds. Final value was 0.000+0.000j.
# w_RC=75.0 | TLS splitting = 1000 | RC-res. coupling=0.01 | TLS-RC coupling=106.07 | Gamma_RC=5.00 | alpha_ph=95.49 | N=14 |
# Completed initial dynamics calculations for Naive in 12.203111887 seconds.
# Completed correlation function calculations for Naive in 1.77873492241 seconds. Final value was 0.000+0.000j.
# Completed initial dynamics calculations for Full in 13.7350759506 seconds.
# Completed correlation function calculations for Full in 2.09972596169 seconds. Final value was 0.000+0.000j.
# w_RC=75.0 | TLS splitting = 1000 | RC-res. coupling=0.01 | TLS-RC coupling=106.07 | Gamma_RC=5.00 | alpha_ph=95.49 | N=14 |
# Completed initial dynamics calculations for Naive in 13.6658270359 seconds.
# Completed correlation function calculations for Naive in 2.07722997665 seconds. Final value was 0.000-0.000j.
# Completed initial dynamics calculations for Full in 19.0772309303 seconds.
# Completed correlation function calculations for Full in 1.70055007935 seconds. Final value was 0.000-0.000j.

# %%
freq, spec = emission_spectra_Tdep(2, 0, alpha_prop, eps, Gamma, w0_prop=w0_prop, T_EM=0., 
                                    Gamma_EM=Gamma_EM, overdamped=False, N=14, per_tau=0.90)
# Out:
# w_RC=75.0 | TLS splitting = 1000 | RC-res. coupling=0.01 | TLS-RC coupling=106.07 | Gamma_RC=5.00 | alpha_ph=95.49 | N=14 |
# Completed initial dynamics calculations for Naive in 11.7108280659 seconds.
# Completed correlation function calculations for Naive in 1.36212897301 seconds. Final value was 0.011+0.003j.
# Completed initial dynamics calculations for Full in 13.4797258377 seconds.
# Completed correlation function calculations for Full in 2.12438607216 seconds. Final value was 0.014+0.003j.
# w_RC=75.0 | TLS splitting = 1000 | RC-res. coupling=0.01 | TLS-RC coupling=106.07 | Gamma_RC=5.00 | alpha_ph=95.49 | N=14 |
# Completed initial dynamics calculations for Naive in 11.9025788307 seconds.
# Completed correlation function calculations for Naive in 1.37391805649 seconds. Final value was 0.000+0.000j.
# Completed initial dynamics calculations for Full in 13.7759320736 seconds.
# Completed correlation function calculations for Full in 1.84198498726 seconds. Final value was 0.000+0.000j.
# w_RC=75.0 | TLS splitting = 1000 | RC-res. coupling=0.01 | TLS-RC coupling=106.07 | Gamma_RC=5.00 | alpha_ph=95.49 | N=14 |
# Completed initial dynamics calculations for Naive in 12.5606200695 seconds.
# Completed correlation function calculations for Naive in 1.83482503891 seconds. Final value was 0.000+0.000j.
# Completed initial dynamics calculations for Full in 13.4981820583 seconds.
# Completed correlation function calculations for Full in 1.49852609634 seconds. Final value was 0.000+0.000j.
# w_RC=75.0 | TLS splitting = 1000 | RC-res. coupling=0.01 | TLS-RC coupling=106.07 | Gamma_RC=5.00 | alpha_ph=95.49 | N=14 |
# Completed initial dynamics calculations for Naive in 12.2178359032 seconds.
# Completed correlation function calculations for Naive in 1.44705986977 seconds. Final value was 0.000+0.000j.
# Completed initial dynamics calculations for Full in 13.2746880054 seconds.
# Completed correlation function calculations for Full in 1.75820398331 seconds. Final value was 0.000-0.000j.

# %% [markdown]
# ## Absorption spectra
# This remains to be done. I need to look over the calculation again but it's not really on my agenda right now...

# %%
reload(SF)
alpha_prop = 0.3
w0_prop = 0.05
eps = 1000
Gamma = eps*0.01
Gamma_EM = eps*0.001
freq, spec = SF.absorption_spectra(alpha_prop, eps, Gamma, w0_prop*eps, Gamma_EM=Gamma_EM, overdamped=False, N=15)
# Out:
# w_RC=50.0 | TLS splitting = 1000 | RC-res. coupling=0.03 | TLS-RC coupling=86.60 | Gamma_RC=10.00 | alpha_ph=95.49 | N=15 |
# Completed response function calculations for Naive in 2.42631196976 seconds.
# Completed response function calculations for Full in 2.37483692169 seconds.
